# %% [markdown]
# # Simple gender analysis

# %% [markdown]
# - ## Imports

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import unicodedata

import os, sys, json, re, argparse, urllib2, html5lib
from bs4 import BeautifulSoup, Tag, UnicodeDammit
import pandas as pd
from pandas.io.json import json_normalize
import time
import math

from crawler import *
# Out:
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %% [markdown]
# - ## Crawl

# %% [raw]
# #crawl top100 per year
# path_ = '../data/top100 per year/'
# for year in range(2000,2017):
#     try:
#         get_top100(year,path_)
#     except Exception as e:
#         print(e)
#         time.sleep(60)
#         print('Retrying for year : %s' %(year))
#         get_top100(year,path_)

# %% [raw]
# for i in range(2000,2017):
#     compare_top_vs_script(i,'../data/top100 per year/','../data/top100 per year/curated/')

# %%
genre_url='http://www.imsdb.com/genre/Action'
scripts_by_genre('action','../data/all_script/action/')
# Out:
# http://www.imsdb.com/scripts/Star-Wars-Revenge-of-the-Sith.html
# Found exception 'NoneType' object has no attribute 'find' in parsing.
# http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html
# Getting script @ http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html.
#       Done parsing script at http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html in 1.36963796616
# -----------------
# ----Did not find scriptfile for http://www.imsdb.com/Movie%20Scripts/Batman%20Begins%20Script.html.
# http://www.imsdb.com/scripts/Collateral.html
# Found exception 'NoneType' object has no attribute 'find' in parsing.
# http://www.imsdb.com/scripts/Jackie-Brown.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Jackie-Brown.html.
#       Done parsing script at http://www.imsdb.com/scripts/Jackie-Brown.html in 1.55606985092
# -----------------
# http://www.imsdb.com/scripts/15-Minutes.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/15-Minutes.html.
#       Done parsing script at http://www.imsdb.com/scripts/15-Minutes.html in 1.10042500496
# -----------------
# http://www.imsdb.com/scripts/2012.html
# Getting script @ http://www.imsdb.com/scripts/2012.html.
#       Done parsing script at http://www.imsdb.com/scripts/2012.html in 1.52414298058
# -----------------
# http://www.imsdb.com/scripts/30-Minutes-or-Less.html
# Getting script @ http://www.imsdb.com/scripts/30-Minutes-or-Less.html.
#       Done parsing script at http://www.imsdb.com/scripts/30-Minutes-or-Less.html in 1.31766200066
# -----------------
# http://www.imsdb.com/scripts/48-Hrs..html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/48-Hrs..html.
# Found exception list index out of range in parsing.
# http://www.imsdb.com/scripts/A-Most-Violent-Year.html
# Getting script @ http://www.imsdb.com/scripts/A-Most-Violent-Year.html.
#       Done parsing script at http://www.imsdb.com/scripts/A-Most-Violent-Year.html in 1.29370999336
# -----------------
# http://www.imsdb.com/scripts/Above-the-Law.html
# Getting script @ http://www.imsdb.com/scripts/Above-the-Law.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Above-the-Law.html in 1.26719689369
# -----------------
# http://www.imsdb.com/scripts/Abyss,-The.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Abyss,-The.html.
#       Done parsing script at http://www.imsdb.com/scripts/Abyss,-The.html in 1.22053217888
# -----------------
# http://www.imsdb.com/scripts/Air-Force-One.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Air-Force-One.html.
#       Done parsing script at http://www.imsdb.com/scripts/Air-Force-One.html in 1.27996397018
# -----------------
# http://www.imsdb.com/scripts/Alien.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Alien.html.
#       Done parsing script at http://www.imsdb.com/scripts/Alien.html in 1.09104084969
# -----------------
# http://www.imsdb.com/scripts/Alien-3.html
# Getting script @ http://www.imsdb.com/scripts/Alien-3.html.
#       Done parsing script at http://www.imsdb.com/scripts/Alien-3.html in 1.11914587021
# -----------------
# http://www.imsdb.com/scripts/Alien-vs.-Predator.html
# Getting script @ http://www.imsdb.com/scripts/Alien-vs.-Predator.html.
# Found exception list index out of range in parsing.
# http://www.imsdb.com/scripts/Alien-Resurrection.html
# Getting script @ http://www.imsdb.com/scripts/Alien-Resurrection.html.
# Found exception list index out of range in parsing.
# http://www.imsdb.com/scripts/Aliens.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Aliens.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/
html.
#       Done parsing script at http://www.imsdb.com/scripts/Mighty-Morphin-Power-Rangers-The-Movie.html in 1.09024310112
# -----------------
# http://www.imsdb.com/scripts/Minority-Report.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Minority-Report.html.
#       Done parsing script at http://www.imsdb.com/scripts/Minority-Report.html in 1.26960301399
# -----------------
# http://www.imsdb.com/scripts/Mission-Impossible.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Mission-Impossible.html.
#       Done parsing script at http://www.imsdb.com/scripts/Mission-Impossible.html in 1.1992521286
# -----------------
# http://www.imsdb.com/scripts/Mission-Impossible-II.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Mission-Impossible-II.html.
#       Done parsing script at http://www.imsdb.com/scripts/Mission-Impossible-II.html in 1.26192092896
# -----------------
# http://www.imsdb.com/scripts/Mummy,-The.html
# Getting script @ http://www.imsdb.com/scripts/Mummy,-The.html.
#       Done parsing script at http://www.imsdb.com/scripts/Mummy,-The.html in 1.36390781403
# -----------------
# http://www.imsdb.com/scripts/Mystery-Men.html
# Found a <pre> inside the <pre>
# ...
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Resident-Evil.html.
#       Done parsing script at http://www.imsdb.com/scripts/Resident-Evil.html in 1.10658502579
# -----------------
# http://www.imsdb.com/scripts/Return-of-the-Apes.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Return-of-the-Apes.html.
# Found exception list index out of range in parsing.
# http://www.imsdb.com/scripts/Rise-of-the-Planet-of-the-Apes.html
# Getting script @ http://www.imsdb.com/scripts/Rise-of-the-Planet-of-the-Apes.html.
#       Done parsing script at http://www.imsdb.com/scripts/Rise-of-the-Planet-of-the-Apes.html in 1.24446415901
# -----------------
# http://www.imsdb.com/scripts/Robin-Hood-Prince-of-Thieves.html
# Getting script @ http://www.imsdb.com/scripts/Robin-Hood-Prince-of-Thieves.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Robin-Hood-Prince-of-Thieves.html in 1.36083388329
# -----------------
# http://www.imsdb.com/scripts/Robocop.pdf
# The file @ http://www.imsdb.com/scripts/Robocop.pdf is a PDF
# http://www.imsdb.com/scripts/Rock,-The.html
# Getting script @ http://www.imsdb.com/scripts/Rock,-The.html.
#       Done parsing script at http://www.imsdb.com/scripts/Rock,-The.html in 1.1033911705
# -----------------
# http://www.imsdb.com/scripts/RocknRolla.html
# Getting script @ http://www.imsdb.com/scripts/RocknRolla.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/RocknRolla.html in 1.50376987457
# -----------------
# http://www.imsdb.com/scripts/Ronin.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Ronin.html.
#       Done parsing script at http://www.imsdb.com/scripts/Ronin.html in 1.27782893181
# -----------------
# http://www.imsdb.com/scripts/Rush.html
# Getting script @ http://www.imsdb.com/scripts/Rush.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Rush.html in 1.31120705605
# -----------------
# http://www.imsdb.com/scripts/Rush-Hour.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Rush-Hour.html.
#       Done parsing script at http://www.imsdb.com/scripts/Rush-Hour.html in 1.14198994637
# -----------------
# http://www.imsdb.com/scripts/Rush-Hour-2.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Rush-Hour-2.html.
#       Done parsing script at http://www.imsdb.com/scripts/Rush-Hour-2.html in 1.11799502373
# -----------------
# http://www.imsdb.com/scripts/Saint,-The.html
# Getting script @ http://www.imsdb.com/scripts/Saint,-The.html.
# Found exception list index out of range in parsing.
# http://www.imsdb.com/scripts/Saving-Private-Ryan.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Saving-Private-Ryan.html.
#       Done parsing script at http://www.imsdb.com/scripts/Saving-Private-Ryan.html in 1.23062205315
# -----------------
# http://www.imsdb.com/scripts/Scarface.html
# Getting script @ http://www.imsdb.com/scripts/Scarface.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Scarface.html in 1.69006299973
# -----------------
# http://www.imsdb.com/scripts/Scott-Pilgrim-vs-the-World.html
# Getting script @ http://www.imsdb.com/scripts/Scott-Pilgrim-vs-the-World.html.
#       Done parsing script at http://www.imsdb.com/scripts/Scott-Pilgrim-vs-the-World.html in 1.57042002678
# -----------------
# http://www.imsdb.com/scripts/Serenity.html
# Getting script @ http://www.imsdb.com/scripts/Serenity.html.
#       Done parsing script at http://www.imsdb.com/scripts/Serenity.html in 1.31499290466
# -----------------
# http://www.imsdb.com/scripts/Sherlock-Holmes.html
# Getting script @ http://www.imsdb.com/scripts/Sherlock-Holmes.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/
html
# Found exception 'NoneType' object has no attribute 'find' in parsing.
# http://www.imsdb.com/scripts/Star-Wars-The-Empire-Strikes-Back.html
# Getting script @ http://www.imsdb.com/scripts/Star-Wars-The-Empire-Strikes-Back.html.
#       Done parsing script at http://www.imsdb.com/scripts/Star-Wars-The-Empire-Strikes-Back.html in 1.12855291367
# -----------------
# http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html
# Getting script @ http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html.
#       Done parsing script at http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html in 1.42435503006
# -----------------
# http://www.imsdb.com/scripts/Star-Wars-The-Phantom-Menace.html
# Getting script @ http://www.imsdb.com/scripts/Star-Wars-The-Phantom-Menace.html.
# Found exception list index out of range in parsing.
# http://www.imsdb.com/scripts/Starship-Troopers.html
# Getting script @ http://www.imsdb.com/scripts/Starship-Troopers.html.
#       Done parsing script at http://www.imsdb.com/scripts/Starship-Troopers.html in 1.22877502441
# -----------------
# http://www.imsdb.com/scripts/Strange-Days.html
# Getting script @ http://www.imsdb.com/scripts/Strange-Days.html.
#       Done parsing script at http://www.imsdb.com/scripts/Strange-Days.html in 1.43482279778
# -----------------
# http://www.imsdb.com/scripts/Stuntman,-The.html
# Getting script @ http://www.imsdb.com/scripts/Stuntman,-The.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Stuntman,-The.html in 1.54395508766
# -----------------
# http://www.imsdb.com/scripts/Superfights.pdf
# The file @ http://www.imsdb.com/scripts/Superfights.pdf is a PDF
# http://www.imsdb.com/scripts/Supergirl.html
# Getting script @ http://www.imsdb.com/scripts/Supergirl.html.
#       Done parsing script at http://www.imsdb.com/scripts/Supergirl.html in 1.08499002457
# -----------------
# http://www.imsdb.com/scripts/Surrogates.html
# Getting script @ http://www.imsdb.com/scripts/Surrogates.html.
#       Done parsing script at http://www.imsdb.com/scripts/Surrogates.html in 1.49548792839
# -----------------
# http://www.imsdb.com/scripts/Swordfish.html
# Getting script @ http://www.imsdb.com/scripts/Swordfish.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Swordfish.html in 1.22954893112
# -----------------
# http://www.imsdb.com/scripts/Terminator.html
# Getting script @ http://www.imsdb.com/scripts/Terminator.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Terminator.html in 1.25773191452
# -----------------
# http://www.imsdb.com/scripts/Terminator-2-Judgement-Day.html
# Getting script @ http://www.imsdb.com/scripts/Terminator-2-Judgement-Day.html.
#       Done parsing script at http://www.imsdb.com/scripts/Terminator-2-Judgement-Day.html in 1.2840821743
# -----------------
# http://www.imsdb.com/scripts/Terminator-Salvation.html
# Getting script @ http://www.imsdb.com/scripts/Terminator-Salvation.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Terminator-Salvation.html in 1.34378504753
# -----------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-7f533c0fd0b3> in <module>()
#      32
#      33
# ---> 34 a=scripts_by_genre('action','../data/all_script/action/')
#
# <ipython-input-13-7f533c0fd0b3> in scripts_by_genre(genre, path_destination)
#      15             url_film=url_film.replace(' ','%20')
#      16             script = urllib2.Request(url_film)
# ---> 17             page_ = urllib2.urlopen(script).read()
#      18             soup_ = BeautifulSoup(page_,"html.parser")
#      19             a_ = soup_.findAll('a', href=re.compile('^/scripts/'))
#
# /home/duc-vinh/anaconda2/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /home/duc-vinh/anaconda2/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# /home/duc-vinh/anaconda2/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     445         protocol = req.get_type()
#     446         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 447                                   '_open', req)
#     448         if result:
#     449             return result
#
# /home/duc-vinh/anaconda2/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# /home/duc-vinh/anaconda2/lib/python2.7/urllib2.pyc in http_open(self, req)
#    1226
#    1227     def http_open(self, req):
# -> 1228         return self.do_open(httplib.HTTPConnection, req)
#    1229
#    1230     http_request = AbstractHTTPHandler.do_request_
#
# /home/duc-vinh/anaconda2/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1193
#    1194         try:
# -> 1195             h.request(req.get_method(), req.get_selector(), req.data, headers)
#    1196         except socket.error, err: # XXX what error?
#    1197             h.close()
#
# /home/duc-vinh/anaconda2/lib/python2.7/httplib.pyc in request(self, method, url, body, headers)
#    1040     def request(self, method, url, body=None, headers={}):
#    1041         """Send a complete request to the server."""
# -> 1042         self._send_request(method, url, body, headers)
#    1043
#    1044     def _set_content_length(self, body, method):
#
# /home/duc-vinh/anaconda2/lib/python2.7/httplib.pyc in _send_request(self, method, url, body, headers)
#    1080         for hdr, value in headers.iteritems():
#    1081             self.putheader(hdr, value)
# -> 1082         self.endheaders(body)
#    1083
#    1084     def getresponse(self, buffering=False):
#
# /home/duc-vinh/anaconda2/lib/python2.7/httplib.pyc in endheaders(self, message_body)
#    1036         else:
#    1037             raise CannotSendHeader()
# -> 1038         self._send_output(message_body)
#    1039
#    1040     def request(self, method, url, body=None, headers={}):
#
# /home/duc-vinh/anaconda2/lib/python2.7/httplib.pyc in _send_output(self, message_body)
#     880             msg += message_body
#     881             message_body = None
# --> 882         self.send(msg)
#     883         if message_body is not None:
#     884             #message_body was not a string (i.e. it is a file) and
#
# /home/duc-vinh/anaconda2/lib/python2.7/httplib.pyc in send(self, data)
#     842         if self.sock is None:
#     843             if self.auto_open:
# --> 844                 self.connect()
#     845             else:
#     846                 raise NotConnected()
#
# /home/duc-vinh/anaconda2/lib/python2.7/httplib.pyc in connect(self)
#     819         """Connect to the host and port specified in __init__."""
#     820         self.sock = self._create_connection((self.host,self.port),
# --> 821                                            self.timeout, self.source_address)
#     822
#     823         if self._tunnel_host:
#
# /home/duc-vinh/anaconda2/lib/python2.7/socket.pyc in create_connection(address, timeout, source_address)
#     564             if source_address:
#     565                 sock.bind(source_address)
# --> 566             sock.connect(sa)
#     567             return sock
#     568
#
# /home/duc-vinh/anaconda2/lib/python2.7/socket.pyc in meth(name, self, *args)
#     226
#     227 def meth(name,self,*args):
# --> 228     return getattr(self._sock,name)(*args)
#     229
#     230 for _m in _socketmethods:
#
# KeyboardInterrupt:

# %%
genre_url='http://www.imsdb.com/genre/Romance'
scripts_by_genre('romance','../data/all_script/romance/')
# Out:
# http://www.imsdb.com/scripts/Star-Wars-Revenge-of-the-Sith.html
# Found exception 'NoneType' object has no attribute 'find' in parsing.
# http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html
# Getting script @ http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html.
#       Done parsing script at http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html in 1.26432299614
# -----------------
# ----Did not find scriptfile for http://www.imsdb.com/Movie%20Scripts/Batman%20Begins%20Script.html.
# http://www.imsdb.com/scripts/Collateral.html
# Found exception 'NoneType' object has no attribute 'find' in parsing.
# http://www.imsdb.com/scripts/Jackie-Brown.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Jackie-Brown.html.
#       Done parsing script at http://www.imsdb.com/scripts/Jackie-Brown.html in 1.42752885818
# -----------------
# http://www.imsdb.com/scripts/10-Things-I-Hate-About-You.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/10-Things-I-Hate-About-You.html.
#       Done parsing script at http://www.imsdb.com/scripts/10-Things-I-Hate-About-You.html in 1.57005810738
# -----------------
# http://www.imsdb.com/scripts/17-Again.html
# Getting script @ http://www.imsdb.com/scripts/17-Again.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/17-Again.html in 1.33731579781
# -----------------
# http://www.imsdb.com/scripts/500-Days-of-Summer.html
# Getting script @ http://www.imsdb.com/scripts/500-Days-of-Summer.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/500-Days-of-Summer.html in 1.3840200901
# -----------------
# http://www.imsdb.com/scripts/Adjustment-Bureau,-The.html
# Getting script @ http://www.imsdb.com/scripts/Adjustment-Bureau,-The.html.
#       Done parsing script at http://www.imsdb.com/scripts/Adjustment-Bureau,-The.html in 1.30600690842
# -----------------
# http://www.imsdb.com/scripts/Adventures-of-Buckaroo-Banzai-Across-the-Eighth-Dimension,-The.html
# Getting script @ http://www.imsdb.com/scripts/Adventures-of-Buckaroo-Banzai-Across-the-Eighth-Dimension,-The.html.
# Found exception list index out of range in parsing.
# http://www.imsdb.com/scripts/
html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Natural-Born-Killers.html.
#       Done parsing script at http://www.imsdb.com/scripts/Natural-Born-Killers.html in 1.2069849968
# -----------------
# http://www.imsdb.com/scripts/Never-Been-Kissed.html
# Getting script @ http://www.imsdb.com/scripts/Never-Been-Kissed.html.
# Found exception list index out of range in parsing.
# http://www.imsdb.com/scripts/Next-Three-Days,-The.html
# Getting script @ http://www.imsdb.com/scripts/Next-Three-Days,-The.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Next-Three-Days,-The.html in 1.23516798019
# -----------------
# http://www.imsdb.com/scripts/Nine.html
# Getting script @ http://www.imsdb.com/scripts/Nine.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Nine.html in 1.08862185478
# -----------------
# http://www.imsdb.com/scripts/Ninotchka.html
# Getting script @ http://www.imsdb.com/scripts/Ninotchka.html.
#       Done parsing script at http://www.imsdb.com/scripts/Ninotchka.html in 1.27887296677
# -----------------
# http://www.imsdb.com/scripts/No-Strings-Attached.html
# Getting script @ http://www.imsdb.com/scripts/No-Strings-Attached.html.
#       Done parsing script at http://www.imsdb.com/scripts/No-Strings-Attached.html in 1.28842306137
# -----------------
# http://www.imsdb.com/scripts/Notting-Hill.html
# Getting script @ http://www.imsdb.com/scripts/Notting-Hill.html.
#       Done parsing script at http://www.imsdb.com/scripts/Notting-Hill.html in 1.07924699783
# -----------------
# http://www.imsdb.com/scripts/Officer-and-a-Gentleman,-An.pdf
# The file @ http://www.imsdb.com/scripts/Officer-and-a-Gentleman,-An.pdf is a PDF
# http://www.imsdb.com/scripts/Other-Boleyn-Girl,-The.html
# Getting script @ http://www.imsdb.com/scripts/Other-Boleyn-Girl,-The.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Other-Boleyn-Girl,-The.html in 1.3567199707
# -----------------
# http://www.imsdb.com/scripts/Out-of-Sight.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Out-of-Sight.html.
#       Done parsing script at http://www.imsdb.com/scripts/Out-of-Sight.html in 1.29693293571
# -----------------
# http://www.imsdb.com/scripts/Pearl-Harbor.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Pearl-Harbor.html.
# Found exception list index out of range in parsing.
# http://www.imsdb.com/scripts/Perks-of-Being-a-Wallflower,-The.html
# Getting script @ http://www.imsdb.com/scripts/Perks-of-Being-a-Wallflower,-The.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Perks-of-Being-a-Wallflower,-The.html in 1.26462817192
# -----------------
# http://www.imsdb.com/scripts/Piano,-The.html
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Piano,-The.html.
#       Done parsing script at http://www.imsdb.com/scripts/Piano,-The.html in 1.04554104805
# -----------------
# http://www.imsdb.com/scripts/Platinum-Blonde.html
# Getting script @ http://www.imsdb.com/scripts/Platinum-Blonde.html.
#       Done parsing script at http://www.imsdb.com/scripts/Platinum-Blonde.html in 1.68555498123
# -----------------
# http://www.imsdb.com/scripts/Pretty-Woman.html
# Catched an unrecognized error
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-8937c95d4cc5> in <module>()
#       1 genre_url='http://www.imsdb.com/genre/Romance'
# ----> 2 scripts_by_genre('romance','../data/all_script/romance/')
#
# /home/duc-vinh/Git_Repository/Data_Science/ENSAE/Dataviz/moViz/notebooks/crawler.py in scripts_by_genre(genre, path_destination)
#     137                 print(url)
#     138                 try:
# --> 139                     parse(url,path_destination,name)
#     140                 except Exception as e:
#     141                     print('Found exception %s in parsing.' %(e))
#
# /home/duc-vinh/Git_Repository/Data_Science/ENSAE/Dataviz/moViz/notebooks/parse_script.pyc in parse(url, path, name)
#     178         return
#     179
# --> 180     script_text,soup=get_script(url)
#     181     space_vector,character_presence = white_space_analysis(script_text,soup)
#     182     usual_spaces,flag=identify_usual_spaces(space_vector,character_presence)
#
# /home/duc-vinh/Git_Repository/Data_Science/ENSAE/Dataviz/moViz/notebooks/parse_script.pyc in get_script(url)
#      24         try:
#      25             request = urllib2.Request(script_url, headers=request_headers)
# ---> 26             contents = urllib2.urlopen(request)#.read()
#      27             soup = BeautifulSoup(contents, 'lxml')
#      28             #print('Detected encoding is ', soup.original_encoding)
#
# /home/duc-vinh/anaconda2/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /home/duc-vinh/anaconda2/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# /home/duc-vinh/anaconda2/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     445         protocol = req.get_type()
#     446         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 447                                   '_open', req)
#     448         if result:
#     449             return result
#
# /home/duc-vinh/anaconda2/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# /home/duc-vinh/anaconda2/lib/python2.7/urllib2.pyc in http_open(self, req)
#    1226
#    1227     def http_open(self, req):
# -> 1228         return self.do_open(httplib.HTTPConnection, req)
#    1229
#    1230     http_request = AbstractHTTPHandler.do_request_
#
# /home/duc-vinh/anaconda2/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1199         else:
#    1200             try:
# -> 1201                 r = h.getresponse(buffering=True)
#    1202             except TypeError: # buffering kw not supported
#    1203                 r = h.getresponse()
#
# /home/duc-vinh/anaconda2/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1119
#    1120         try:
# -> 1121             response.begin()
#    1122             assert response.will_close != _UNKNOWN
#    1123             self.__state = _CS_IDLE
#
# /home/duc-vinh/anaconda2/lib/python2.7/httplib.pyc in begin(self)
#     436         # read until we get a non-100 response
#     437         while True:
# --> 438             version, status, reason = self._read_status()
#     439             if status != CONTINUE:
#     440                 break
#
# /home/duc-vinh/anaconda2/lib/python2.7/httplib.pyc in _read_status(self)
#     392     def _read_status(self):
#     393         # Initialize with Simple-Response defaults
# --> 394         line = self.fp.readline(_MAXLINE + 1)
#     395         if len(line) > _MAXLINE:
#     396             raise LineTooLong("header line")
#
# /home/duc-vinh/anaconda2/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:

# %% [markdown]
# - ### Extract functions

# %%
path='../data/top100 per year/curated/'
col=['classement','titre','annee','annee_','categorie','realisateur','url','url_script']
titles=pd.DataFrame(columns=col)
for year in range(2000,2017):
    df=get_curated(year,path)
    df['annee_']=year
    titles = pd.concat([titles,df])

# %%
#retraiter la colonne catégorie
titles.reset_index(inplace=True,drop=True)
titles['categorie']=titles['categorie'].apply(lambda x : x.replace('\n','').replace(' ',''))
titles['categorie1'], titles['categorie2'], titles['categorie3']= titles['categorie'].str.split(',', 2).str

# %%
#consolider le dataframe pour les liens qui ont un lien script
titles = titles.dropna(subset=['url_script'],how='any')
titles.reset_index(inplace=True,drop=True)
titles
# Out:
#           annee  annee_                   categorie  classement    durée  \
# 0        (2000)  2000.0     Adventure,Drama,Romance         2.0  143 min
# 1        (2000)  2000.0      Action,Adventure,Drama         4.0  155 min
# 2        (2000)  2000.0     Action,Adventure,Sci-Fi         8.0  104 min
# 3        (2000)  2000.0        Drama,Fantasy,Horror        10.0  130 min
# 4        (2000)  2000.0    Action,Adventure,Fantasy        12.0  120 min
# 5        (2000)  2000.0             Biography,Drama        13.0  131 min
# 6        (2000)  2000.0     Action,Adventure,Comedy        14.0   98 min
# 7        (2000)  2000.0        Crime,Drama,Thriller        15.0  147 min
# 8        (2000)  2000.0        Drama,Mystery,Sci-Fi        23.0  106 min
# 9        (2000)  2000.0              Horror,Mystery        27.0  116 min
# 10       (2000)  2000.0        Action,Horror,Sci-Fi        31.0  112 min
# 11       (2000)  2000.0   Adventure,Sci-Fi,Thriller        41.0  114 min
# 12       (2000)  2000.0                      Comedy        45.0   98 min
# 13       (2000)  2000.0         Crime,Drama,Mystery        55.0  118 min
# 14       (2000)  2000.0              Comedy,Fantasy        58.0   90 min
# 15       (2000)  2000.0               Horror,Sci-Fi        59.0  109 min
# 259  http://www.imsdb.com/Movie Scripts/Point Break...
# 260  http://www.imsdb.com/Movie Scripts/La La Land ...
# 261  http://www.imsdb.com/Movie Scripts/Ghostbuster...
#
#                                             url_script categorie1 categorie2  \
# 0          http://www.imsdb.com/scripts/Cast-Away.html  Adventure      Drama
# 1          http://www.imsdb.com/scripts/Gladiator.html     Action  Adventure
# 2              http://www.imsdb.com/scripts/X-Men.html     Action  Adventure
# 3    http://www.imsdb.com/scripts/What-Lies-Beneath...      Drama    Fantasy
# 4    http://www.imsdb.com/scripts/Crouching-Tiger,-...     Action  Adventure
# 5    http://www.imsdb.com/scripts/Erin-Brockovich.html  Biography      Drama
# 6    http://www.imsdb.com/scripts/Charlie's-Angels....     Action  Adventure
# 7            http://www.imsdb.com/scripts/Traffic.html      Crime      Drama
# 8        http://www.imsdb.com/scripts/Unbreakable.html      Drama    Mystery
# 9           http://www.imsdb.com/scripts/Scream-3.html     Horror    Mystery
# 10        http://www.imsdb.com/scripts/Hollow-Man.html     Action     Horror
# 11   http://www.imsdb.com/scripts/Mission-to-Mars.html  Adventure     Sci-Fi
# 12       http://www.imsdb.com/scripts/Next-Friday.html     Comedy        NaN
# 13         http://www.imsdb.com/scripts/Frequency.html      Crime      Drama
# 14      http://www.imsdb.com/scripts/Little-Nicky.html     Comedy    Fantasy
# 15       http://www.imsdb.com/scripts/Pitch-Black.html     Horror     Sci-Fi
# 16   http://www.imsdb.com/scripts/Autumn-in-New-Yor...      Drama    Romance
# 17     http://www.imsdb.com/scripts/Thirteen-Days.html      Drama    History
# 18     http://www.imsdb.com/scripts/Almost-Famous.html  Adventure     Comedy
# 19            http://www.imsdb.com/scripts/Snatch.html     Comedy      Crime
# 20     http://www.imsdb.com/scripts/High-Fidelity.html     Comedy      Drama
# 21           http://www.imsdb.com/scripts/Memento.html    Mystery   Thriller
# 22       http://www.imsdb.com/scripts/Nurse-Betty.html     Comedy      Crime
# 23    http://www.imsdb.com/scripts/Reindeer-Games.html     Action  Adventure
# 24       http://www.imsdb.com/scripts/Wonder-Boys.html     Comedy      Drama
# 25        http://www.imsdb.com/scripts/Red-Planet.html     Action     Sci-Fi
# 26             http://www.imsdb.com/scripts/Shrek.html  Animation  Adventure
# 27       http://www.imsdb.com/scripts/Rush-Hour-2.html     Action     Comedy
# 28      http://www.imsdb.com/scripts/Pearl-Harbor.html     Action      Drama
# 29    http://www.imsdb.com/scripts/Ocean's-Eleven.html      Crime   Thriller
# ..                                                 ...        ...        ...
# 232           http://www.imsdb.com/scripts/Looper.html     Action      Crime
# 233        http://www.imsdb.com/scripts/Chronicle.html     Sci-Fi   Thriller
# 234     http://www.imsdb.com/scripts/Total-Recall.html     Action  Adventure
# 235       http://www.imsdb.com/scripts/ParaNorman.html  Animation  Adventure
# 236  http://www.imsdb.com/scripts/Moonrise-Kingdom....  Adventure     Comedy
# 237    http://www.imsdb.com/scripts/Frankenweenie.html  Animation     Comedy
# 238              http://www.imsdb.com/scripts/Mud.html      Drama        NaN
# 239           http://www.imsdb.com/scripts/Frozen.html  Animation  Adventure
# 240  http://www.imsdb.com/scripts/Despicable-Me-2.html  Animation  Adventure
# 241          http://www.imsdb.com/scripts/Gravity.html  Adventure      Drama
# 242  http://www.imsdb.com/scripts/American-Hustle.html      Crime      Drama
# 243               http://www.imsdb.com/scripts/42.html  Biography      Drama
# 244         http://www.imsdb.com/scripts/Oblivion.html     Action  Adventure
# 245  http://www.imsdb.com/scripts/Saving-Mr.-Banks....  Biography     Comedy
# 246  http://www.imsdb.com/scripts/12-Years-a-Slave....  Biography      Drama
# 247        http://www.imsdb.com/scripts/Evil-Dead.html    Fantasy     Horror
# 248  http://www.imsdb.com/scripts/August-Osage-Coun...      Drama        NaN
# 249           http://www.imsdb.com/scripts/Carrie.html      Drama     Horror
# 250  http://www.imsdb.com/scripts/Dallas-Buyers-Clu...  Biography      Drama
# 251             http://www.imsdb.com/scripts/Rush.html     Action  Biography
# 252              http://www.imsdb.com/scripts/Her.html      Drama    Romance
# 253  http://www.imsdb.com/scripts/American-Sniper.html     Action  Biography
# 254         http://www.imsdb.com/scripts/Godzilla.html     Action  Adventure
# 255     http://www.imsdb.com/scripts/Interstellar.html  Adventure      Drama
# 256  http://www.imsdb.com/scripts/How-to-Train-Your...  Animation     Action
# 257  http://www.imsdb.com/scripts/Star-Wars-The-For...     Action  Adventure
# 258   http://www.imsdb.com/scripts/Fantastic-Four.html     Action  Adventure
# 259      http://www.imsdb.com/scripts/Point-Break.html     Action      Crime
# 260       http://www.imsdb.com/scripts/La-La-Land.html     Comedy      Drama
# 261     http://www.imsdb.com/scripts/Ghostbusters.html     Action     Comedy
#
#     categorie3
# 0      Romance
# 1        Drama
# 2       Sci-Fi
# 3       Horror
# 4      Fantasy
# 5          NaN
# 6       Comedy
# 7     Thriller
# 8       Sci-Fi
# 9          NaN
# 10      Sci-Fi
# 11    Thriller
# 12         NaN
# 13     Mystery
# 14         NaN
# 15         NaN
# 16         NaN
# 17    Thriller
# 18       Drama
# 19         NaN
# 20       Music
# 21         NaN
# 22       Drama
# 23       Crime
# 24         NaN
# 25    Thriller
# 26      Comedy
# 27       Crime
# 28     History
# 29         NaN
# ..         ...
# 232      Drama
# 233        NaN
# 234    Mystery
# 235     Comedy
# 236      Drama
# 237     Family
# 238        NaN
# 239     Comedy
# 240     Comedy
# 241     Sci-Fi
# 242        NaN
# 243      Sport
# 244    Mystery
# 245      Drama
# 246    History
# 247   Thriller
# 248        NaN
# 249        NaN
# 250        NaN
# 251      Drama
# 252     Sci-Fi
# 253      Drama
# 254     Sci-Fi
# 255     Sci-Fi
# 256  Adventure
# 257    Fantasy
# 258     Sci-Fi
# 259      Sport
# 260      Music
# 261    Fantasy
#
# [262 rows x 12 columns]

# %%
#les différentes catégories:
l=list(titles.categorie1)+list(titles.categorie2)+list(titles.categorie3)
set(l)
# Out:
# {nan,
#  u'Action',
#  u'Adventure',
#  u'Animation',
#  u'Biography',
#  u'Comedy',
#  u'Crime',
#  u'Drama',
#  u'Family',
#  u'Fantasy',
#  u'History',
#  u'Horror',
#  u'Music',
#  u'Musical',
#  u'Mystery',
#  u'Romance',
#  u'Sci-Fi',
#  u'Sport',
#  u'Thriller',
#  u'War',
#  u'Western'}

# %% [markdown]
# - ### Analysis Functions

# %%
def clean_character(char):
    if isinstance(char,unicode) or isinstance(char,str):
        char=char.replace('\n','').replace('*','').replace('O/S','').replace('V.O.','')
        char=re.sub(' +',' ',char)
        if 'CONTINUED' in char:
            return u'CONTINUED'
        if '(' in char or ')' in char:
            regex = re.compile(".*?\((.*?)\)")
            to_delete = re.findall(regex, char)
            for e in to_delete:
                char=char.replace('(%s)' %e,'')
            if char=='' or ')'in char:
                return None
            else:
                return char.rstrip() #delete lose end white space
        else:
            return char.rstrip()
    else:
        return None
    
def continued_speech(char_vector):
    char_vector=list(char_vector)
    while 'CONTINUED' in char_vector:
        count=0
        idx=char_vector.index("CONTINUED")
        for element in char_vector[idx-1::-1]:
            #if (isinstance(element,str) or isinstance(element,unicode)) and (element!='unknown'):
            if element and element!='unknown':
                char_vector[idx]=char_vector[idx-1-count]
                #print('Replaces CONTINUED with %s' %(char_vector[idx-1-count]))
                break
            count=count+1
            if count==len(char_vector[idx-1::-1]):
                char_vector[idx]='unknown'
                break
    return char_vector


# to remove outliers
def principal_characters(char_dic):
    mean = 0
    for i, j in char_dic.items():
        mean = mean + j
    mean = mean / len(char_dic)

    stddev = 0
    for i, j in char_dic.items():
        stddev = stddev + (j - mean)*(j - mean)
    stddev = stddev / len(char_dic)
    stddev = math.sqrt(stddev)

    temp = {}
    for i, j in char_dic.items():
        if (math.fabs(j - mean) < 3*stddev):
            temp[i] = j
    print(stddev,mean)
    return temp


def char_analysis(df):
    d=dict(Counter(df['character_clean']))
    d={key: value for key, value in d.items() 
                 if key}
    charlist = sorted(d)
    gender = dict()
    lines=[element.split('\n') for element in df['text']]
    lines=[item for sublist in lines for item in sublist]

    for char in charlist:
        m, f, p = 0, 0, 0 
        for i in range(len(lines)):
            srch = re.search(char, lines[i], re.I)
            if not srch:
                continue
            if srch.group().isupper():
                continue
            else:
                k, k_range = -1, 2
                while k + i + 1 < len(lines):
                    k = k + 1
                    m = m + len(re.findall("\s+he", lines[k+i], re.I)) + len(re.findall("\s+him", lines[k+i], re.I))
                    f = f + len(re.findall("\s+she", lines[k+i], re.I)) + len(re.findall("\s+her", lines[k+i], re.I))
                    if lines[k+i].isupper():
                        break
                    if k >= k_range:
                        break
                k, k_range = -1, 4
                while k + i + 1 < len(lines):
                    k = k + 1
                    m1, m2, m3, m4 = re.search("\s+he", lines[k+i], re.I), re.search("\s+him", lines[k+i], re.I),\
                                    re.search("\s+she", lines[k+i], re.I), re.search("\s+her", lines[k+i], re.I)
                    if m1:
                        if m2:
                            mc = min(m1.span()[0], m2.span()[0])
                        else:
                            mc = m1.span()[0]
                    else:
                        mc = len(lines[k+i])
                    if m3:
                        if m4:
                            fc = min(m3.span()[0], m4.span()[0])
                        else:
                            fc = m3.span()[0]
                    else:
                        fc = len(lines[k+i])
                    if not(m1 or m2 or m3 or m4):
                        continue
                    else:
                        if (mc < fc):
                            p = p - 1
                        else:
                            p = p + 1
                        break
                    if lines[k+i].isupper():
                        break
                    if k >= k_range:
                        break
        gender[char] = m, f, p

    for char, g in gender.items():
        g_score = 2*g[1] - g[0] 
        g_sum = g[1]+g[0]
        g_score = g_score
        if (g_sum == 0.0) :#or (0 == 1):
            #print(char+" Undetermined ")
            gender[char] = "?" #0, 0, -1
        elif g_score > 0:
            #print(char+" Female "+str(g[0])+","+str(g[1])+","+str(g[2])+","+str(g_score))
            gender[char] = "F" #0, 0, 1
        else:
            #print(char+" Male", " ", str(g[0])+","+str(g[1])+","+str(g[2])+","+str(g_score))
            gender[char] = "M" #0, 0, 0
            
    return d,gender

# %% [markdown]
# - ### Script loader and parser

# %%
output_actions=read_all_files('../data/all_script/action/',sep='|')
output_romances=read_all_files('../data/all_script/romance/',sep='|')
# Out:
# Getting script @ http://www.imsdb.com/scripts/Gladiator.html.
#       Done parsing script at http://www.imsdb.com/scripts/Gladiator.html in 2.55342006683
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/X-Men.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/Crouching-Tiger,-Hidden-Dragon.html.
#       Done parsing script at http://www.imsdb.com/scripts/Crouching-Tiger,-Hidden-Dragon.html in 0.97320318222
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Charlie's-Angels.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Charlie's-Angels.html in 1.26062297821
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Hollow-Man.html.
#       Done parsing script at http://www.imsdb.com/scripts/Hollow-Man.html in 1.24292397499
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Reindeer-Games.html.
#       Done parsing script at http://www.imsdb.com/scripts/Reindeer-Games.html in 1.4341571331
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Red-Planet.html.
# list index out of range
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Rush-Hour-2.html.
#       Done parsing script at http://www.imsdb.com/scripts/Rush-Hour-2.html in 1.0705280304
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Pearl-Harbor.html.
# list index out of range
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Jurassic-Park-III.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/Swordfish.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Swordfish.html in 1.23918795586
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/15-Minutes.html.
#       Done parsing script at http://www.imsdb.com/scripts/15-Minutes.html in 1.17329001427
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Spider-Man.html.
#       Done parsing script at http://www.imsdb.com/scripts/Spider-Man.html in 1.11400699615
# -----------------
# Getting script @ http://www.imsdb.com/scripts/xXx.html.
#       Done parsing script at http://www.imsdb.com/scripts/xXx.html in 1.25908184052
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Minority-Report.html.
#       Done parsing script at http://www.imsdb.com/scripts/Minority-Report.html in 1.38340306282
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Blade-II.html.
# list index out of range
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Star-Trek-Nemesis.html.
#       Done parsing script at http://www.imsdb.com/scripts/Star-Trek-Nemesis.html in 1.11233997345
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Collateral-Damage.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Collateral-Damage.html in 1.34862589836
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Resident-Evil.html.
#       Done parsing script at http://www.imsdb.com/scripts/Resident-Evil.html in 1.15258002281
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Freddy-vs.-Jason.html.
#       Done parsing script at http://www.imsdb.com/scripts/Freddy-vs.-Jason.html in 1.11570811272
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Cradle-2-the-Grave.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Cradle-2-the-Grave.html in 1.26495289803
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Basic.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Basic.html in 1.30297708511
# -----------------
# Getting script @ http://www.imsdb.com/scripts/I,-Robot.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/I,-Robot.html in 1.2289481163
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Hellboy.html.
#       Done parsing script at http://www.imsdb.com/scripts/Hellboy.html in 1.23401618004
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Dawn-of-the-Dead.html.
#       Done parsing script at http://www.imsdb.com/scripts/Dawn-of-the-Dead.html in 1.21371984482
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Blade-Trinity.html.
#       Done parsing script at http://www.imsdb.com/scripts/Blade-Trinity.html in 1.2397210598
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Walking-Tall.html.
#       Done parsing script at http://www.imsdb.com/scripts/Walking-Tall.html in 1.00809788704
# -----------------
# 'NoneType' object has no attribute 'find'
# Getting script @ http://www.imsdb.com/scripts/Cellular.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Cellular.html in 1.28008008003
# -----------------
# Getting script @ http://www.imsdb.com/scripts/King-Kong.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/King-Kong.html in 1.5043759346
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Fantastic-Four.html.
#       Done parsing script at http://www.imsdb.com/scripts/Fantastic-Four.html in 1.27812314034
# -----------------
# Getting script @ http://www.imsdb.com/scripts/V-for-Vendetta.html.
#       Done parsing script at http://www.imsdb.com/scripts/V-for-Vendetta.html in 1.49146008492
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Hostage.html.
#       Done parsing script at http://www.imsdb.com/scripts/Hostage.html in 1.19417405128
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Pirates-of-the-Caribbean-Dead-Man's-Chest.html.
#       Done parsing script at http://www.imsdb.com/scripts/Pirates-of-the-Caribbean-Dead-Man's-Chest.html in 1.28217101097
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Miami-Vice.html.
#       Done parsing script at http://www.imsdb.com/scripts/Miami-Vice.html in 1.21308493614
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Smokin'-Aces.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Smokin'-Aces.html in 1.50635194778
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Crank.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Crank.html in 1.51139807701
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Wild-Hogs.html.
#       Done parsing script at http://www.imsdb.com/scripts/Wild-Hogs.html in 1.28206396103
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Ghost-Rider.html.
#       Done parsing script at http://www.imsdb.com/scripts/Ghost-Rider.html in 1.28967285156
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Hancock.html.
#       Done parsing script at http://www.imsdb.com/scripts/Hancock.html in 1.25730204582
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Kung-Fu-Panda.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Kung-Fu-Panda.html in 1.24441123009
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Wanted.html.
#       Done parsing script at http://www.imsdb.com/scripts/Wanted.html in 1.30949020386
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Tropic-Thunder.html.
#       Done parsing script at http://www.imsdb.com/scripts/Tropic-Thunder.html in 1.2594909668
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Eagle-Eye.html.
#       Done parsing script at http://www.imsdb.com/scripts/Eagle-Eye.html in 1.29631996155
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Pineapple-Express.html.
#       Done parsing script at http://www.imsdb.com/scripts/Pineapple-Express.html in 1.41870498657
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Speed-Racer.html.
#       Done parsing script at http://www.imsdb.com/scripts/Speed-Racer.html in 1.35692715645
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Max-Payne.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Max-Payne.html in 1.50759601593
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Defiance.html.
#       Done parsing script at http://www.imsdb.com/scripts/Defiance.html in 1.35217499733
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Avatar.html.
#       Done parsing script at http://www.imsdb.com/scripts/Avatar.html in 1.46925902367
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Star-Trek.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Star-Trek.html in 1.44934391975
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Sherlock-Holmes.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Sherlock-Holmes.html in 1.29452800751
# -----------------
# Getting script @ http://www.imsdb.com/scripts/X-Men-Origins-Wolverine.html.
#       Done parsing script at http://www.imsdb.com/scripts/X-Men-Origins-Wolverine.html in 1.08679199219
# -----------------
# Getting script @ http://www.imsdb.com/scripts/2012.html.
#       Done parsing script at http://www.imsdb.com/scripts/2012.html in 1.45648288727
# -----------------
# Getting script @ http://www.imsdb.com/scripts/G.I.-Joe-The-Rise-of-Cobra.html.
#       Done parsing script at http://www.imsdb.com/scripts/G.I.-Joe-The-Rise-of-Cobra.html in 1.30138611794
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Terminator-Salvation.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Terminator-Salvation.html in 1.45075583458
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Watchmen.html.
#       Done parsing script at http://www.imsdb.com/scripts/Watchmen.html in 1.29288887978
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Surrogates.html.
#       Done parsing script at http://www.imsdb.com/scripts/Surrogates.html in 1.23707795143
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Ninja-Assassin.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Ninja-Assassin.html in 1.33331513405
# -----------------
# Getting script @ http://www.imsdb.com/scripts/9.html.
#       Done parsing script at http://www.imsdb.com/scripts/9.html in 1.4116859436
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Inception.html.
#       Done parsing script at http://www.imsdb.com/scripts/Inception.html in 1.35802984238
# -----------------
# Getting script @ http://www.imsdb.com/scripts/How-to-Train-Your-Dragon.html.
#       Done parsing script at http://www.imsdb.com/scripts/How-to-Train-Your-Dragon.html in 1.2077050209
# -----------------
# Getting script @ http://www.imsdb.com/scripts/TRON-Legacy.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/TRON-Legacy.html in 1.29081511497
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Clash-of-the-Titans.html.
#       Done parsing script at http://www.imsdb.com/scripts/Clash-of-the-Titans.html in 1.3150408268
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Megamind.html.
#       Done parsing script at http://www.imsdb.com/scripts/Megamind.html in 1.26988506317
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Legion.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Legion.html in 1.28036212921
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Machete.html.
#       Done parsing script at http://www.imsdb.com/scripts/Machete.html in 1.25797915459
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Thor.html.
#       Done parsing script at http://www.imsdb.com/scripts/Thor.html in 1.43452000618
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Rise-of-the-Planet-of-the-Apes.html.
#       Done parsing script at http://www.imsdb.com/scripts/Rise-of-the-Planet-of-the-Apes.html in 1.26021409035
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Cowboys-&-Aliens.html.
#       Done parsing script at http://www.imsdb.com/scripts/Cowboys-&-Aliens.html in 1.29738402367
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Unknown.html.
#       Done parsing script at http://www.imsdb.com/scripts/Unknown.html in 1.27294111252
# -----------------
# Getting script @ http://www.imsdb.com/scripts/I-Am-Number-Four.html.
#       Done parsing script at http://www.imsdb.com/scripts/I-Am-Number-Four.html in 1.22609114647
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Hanna.html.
#       Done parsing script at http://www.imsdb.com/scripts/Hanna.html in 1.26104688644
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Colombiana.html.
#       Done parsing script at http://www.imsdb.com/scripts/Colombiana.html in 1.4243710041
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Men-in-Black-3.html.
#       Done parsing script at http://www.imsdb.com/scripts/Men-in-Black-3.html in 1.21615600586
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Snow-White-and-the-Huntsman.html.
#       Done parsing script at http://www.imsdb.com/scripts/Snow-White-and-the-Huntsman.html in 1.29500699043
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Looper.html.
#       Done parsing script at http://www.imsdb.com/scripts/Looper.html in 1.26345586777
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Total-Recall.html.
#       Done parsing script at http://www.imsdb.com/scripts/Total-Recall.html in 1.18490314484
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Oblivion.html.
#       Done parsing script at http://www.imsdb.com/scripts/Oblivion.html in 1.26288509369
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Rush.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Rush.html in 1.2736620903
# -----------------
# Getting script @ http://www.imsdb.com/scripts/American-Sniper.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/American-Sniper.html in 1.24048686028
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Godzilla.html.
#       Done parsing script at http://www.imsdb.com/scripts/Godzilla.html in 1.29287600517
# -----------------
# Getting script @ http://www.imsdb.com/scripts/How-to-Train-Your-Dragon-2.html.
#       Done parsing script at http://www.imsdb.com/scripts/How-to-Train-Your-Dragon-2.html in 1.23330783844
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html.
#       Done parsing script at http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html in 1.31784105301
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Fantastic-Four.html.
#       Done parsing script at http://www.imsdb.com/scripts/Fantastic-Four.html in 1.27774810791
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Point-Break.html.
#       Done parsing script at http://www.imsdb.com/scripts/Point-Break.html in 1.23128914833
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Ghostbusters.html.
#       Done parsing script at http://www.imsdb.com/scripts/Ghostbusters.html in 0.812021017075
# -----------------
# CPU times: user 18.8 s, sys: 284 ms, total: 19.1 s
# Wall time: 1min 50s

# %%
#construct character info and add it to dataframe
output_actions_=[]
male_nb_speech=[]
female_nb_speech=[]
nb_of_errors=0
for df in output_actions:
    try:
        #print(df['text'][0].split('\n')[0])
        test=df['character'].apply(lambda x :clean_character(x))
        df['character_clean']=continued_speech(test)
        char,gender=char_analysis(df)
        output_actions_.append(char)
        #create gender column in dataframe:
        df['gender']=[gender.get(item,item)  for item in list(df['character_clean'])]
        male_nb_speech.append(len(df[df['gender']=='M']))
        female_nb_speech.append(len(df[df['gender']=='F']))
    except Exception as e:
        print('------Caught exception : %s' %e)
        nb_of_errors=nb_of_errors+1
# Out:
# ------Caught exception : unbalanced parenthesis
# ------Caught exception : 'character'
# ------Caught exception : unbalanced parenthesis
# ------Caught exception : unbalanced parenthesis
# ------Caught exception : 'character'
# ------Caught exception : unbalanced parenthesis
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : unbalanced parenthesis
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : unbalanced parenthesis
# ------Caught exception : unbalanced parenthesis
# ------Caught exception : unexpected end of regular expression
# ------Caught exception : unbalanced parenthesis
# ------Caught exception : 'character'
# ------Caught exception : unbalanced parenthesis
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : unbalanced parenthesis
# ------Caught exception : nothing to repeat
# ------Caught exception : unbalanced parenthesis
# ------Caught exception : unbalanced parenthesis

# %%
print('The number of errors is %s out of a total %s.' %(nb_of_errors,len(output_actions)))
# Out:
# The number of errors is 30 out of a total 174.

# %%
m=sum(male_nb_speech)
f=sum(female_nb_speech)

 
# Data to plot
labels = ["M","F"]
sizes = [m, f]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Repartition des repliques dans les films d'actions") 
plt.axis('equal')
plt.show()

# %%
i=1
male_nb_speech=len(output_actions[i][output_actions[i]['gender']=='M'])
female_nb_speech=len(output_actions[i][output_actions[i]['gender']=='F'])

 
# Data to plot
labels = ["M","F"]
sizes = [male_nb_speech, female_nb_speech]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Repartition des repliques dans %s' %output_actions[i]['text'][0].split('\n')[0]) 
plt.axis('equal')
plt.show()

# %%
i=10
male_nb_speech=len(output_actions[i][output_actions[i]['gender']=='M'])
female_nb_speech=len(output_actions[i][output_actions[i]['gender']=='F'])

 
# Data to plot
labels = ["M","F"]
sizes = [male_nb_speech, female_nb_speech]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Repartition des repliques dans %s' %output_actions[i]['text'][0].split('\n')[0]) 
plt.axis('equal')
plt.show()

# %%
#construct character info and add it to dataframe
output_romances_=[]
male_nb_speech=[]
female_nb_speech=[]
nb_of_errors=0
for df in output_romances:
    try:
        #print(df['text'][0].split('\n')[0])
        test=df['character'].apply(lambda x :clean_character(x))
        df['character_clean']=continued_speech(test)
        char,gender=char_analysis(df)
        output_romances_.append(char)
        #create gender column in dataframe:
        df['gender']=[gender.get(item,item)  for item in list(df['character_clean'])]
        male_nb_speech.append(len(df[df['gender']=='M']))
        female_nb_speech.append(len(df[df['gender']=='F']))
    except Exception as e:
        print('------Caught exception : %s' %e)
        nb_of_errors=nb_of_errors+1
# Out:
# ------Caught exception : 'character'
# ------Caught exception : unbalanced parenthesis
# ------Caught exception : unbalanced parenthesis
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : unbalanced parenthesis
# ------Caught exception : unexpected end of regular expression
# ------Caught exception : 'character'
# ------Caught exception : unbalanced parenthesis

# %%
print('The number of errors is %s out of a total %s.' %(nb_of_errors,len(output_romances)))
# Out:
# The number of errors is 13 out of a total 102.

# %%
m=sum(male_nb_speech)
f=sum(female_nb_speech)

 
# Data to plot
labels = ["M","F"]
sizes = [m, f]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Repartition des repliques dans les films romantiques") 
plt.axis('equal')
plt.show()

# %%
m=len(actions_url)
f=len(romances_url)

 
# Data to plot
labels = ["Actions","Romances"]
sizes = [m, f]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Ratio Actions-Romances parmis les top100") 
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-497338593929> in <module>()
# ----> 1 m=len(actions_url)
#       2 f=len(romances_url)
#       3
#       4
#       5 # Data to plot
#
# NameError: name 'actions_url' is not defined

# %%
def find(df,to_find):
    count=0
    for element in df['text']:
        if to_find in normalize_text(element):
            count+=1
    return count

def find_female_in(df,to_find):
    count_female=0
    count_total=0
    idx=0
    try:
        list_female=list(df[df['gender']=='F']['character_clean'].apply(lambda x : normalize_text(x)))
        list_female=list(set(list_female))
        #list_female.append('she').append('her')
    except Exception as e:
        try:
            
            for element in df['text']:
                if to_find in normalize_text(element):
                    count_total+=1
                    if 'she' in element or "her" in element:
                        count_female+=1
            return count_female,count_total
        except Exception as ex:
            print('Warning : %s.' %(ex))
            return 0,0
    list_female.append('she')
    list_female.append("her")
    for element in df['text']:
        if to_find in normalize_text(element):
            count_total+=1
            for indicator in list_female: #she or her
                if indicator in element:
                    count_female+=1
                    break
        idx+=1
    return count_female,count_total

def find_any(df,l):
    for element in df['text']:
        for room in l:
            if room in normalize_text(element):
                print("Found %s" %room)
    return

def normalize_text(text):
    text = text.lower()
    normal = unicodedata.normalize('NFKD', text).encode('ASCII', 'ignore')
    return normal

# %%
l=['KITCHEN','Kitchen','kitchen','bed','BED','BEDROOM','Bed','Bedroom','bedroom','BATH','bath','Bath','BATHROOM',
  'Bathroom','bathroom','toilet','TOILET','Toilet']
l_norm=['kitchen','bed','bedroom','bath','bathroom','toilet']

# %% [raw]
# for df in output_romances:
#     find_any(df,l_norm)

# %%
import random
kitchen_count_action=0
kitchen_count_romance=0
rand_idx = random.sample(range(0,len(output_actions)),  len(output_romances))
for df in [output_actions[i] for i in rand_idx]:
    try:
        kitchen_count_action += find(df,'kitchen')
    except Exception as e:
        print(e)
for df in output_romances:
    try:
        kitchen_count_romance += find(df,'kitchen')
    except Exception as e:
        print(e)
# Out:
# 'NoneType' object has no attribute '__getitem__'

# %%
# Data to plot
labels = ["in actions","in romance"]
sizes = [kitchen_count_action, kitchen_count_romance]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Repartition de la presence des cuisines dans les films actions-romances") 
plt.axis('equal')
plt.show()

print('Actions: %s de présence cuisines' %(kitchen_count_action))
print('Romances: %s  de présence cuisines' %(kitchen_count_romance))
# Out:
# Actions: 60 de présence cuisines
# Romances: 99  de présence cuisines

# %%
kitchen_count_action_f=0
kitchen_count_action =0
kitchen_count_romance_f=0
kitchen_count_romance = 0
for df in output_actions:
    kitchen_count_action_f += find_female_in(df,'kitchen')[0]
    kitchen_count_action += find_female_in(df,'kitchen')[1]
for df in output_romances:
    kitchen_count_romance_f += find_female_in(df,'kitchen')[0]
    kitchen_count_romance += find_female_in(df,'kitchen')[1]
# Out:
# Warning : 'NoneType' object has no attribute '__getitem__'.
# Warning : 'NoneType' object has no attribute '__getitem__'.

# %%
# Data to plot
labels = ["in actions","in romance"]
sizes = [kitchen_count_action_f, kitchen_count_romance_f]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Repartition de la presence des cuisines dans les films actions-romances") 
plt.axis('equal')
plt.show()

print('Actions: %s femmes & cuisines' %(kitchen_count_action_f))
print('Romances: %s femmes & cuisines' %(kitchen_count_romance_f))
# Out:
# Actions: 95 femmes & cuisines
# Romances: 37 femmes & cuisines

# %%
# Data to plot
labels = ["other","women"]
sizes = [kitchen_count_action - kitchen_count_action_f, kitchen_count_action_f]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Repartition H/F & cuisne dans les films d'actions") 
plt.axis('equal')
plt.show()

print(' %s femmes & cuisines' %(kitchen_count_action_f))
print('%s autres & cuisines' %(kitchen_count_action- kitchen_count_action_f))
# Out:
#  95 femmes & cuisines
# 228 autres & cuisines

# %%
# Data to plot
labels = ["other","women"]
sizes = [kitchen_count_romance - kitchen_count_romance_f, kitchen_count_romance_f]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Repartition H/F & cuisine dans les films d'actions") 
plt.axis('equal')
plt.show()

print('Actions: %s femmes & cuisines' %(kitchen_count_action_f))
print('Romances: %s femmes & cuisines' %(kitchen_count_romance_f))
# Out:
# Actions: 95 femmes & cuisines
# : 37 femmes & cuisines
