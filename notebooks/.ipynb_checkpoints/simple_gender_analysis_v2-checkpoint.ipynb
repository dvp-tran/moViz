# %% [markdown]
# # Simple gender analysis

# %% [markdown]
# - ## Imports

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import unicodedata

import os, sys, json, re, argparse, urllib2, html5lib
from bs4 import BeautifulSoup, Tag, UnicodeDammit
import pandas as pd
from pandas.io.json import json_normalize
import time
import math
from parse_script import *
from crawler import *
# Out:
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %% [markdown]
# - ## Crawl

# %% [raw]
# #crawl top100 per year
# path_ = '../data/top100 per year/'
# for year in range(1995,2017):
#     try:
#         get_top100(year,path_)
#     except Exception as e:
#         print(e)
#         time.sleep(60)
#         print('Retrying for year : %s' %(year))
#         get_top100(year,path_)

# %% [raw]
# for i in range(1995,2017):
#     compare_top_vs_script(i,'../data/top100 per year/','../data/top100 per year/curated/')

# %% [markdown]
# - ### Extract functions

# %%
path='../data/top100 per year/curated/'
col=['classement','titre','annee','annee_','categorie','realisateur','url','url_script']
titles=pd.DataFrame(columns=col)
for year in range(1995,2017):
    df=get_curated(year,path)
    df['annee_']=year
    titles = pd.concat([titles,df])

# %%
#retraiter la colonne catégorie
titles.reset_index(inplace=True,drop=True)
titles['categorie']=titles['categorie'].apply(lambda x : x.replace('\n','').replace(' ',''))
titles['categorie1'], titles['categorie2'], titles['categorie3']= titles['categorie'].str.split(',', 2).str

# %%
#consolider le dataframe pour les liens qui ont un lien script
titles = titles.dropna(subset=['url_script'],how='any')
titles.reset_index(inplace=True,drop=True)
titles
# Out:
#           annee  annee_                   categorie  classement    duree  \
# 0        (1995)  1995.0  Animation,Adventure,Comedy         1.0   81 min
# 1    (I) (1995)  1995.0     Adventure,Drama,History         3.0  140 min
# 2        (1995)  1995.0         Crime,Drama,Mystery         9.0  127 min
# 3        (1995)  1995.0                 Drama,Music        14.0  143 min
# 4        (1995)  1995.0     Biography,Drama,History        18.0  178 min
# 5        (1995)  1995.0       Comedy,Crime,Thriller        19.0  105 min
# 6        (1995)  1995.0          Action,Crime,Drama        25.0  170 min
# 7        (1995)  1995.0         Action,Comedy,Crime        28.0  119 min
# 8        (1995)  1995.0              Comedy,Romance        32.0   97 min
# 9        (1995)  1995.0               Drama,Romance        39.0  136 min
# 10       (1995)  1995.0       Biography,Crime,Drama        40.0  178 min
# 11       (1995)  1995.0     Action,Adventure,Family        45.0   95 min
# 12       (1995)  1995.0         Action,Crime,Sci-Fi        52.0   96 min
# 13       (1995)  1995.0         Crime,Drama,Mystery        56.0  123 min
# 14       (1995)  1995.0               Drama,Romance        57.0  111 min
# 15       (1995)  1995.0       Action,Crime,Thriller        60.0  132 min
# 16       (1995)  1995.0         Action,Crime,Sci-Fi        71.0  106 min
# 17       (1995)  1995.0         Crime,Drama,Mystery        91.0  102 min
# 18       (1995)  1995.0             Horror,Thriller        94.0   87 min
# 19       (1995)  1995.0     Horror,Mystery,Thriller        99.0  109 min
# 20       (1996)  1996.0     Action,Adventure,Sci-Fi         1.0  145 min
# 21       (1996)  1996.0        Comedy,Drama,Romance         4.0  139 min
# 22       (1996)  1996.0              Horror,Mystery        13.0  111 min
# 23       (1996)  1996.0      Action,Adventure,Drama        17.0  111 min
# 353  http://www.imsdb.com/scripts/August-Osage-Coun...      Drama        NaN
# 354           http://www.imsdb.com/scripts/Carrie.html      Drama     Horror
# 355  http://www.imsdb.com/scripts/Dallas-Buyers-Clu...  Biography      Drama
# 356             http://www.imsdb.com/scripts/Rush.html     Action  Biography
# 357              http://www.imsdb.com/scripts/Her.html      Drama    Romance
# 358  http://www.imsdb.com/scripts/American-Sniper.html     Action  Biography
# 359         http://www.imsdb.com/scripts/Godzilla.html     Action  Adventure
# 360     http://www.imsdb.com/scripts/Interstellar.html  Adventure      Drama
# 361  http://www.imsdb.com/scripts/How-to-Train-Your...  Animation     Action
# 362  http://www.imsdb.com/scripts/Star-Wars-The-For...     Action  Adventure
# 363   http://www.imsdb.com/scripts/Fantastic-Four.html     Action  Adventure
# 364      http://www.imsdb.com/scripts/Point-Break.html     Action      Crime
# 365       http://www.imsdb.com/scripts/La-La-Land.html     Comedy      Drama
# 366     http://www.imsdb.com/scripts/Ghostbusters.html     Action     Comedy
#
#     categorie3
# 0       Comedy
# 1      History
# 2      Mystery
# 3          NaN
# 4      History
# 5     Thriller
# 6        Drama
# 7        Crime
# 8          NaN
# 9          NaN
# 10       Drama
# 11      Family
# 12      Sci-Fi
# 13     Mystery
# 14         NaN
# 15    Thriller
# 16      Sci-Fi
# 17     Mystery
# 18         NaN
# 19    Thriller
# 20      Sci-Fi
# 21     Romance
# 22         NaN
# 23       Drama
# 24    Thriller
# 25     Mystery
# 26     Romance
# 27    Thriller
# 28      Horror
# 29         NaN
# ..         ...
# 337      Drama
# 338        NaN
# 339    Mystery
# 340     Comedy
# 341      Drama
# 342     Family
# 343        NaN
# 344     Comedy
# 345     Comedy
# 346     Sci-Fi
# 347        NaN
# 348      Sport
# 349    Mystery
# 350      Drama
# 351    History
# 352   Thriller
# 353        NaN
# 354        NaN
# 355        NaN
# 356      Drama
# 357     Sci-Fi
# 358      Drama
# 359     Sci-Fi
# 360     Sci-Fi
# 361  Adventure
# 362    Fantasy
# 363     Sci-Fi
# 364      Sport
# 365      Music
# 366    Fantasy
#
# [367 rows x 12 columns]

# %%
print('Only remains %s movies.'%(len(titles)))
# Out:
# Only remains 367 movies.

# %%
#les différentes catégories:
l=list(titles.categorie1)+list(titles.categorie2)+list(titles.categorie3)
set(l)
# Out:
# {nan,
#  u'Action',
#  u'Adventure',
#  u'Animation',
#  u'Biography',
#  u'Comedy',
#  u'Crime',
#  u'Drama',
#  u'Family',
#  u'Fantasy',
#  u'History',
#  u'Horror',
#  u'Music',
#  u'Musical',
#  u'Mystery',
#  u'Romance',
#  u'Sci-Fi',
#  u'Sport',
#  u'Thriller',
#  u'War',
#  u'Western'}

# %% [markdown]
# - ### Analysis Functions

# %%
def clean_character(char):
    if isinstance(char,unicode) or isinstance(char,str):
        char=char.replace('\n','').replace('*','').replace('O/S','').replace('V.O.','')
        char=re.sub(' +',' ',char)
        if 'CONTINUED' in char:
            return u'CONTINUED'
        if '(' in char or ')' in char:
            regex = re.compile(".*?\((.*?)\)")
            to_delete = re.findall(regex, char)
            for e in to_delete:
                char=char.replace('(%s)' %e,'')
            if char=='' or ')'in char:
                return None
            else:
                return char.rstrip() #delete lose end white space
        else:
            return char.rstrip()
    else:
        return None
    
def continued_speech(char_vector):
    char_vector=list(char_vector)
    while 'CONTINUED' in char_vector:
        count=0
        idx=char_vector.index("CONTINUED")
        for element in char_vector[idx-1::-1]:
            #if (isinstance(element,str) or isinstance(element,unicode)) and (element!='unknown'):
            if element and element!='unknown':
                char_vector[idx]=char_vector[idx-1-count]
                #print('Replaces CONTINUED with %s' %(char_vector[idx-1-count]))
                break
            count=count+1
            if count==len(char_vector[idx-1::-1]):
                char_vector[idx]='unknown'
                break
    return char_vector


# to remove outliers
def principal_characters(char_dic):
    mean = 0
    for i, j in char_dic.items():
        mean = mean + j
    mean = mean / len(char_dic)

    stddev = 0
    for i, j in char_dic.items():
        stddev = stddev + (j - mean)*(j - mean)
    stddev = stddev / len(char_dic)
    stddev = math.sqrt(stddev)

    temp = {}
    for i, j in char_dic.items():
        if (math.fabs(j - mean) < 3*stddev):
            temp[i] = j
    print(stddev,mean)
    return temp


def char_analysis(df):
    d=dict(Counter(df['character_clean']))
    d={key: value for key, value in d.items() 
                 if key}
    charlist = sorted(d)
    gender = dict()
    lines=[element.split('\n') for element in df['text']]
    lines=[item for sublist in lines for item in sublist]

    for char in charlist:
        m, f, p = 0, 0, 0 
        for i in range(len(lines)):
            srch = re.search(char, lines[i], re.I)
            if not srch:
                continue
            if srch.group().isupper():
                continue
            else:
                k, k_range = -1, 2
                while k + i + 1 < len(lines):
                    k = k + 1
                    m = m + len(re.findall("\s+he", lines[k+i], re.I)) + len(re.findall("\s+him", lines[k+i], re.I))
                    f = f + len(re.findall("\s+she", lines[k+i], re.I)) + len(re.findall("\s+her", lines[k+i], re.I))
                    if lines[k+i].isupper():
                        break
                    if k >= k_range:
                        break
                k, k_range = -1, 4
                while k + i + 1 < len(lines):
                    k = k + 1
                    m1, m2, m3, m4 = re.search("\s+he", lines[k+i], re.I), re.search("\s+him", lines[k+i], re.I),\
                                    re.search("\s+she", lines[k+i], re.I), re.search("\s+her", lines[k+i], re.I)
                    if m1:
                        if m2:
                            mc = min(m1.span()[0], m2.span()[0])
                        else:
                            mc = m1.span()[0]
                    else:
                        mc = len(lines[k+i])
                    if m3:
                        if m4:
                            fc = min(m3.span()[0], m4.span()[0])
                        else:
                            fc = m3.span()[0]
                    else:
                        fc = len(lines[k+i])
                    if not(m1 or m2 or m3 or m4):
                        continue
                    else:
                        if (mc < fc):
                            p = p - 1
                        else:
                            p = p + 1
                        break
                    if lines[k+i].isupper():
                        break
                    if k >= k_range:
                        break
        gender[char] = m, f, p

    for char, g in gender.items():
        g_score = 2*g[1] - g[0] 
        g_sum = g[1]+g[0]
        g_score = g_score
        if (g_sum == 0.0) :#or (0 == 1):
            #print(char+" Undetermined ")
            gender[char] = "?" #0, 0, -1
        elif g_score > 0:
            #print(char+" Female "+str(g[0])+","+str(g[1])+","+str(g[2])+","+str(g_score))
            gender[char] = "F" #0, 0, 1
        else:
            #print(char+" Male", " ", str(g[0])+","+str(g[1])+","+str(g[2])+","+str(g_score))
            gender[char] = "M" #0, 0, 0
            
    return d,gender

# %% [markdown]
# - ### Script loader and parser

# %%
def get_all_bygenre(genre):
    urls = list(titles[(titles['categorie1']==genre) | (titles['categorie2']==genre)]['url_script'])
    output=[]
    nb_of_errors=0
    for url in urls:
        path='../data/script/%s/' %(genre.lower())
        name=url.replace(':','').replace('/','')
        try:
            test=parse(url,path+'raw/',name)
            try:
                #print(df['text'][0].split('\n')[0])
                vec=test['character'].apply(lambda x :clean_character(x))
                test['character_clean']=continued_speech(vec)
                char,gender=char_analysis(test)
                #output_actions_.append(char)
                #create gender column in dataframe:
                test['gender']=[gender.get(item,item)  for item in list(test['character_clean'])]
                if not os.path.exists(path+'clean/'):
                    os.makedirs(path+'clean/')
                test.to_csv(path+'clean/'+name+'.csv',sep='|',encoding='latin1')
            except Exception as e:
                print('------Caught exception : %s' %e)
                nb_of_errors=nb_of_errors+1
            output.append(test)
        except Exception as e:
            print(e)
            nb_of_errors=nb_of_errors+1
    return output

# %%
out = get_all_bygenre('Action')
# Out:
# Getting script @ http://www.imsdb.com/scripts/Heat.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Heat.html in 3.81798696518
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Bad-Boys.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Bad-Boys.html in 2.26882982254
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Mighty-Morphin-Power-Rangers-The-Movie.html.
#       Done parsing script at http://www.imsdb.com/scripts/Mighty-Morphin-Power-Rangers-The-Movie.html in 1.71898889542
# -----------------
# ------Caught exception : unbalanced parenthesis
# Getting script @ http://www.imsdb.com/scripts/Judge-Dredd.html.
#       Done parsing script at http://www.imsdb.com/scripts/Judge-Dredd.html in 1.98093509674
# -----------------
# ------Caught exception : unbalanced parenthesis
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Assassins.html.
#       Done parsing script at http://www.imsdb.com/scripts/Assassins.html in 2.23551893234
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Virtuosity.html.
#       Done parsing script at http://www.imsdb.com/scripts/Virtuosity.html in 1.69378614426
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Independence-Day.html.
#       Done parsing script at http://www.imsdb.com/scripts/Independence-Day.html in 2.52137494087
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Star-Trek-First-Contact.html.
#       Done parsing script at http://www.imsdb.com/scripts/Star-Trek-First-Contact.html in 2.69643115997
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Broken-Arrow.html.
#       Done parsing script at http://www.imsdb.com/scripts/Broken-Arrow.html in 1.44721603394
# -----------------
# ------Caught exception : 'character'
# The file @ http://www.imsdb.com/scripts/Courage-Under-Fire.pdf is a PDF
# ------Caught exception : 'NoneType' object has no attribute '__getitem__'
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/From-Dusk-Till-Dawn.html.
#       Done parsing script at http://www.imsdb.com/scripts/From-Dusk-Till-Dawn.html in 2.03970980644
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Air-Force-One.html.
#       Done parsing script at http://www.imsdb.com/scripts/Air-Force-One.html in 2.46016812325
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Tomorrow-Never-Dies.html.
#       Done parsing script at http://www.imsdb.com/scripts/Tomorrow-Never-Dies.html in 5.12730002403
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Starship-Troopers.html.
#       Done parsing script at http://www.imsdb.com/scripts/Starship-Troopers.html in 2.62837696075
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Breakdown.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Breakdown.html in 2.50969481468
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Absolute-Power.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Absolute-Power.html in 2.9054479599
# -----------------
# Getting script @ http://www.imsdb.com/scripts/G.I.-Jane.html.
#       Done parsing script at http://www.imsdb.com/scripts/G.I.-Jane.html in 2.65877103806
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Alien-Resurrection.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/
# -----------------
# ------Caught exception : unbalanced parenthesis
# Getting script @ http://www.imsdb.com/scripts/TRON-Legacy.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/TRON-Legacy.html in 3.35260391235
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Clash-of-the-Titans.html.
#       Done parsing script at http://www.imsdb.com/scripts/Clash-of-the-Titans.html in 4.18171191216
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Megamind.html.
#       Done parsing script at http://www.imsdb.com/scripts/Megamind.html in 3.97816109657
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Legion.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Legion.html in 2.66708016396
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Machete.html.
#       Done parsing script at http://www.imsdb.com/scripts/Machete.html in 2.36799407005
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Thor.html.
#       Done parsing script at http://www.imsdb.com/scripts/Thor.html in 3.06680798531
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Rise-of-the-Planet-of-the-Apes.html.
#       Done parsing script at http://www.imsdb.com/scripts/Rise-of-the-Planet-of-the-Apes.html in 2.75838685036
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Cowboys-&-Aliens.html.
#       Done parsing script at http://www.imsdb.com/scripts/Cowboys-&-Aliens.html in 3.18621587753
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Unknown.html.
#       Done parsing script at http://www.imsdb.com/scripts/Unknown.html in 2.7501449585
# -----------------
# ------Caught exception : unbalanced parenthesis
# Getting script @ http://www.imsdb.com/scripts/I-Am-Number-Four.html.
#       Done parsing script at http://www.imsdb.com/scripts/I-Am-Number-Four.html in 2.07124590874
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Hanna.html.
#       Done parsing script at http://www.imsdb.com/scripts/Hanna.html in 3.7353758812
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Colombiana.html.
#       Done parsing script at http://www.imsdb.com/scripts/Colombiana.html in 3.61367201805
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Men-in-Black-3.html.
#       Done parsing script at http://www.imsdb.com/scripts/Men-in-Black-3.html in 2.52805900574
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Snow-White-and-the-Huntsman.html.
#       Done parsing script at http://www.imsdb.com/scripts/Snow-White-and-the-Huntsman.html in 2.7929019928
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Looper.html.
#       Done parsing script at http://www.imsdb.com/scripts/Looper.html in 2.71787190437
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Total-Recall.html.
#       Done parsing script at http://www.imsdb.com/scripts/Total-Recall.html in 2.20880293846
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Oblivion.html.
#       Done parsing script at http://www.imsdb.com/scripts/Oblivion.html in 3.2113070488
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Rush.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Rush.html in 3.41899800301
# -----------------
# Getting script @ http://www.imsdb.com/scripts/American-Sniper.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/American-Sniper.html in 3.06332802773
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Godzilla.html.
#       Done parsing script at http://www.imsdb.com/scripts/Godzilla.html in 2.62581110001
# -----------------
# Getting script @ http://www.imsdb.com/scripts/How-to-Train-Your-Dragon-2.html.
#       Done parsing script at http://www.imsdb.com/scripts/How-to-Train-Your-Dragon-2.html in 2.94415807724
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html.
#       Done parsing script at http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html in 3.67593502998
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Fantastic-Four.html.
#       Done parsing script at http://www.imsdb.com/scripts/Fantastic-Four.html in 3.41458892822
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Point-Break.html.
#       Done parsing script at http://www.imsdb.com/scripts/Point-Break.html in 2.57396292686
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Ghostbusters.html.
#       Done parsing script at http://www.imsdb.com/scripts/Ghostbusters.html in 1.76547694206
# -----------------

# %%
for element in ['Romance','Drama','Comedy','Sci-Fi','Horror','Thriller']:
    get_all_bygenre(element)
# Out:
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Clueless.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/Sense-and-Sensibility.html.
#       Done parsing script at http://www.imsdb.com/scripts/Sense-and-Sensibility.html in 2.66455411911
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Leaving-Las-Vegas.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/Titanic.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Titanic.html in 3.07859921455
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/There's-Something-About-Mary.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/Runaway-Bride.html.
#       Done parsing script at http://www.imsdb.com/scripts/Runaway-Bride.html in 3.21873497963
# -----------------
# Getting script @ http://www.imsdb.com/scripts/American-Beauty.html.
#       Done parsing script at http://www.imsdb.com/scripts/American-Beauty.html in 2.91960692406
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Cruel-Intentions.html.
#       Done parsing script at http://www.imsdb.com/scripts/Cruel-Intentions.html in 2.10037398338
# -----------------
# Getting script @ http://www.imsdb.com/scripts/At-First-Sight.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/Autumn-in-New-York.html.
#       Done parsing script at http://www.imsdb.com/scripts/Autumn-in-New-York.html in 3.68132996559
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Legally-Blonde.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Erin-Brockovich.html.
#       Done parsing script at http://www.imsdb.com/scripts/Erin-Brockovich.html in 2.77080821991
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Traffic.html.
#       Done parsing script at http://www.imsdb.com/scripts/Traffic.html in 2.86867594719
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Unbreakable.html.
#       Done parsing script at http://www.imsdb.com/scripts/Unbreakable.html in 1.99166989326
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Frequency.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/Autumn-in-New-York.html.
#       Done parsing script at http://www.imsdb.com/scripts/Autumn-in-New-York.html in 3.03102612495
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Thirteen-Days.html.
#       Done parsing script at http://www.imsdb.com/scripts/Thirteen-Days.html in 2.3827419281
# -----------------
# Getting script @ http://www.imsdb.com/scripts/High-Fidelity.html.
#       Done parsing script at http://www.imsdb.com/scripts/High-Fidelity.html in 2.81018018723
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Wonder-Boys.html.
#       Done parsing script at http://www.imsdb.com/scripts/Wonder-Boys.html in 2.07662582397
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Pearl-Harbor.html.
# list index out of range
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Hannibal.html.
#       Done parsing script at http://www.imsdb.com/scripts/Hannibal.html in 2.68363189697
# -----------------
# ------Caught exception : unbalanced parenthesis
# Getting script @ http://www.imsdb.com/scripts/Save-the-Last-Dance.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Save-the-Last-Dance.html in 2.44328117371
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Training-Day.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/Ali.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Ali.html in 4.39383888245
# -----------------
# Getting script @ http://www.imsdb.com/scripts/In-the-Bedroom.html.
#       Done parsing script at http://www.imsdb.com/scripts/In-the-Bedroom.html in 3.50261092186
# -----------------
# ------Caught exception : unbalanced parenthesis
# The file @ http://www.imsdb.com/scripts/Monster's-Ball.pdf is a PDF
# ------Caught exception : 'NoneType' object has no attribute '__getitem__'
# Getting script @ http://www.imsdb.com/scripts/Angel-Eyes.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Angel-Eyes.html in 2.65733504295
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Signs.html.
#       Done parsing script at http://www.imsdb.com/scripts/Signs.html in 3.37665200233
# -----------------
# The file @ http://www.imsdb.com/scripts/8-Mile.pdf is a PDF
# ------Caught exception : 'NoneType' object has no attribute '__getitem__'
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Panic-Room.html.
#       Done parsing script at http://www.imsdb.com/scripts/Panic-Room.html in 3.41087293625
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Gangs-of-New-York.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/John-Q.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/Insomnia.html.
#       Done parsing script at http://www.imsdb.com/scripts/Insomnia.html in 2.75785708427
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Collateral-Damage.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Collateral-Damage.html in 3.60266804695
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Enough.html.
#       Done parsing script at http://www.imsdb.com/scripts/Enough.html in 4.61461186409
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Queen-of-the-Damned.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Queen-of-the-Damned.html in 3.52659511566
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Bruce-Almighty.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Bruce-Almighty.html in 3.12105989456
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Something's-Gotta-Give.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Something's-Gotta-Give.html in 3.25728297234
# -----------------
# ------Caught exception : unbalanced parenthesis
# Getting script @ http://www.imsdb.com/scripts/Cold-Mountain.html.
#       Done parsing script at http://www.imsdb.com/scripts/Cold-Mountain.html in 4.2645380497
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Big-Fish.html.
#       Done parsing script at http://www.imsdb.com/scripts/Big-Fish.html in 3.03955197334
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Lost-in-Translation.html.
#       Done parsing script at http://www.imsdb.com/scripts/Lost-in-Translation.html in 2.33068203926
# -----------------
# 'NoneType' object has no attribute 'find'
# Getting script @ http://www.imsdb.com/scripts/Sideways.html.
#       Done parsing script at http://www.imsdb.com/scripts/Sideways.html in 3.51036715508
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Spanglish.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Spanglish.html in 3.74428915977
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Eternal-Sunshine-of-the-Spotless-Mind.html.
#       Done parsing script at http://www.imsdb.com/scripts/Eternal-Sunshine-of-the-Spotless-Mind.html in 3.13059902191
# -----------------
# ------Caught exception : unbalanced parenthesis
# Getting script @ http://www.imsdb.com/scripts/Garden-State.html.
#       Done parsing script at http://www.imsdb.com/scripts/Garden-State.html in 4.11415696144
# -----------------
# ------Caught exception : unexpected end of regular expression
# Getting script @ http://www.imsdb.com/scripts/Hotel-Rwanda.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Bridesmaids.html.
#       Done parsing script at http://www.imsdb.com/scripts/Bridesmaids.html in 3.47319412231
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Horrible-Bosses.html.
#       Done parsing script at http://www.imsdb.com/scripts/Horrible-Bosses.html in 3.84000086784
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Bad-Teacher.html.
#       Done parsing script at http://www.imsdb.com/scripts/Bad-Teacher.html in 2.99927616119
# -----------------
# ------Caught exception : unbalanced parenthesis
# Getting script @ http://www.imsdb.com/scripts/No-Strings-Attached.html.
#       Done parsing script at http://www.imsdb.com/scripts/No-Strings-Attached.html in 2.24017000198
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Midnight-in-Paris.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Midnight-in-Paris.html in 1.53624391556
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Hall-Pass.html.
#       Done parsing script at http://www.imsdb.com/scripts/Hall-Pass.html in 5.09307289124
# -----------------
# ------Caught exception : unbalanced parenthesis
# Getting script @ http://www.imsdb.com/scripts/Paul.html.
#       Done parsing script at http://www.imsdb.com/scripts/Paul.html in 4.59534192085
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Larry-Crowne.html.
#       Done parsing script at http://www.imsdb.com/scripts/Larry-Crowne.html in 4.27772593498
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Arthur.html.
#       Done parsing script at http://www.imsdb.com/scripts/Arthur.html in 3.77665185928
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Ted.html.
#       Done parsing script at http://www.imsdb.com/scripts/Ted.html in 4.0768430233
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Silver-Linings-Playbook.html.
#       Done parsing script at http://www.imsdb.com/scripts/Silver-Linings-Playbook.html in 3.8609380722
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Moonrise-Kingdom.html.
#       Done parsing script at http://www.imsdb.com/scripts/Moonrise-Kingdom.html in 3.60000491142
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Frankenweenie.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Frankenweenie.html in 3.00725007057
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Saving-Mr.-Banks.html.
#       Done parsing script at http://www.imsdb.com/scripts/Saving-Mr.-Banks.html in 3.66056203842

# %%
liste=[ u'Action',
 u'Adventure',
 u'Animation',
 u'Biography',
 u'Comedy',
 u'Crime',
 u'Drama',
 u'Family',
 u'Fantasy',
 u'History',
 u'Horror',
 u'Music',
 u'Musical',
 u'Mystery',
 u'Romance',
 u'Sci-Fi',
 u'Sport',
 u'Thriller',
 u'War',
 u'Western']

for element in liste:
    get_all_bygenre(element)

# %%
# %%time
actions_url = list(titles[(titles['categorie1']=='Action') | (titles['categorie2']=='Action')]['url_script'])
output_actions=[]
nb_of_errors=0
for url in actions_url:
    path='../data/script/action/'
    name=url.replace(':','').replace('/','')
    try:
        test=parse(url,path+'raw/',name)
        try:
            #print(df['text'][0].split('\n')[0])
            vec=test['character'].apply(lambda x :clean_character(x))
            test['character_clean']=continued_speech(vec)
            char,gender=char_analysis(test)
            #output_actions_.append(char)
            #create gender column in dataframe:
            test['gender']=[gender.get(item,item)  for item in list(test['character_clean'])]
            if not os.path.exists(path+'clean/'):
                os.makedirs(path+'clean/')
            test.to_csv(path+'clean/'+name+'.csv',sep='|',encoding='latin1')
        except Exception as e:
            print('------Caught exception : %s' %e)
            nb_of_errors=nb_of_errors+1
        output_actions.append(test)
    except Exception as e:
        print(e)
        nb_of_errors=nb_of_errors+1
# Out:
# Getting script @ http://www.imsdb.com/scripts/Heat.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Heat.html in 2.90403199196
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Bad-Boys.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Bad-Boys.html in 2.73012804985
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Mighty-Morphin-Power-Rangers-The-Movie.html.
#       Done parsing script at http://www.imsdb.com/scripts/Mighty-Morphin-Power-Rangers-The-Movie.html in 2.91653013229
# -----------------
# ------Caught exception : unbalanced parenthesis
# Getting script @ http://www.imsdb.com/scripts/Judge-Dredd.html.
#       Done parsing script at http://www.imsdb.com/scripts/Judge-Dredd.html in 2.61026382446
# -----------------
# ------Caught exception : unbalanced parenthesis
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Assassins.html.
#       Done parsing script at http://www.imsdb.com/scripts/Assassins.html in 2.28155589104
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Virtuosity.html.
#       Done parsing script at http://www.imsdb.com/scripts/Virtuosity.html in 2.09440898895
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Independence-Day.html.
#       Done parsing script at http://www.imsdb.com/scripts/Independence-Day.html in 2.1820499897
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Star-Trek-First-Contact.html.
#       Done parsing script at http://www.imsdb.com/scripts/Star-Trek-First-Contact.html in 3.29868102074
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Broken-Arrow.html.
#       Done parsing script at http://www.imsdb.com/scripts/Broken-Arrow.html in 1.98773407936
# -----------------
# ------Caught exception : 'character'
# The file @ http://www.imsdb.com/scripts/Courage-Under-Fire.pdf is a PDF
# ------Caught exception : 'NoneType' object has no attribute '__getitem__'
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/From-Dusk-Till-Dawn.html.
#       Done parsing script at http://www.imsdb.com/scripts/From-Dusk-Till-Dawn.html in 1.84487700462
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Air-Force-One.html.
#       Done parsing script at http://www.imsdb.com/scripts/Air-Force-One.html in 2.8286190033
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Tomorrow-Never-Dies.html.
#       Done parsing script at http://www.imsdb.com/scripts/Tomorrow-Never-Dies.html in 3.0692179203
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Starship-Troopers.html.
#       Done parsing script at http://www.imsdb.com/scripts/Starship-Troopers.html in 2.23037695885
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Breakdown.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Breakdown.html in 2.53925490379
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Absolute-Power.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Absolute-Power.html in 2.65141201019
# -----------------
# Getting script @ http://www.imsdb.com/scripts/G.I.-Jane.html.
#       Done parsing script at http://www.imsdb.com/scripts/G.I.-Jane.html in 2.20299720764
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Alien-Resurrection.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/Metro.html.
#       Done parsing script at http://www.imsdb.com/scripts/Metro.html in 2.88549399376
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Armageddon.html.
# list index out of range
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Rush-Hour.html.
#       Done parsing script at http://www.imsdb.com/scripts/Rush-Hour.html in 2.19387102127
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Godzilla.html.
#       Done parsing script at http://www.imsdb.com/scripts/Godzilla.html in 2.48925900459
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Enemy-of-the-State.html.
# list index out of range
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Blade.html.
#       Done parsing script at http://www.imsdb.com/scripts/Blade.html in 2.02544403076
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Lost-in-Space.html.
#       Done parsing script at http://www.imsdb.com/scripts/Lost-in-Space.html in 2.30606508255
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Ronin.html.
#       Done parsing script at http://www.imsdb.com/scripts/Ronin.html in 3.72237491608
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Hard-Rain.html.
#       Done parsing script at http://www.imsdb.com/scripts/Hard-Rain.html in 2.41485500336
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Soldier.html.
#       Done parsing script at http://www.imsdb.com/scripts/Soldier.html in 2.78864002228
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Wild-Wild-West.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Wild-Wild-West.html in 2.81118011475
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Entrapment.html.
#       Done parsing script at http://www.imsdb.com/scripts/Entrapment.html in 2.65426492691
# -----------------
# ------Caught exception : unbalanced parenthesis
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Three-Kings.html.
#       Done parsing script at http://www.imsdb.com/scripts/Three-Kings.html in 2.5030310154
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Lake-Placid.html.
#       Done parsing script at http://www.imsdb.com/scripts/Lake-Placid.html in 1.98170185089
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Mystery-Men.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/Gladiator.html.
#       Done parsing script at http://www.imsdb.com/scripts/Gladiator.html in 1.99003911018
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/X-Men.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/Crouching-Tiger,-Hidden-Dragon.html.
#       Done parsing script at http://www.imsdb.com/scripts/Crouching-Tiger,-Hidden-Dragon.html in 1.35294413567
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Charlie's-Angels.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Charlie's-Angels.html in 2.32546401024
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Hollow-Man.html.
#       Done parsing script at http://www.imsdb.com/scripts/Hollow-Man.html in 2.982213974
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Reindeer-Games.html.
#       Done parsing script at http://www.imsdb.com/scripts/Reindeer-Games.html in 4.58287286758
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Red-Planet.html.
# list index out of range
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Rush-Hour-2.html.
#       Done parsing script at http://www.imsdb.com/scripts/Rush-Hour-2.html in 1.74267411232
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Pearl-Harbor.html.
# list index out of range
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Jurassic-Park-III.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/Swordfish.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Swordfish.html in 2.50551915169
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/15-Minutes.html.
#       Done parsing script at http://www.imsdb.com/scripts/15-Minutes.html in 2.04182195663
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Spider-Man.html.
#       Done parsing script at http://www.imsdb.com/scripts/Spider-Man.html in 2.04607701302
# -----------------
# Getting script @ http://www.imsdb.com/scripts/xXx.html.
#       Done parsing script at http://www.imsdb.com/scripts/xXx.html in 2.60578799248
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Minority-Report.html.
#       Done parsing script at http://www.imsdb.com/scripts/Minority-Report.html in 3.70805096626
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Blade-II.html.
# list index out of range
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Star-Trek-Nemesis.html.
#       Done parsing script at http://www.imsdb.com/scripts/Star-Trek-Nemesis.html in 2.15966916084
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Collateral-Damage.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Collateral-Damage.html in 2.90647792816
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Resident-Evil.html.
#       Done parsing script at http://www.imsdb.com/scripts/Resident-Evil.html in 2.06651806831
# -----------------
# ------Caught exception : unbalanced parenthesis
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Freddy-vs.-Jason.html.
#       Done parsing script at http://www.imsdb.com/scripts/Freddy-vs.-Jason.html in 2.03574705124
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Cradle-2-the-Grave.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Cradle-2-the-Grave.html in 2.07925796509
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Basic.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Basic.html in 2.36927700043
# -----------------
# ------Caught exception : unbalanced parenthesis
# Getting script @ http://www.imsdb.com/scripts/I,-Robot.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/I,-Robot.html in 2.43463587761
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Hellboy.html.
#       Done parsing script at http://www.imsdb.com/scripts/Hellboy.html in 2.6553800106
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Dawn-of-the-Dead.html.
#       Done parsing script at http://www.imsdb.com/scripts/Dawn-of-the-Dead.html in 2.68153691292
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Blade-Trinity.html.
#       Done parsing script at http://www.imsdb.com/scripts/Blade-Trinity.html in 2.82890510559
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Walking-Tall.html.
#       Done parsing script at http://www.imsdb.com/scripts/Walking-Tall.html in 1.62277698517
# -----------------
# 'NoneType' object has no attribute 'find'
# Getting script @ http://www.imsdb.com/scripts/Cellular.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Cellular.html in 2.76876282692
# -----------------
# Getting script @ http://www.imsdb.com/scripts/King-Kong.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/King-Kong.html in 3.23222899437
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Fantastic-Four.html.
#       Done parsing script at http://www.imsdb.com/scripts/Fantastic-Four.html in 2.94401502609
# -----------------
# Getting script @ http://www.imsdb.com/scripts/V-for-Vendetta.html.
#       Done parsing script at http://www.imsdb.com/scripts/V-for-Vendetta.html in 3.20312094688
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Hostage.html.
#       Done parsing script at http://www.imsdb.com/scripts/Hostage.html in 2.34139204025
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Pirates-of-the-Caribbean-Dead-Man's-Chest.html.
#       Done parsing script at http://www.imsdb.com/scripts/Pirates-of-the-Caribbean-Dead-Man's-Chest.html in 2.46393799782
# -----------------
# ------Caught exception : nothing to repeat
# Getting script @ http://www.imsdb.com/scripts/Miami-Vice.html.
#       Done parsing script at http://www.imsdb.com/scripts/Miami-Vice.html in 2.22770094872
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Smokin'-Aces.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Smokin'-Aces.html in 3.16327118874
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Crank.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Crank.html in 3.34559702873
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Wild-Hogs.html.
#       Done parsing script at http://www.imsdb.com/scripts/Wild-Hogs.html in 2.65177297592
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Ghost-Rider.html.
#       Done parsing script at http://www.imsdb.com/scripts/Ghost-Rider.html in 2.74291586876
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Hancock.html.
#       Done parsing script at http://www.imsdb.com/scripts/Hancock.html in 2.44488096237
# -----------------
# ------Caught exception : 'character'
# Getting script @ http://www.imsdb.com/scripts/Kung-Fu-Panda.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Kung-Fu-Panda.html in 4.45883321762
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Wanted.html.
#       Done parsing script at http://www.imsdb.com/scripts/Wanted.html in 2.42671394348
# -----------------
# ------Caught exception : 'character'
# Getting script @ http://www.imsdb.com/scripts/Tropic-Thunder.html.
#       Done parsing script at http://www.imsdb.com/scripts/Tropic-Thunder.html in 2.34923887253
# -----------------
# ------Caught exception : 'character'
# Getting script @ http://www.imsdb.com/scripts/Eagle-Eye.html.
#       Done parsing script at http://www.imsdb.com/scripts/Eagle-Eye.html in 2.76705288887
# -----------------
# ------Caught exception : 'character'
# Getting script @ http://www.imsdb.com/scripts/Pineapple-Express.html.
#       Done parsing script at http://www.imsdb.com/scripts/Pineapple-Express.html in 3.33881497383
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Speed-Racer.html.
#       Done parsing script at http://www.imsdb.com/scripts/Speed-Racer.html in 2.77170205116
# -----------------
# ------Caught exception : 'character'
# Getting script @ http://www.imsdb.com/scripts/Max-Payne.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Max-Payne.html in 3.04238390923
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Defiance.html.
#       Done parsing script at http://www.imsdb.com/scripts/Defiance.html in 2.51125383377
# -----------------
# ------Caught exception : 'character'
# Getting script @ http://www.imsdb.com/scripts/Avatar.html.
#       Done parsing script at http://www.imsdb.com/scripts/Avatar.html in 3.51328897476
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Star-Trek.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Star-Trek.html in 3.30509805679
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Sherlock-Holmes.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Sherlock-Holmes.html in 3.17641091347
# -----------------
# Getting script @ http://www.imsdb.com/scripts/X-Men-Origins-Wolverine.html.
#       Done parsing script at http://www.imsdb.com/scripts/X-Men-Origins-Wolverine.html in 2.20317482948
# -----------------
# ------Caught exception : 'character'
# Getting script @ http://www.imsdb.com/scripts/2012.html.
#       Done parsing script at http://www.imsdb.com/scripts/2012.html in 3.1820268631
# -----------------
# Getting script @ http://www.imsdb.com/scripts/G.I.-Joe-The-Rise-of-Cobra.html.
#       Done parsing script at http://www.imsdb.com/scripts/G.I.-Joe-The-Rise-of-Cobra.html in 3.07493710518
# -----------------
# ------Caught exception : 'character'
# Getting script @ http://www.imsdb.com/scripts/Terminator-Salvation.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Terminator-Salvation.html in 2.87570786476
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Watchmen.html.
#       Done parsing script at http://www.imsdb.com/scripts/Watchmen.html in 2.52599787712
# -----------------
# ------Caught exception : 'character'
# Getting script @ http://www.imsdb.com/scripts/Surrogates.html.
#       Done parsing script at http://www.imsdb.com/scripts/Surrogates.html in 2.51413798332
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Ninja-Assassin.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Ninja-Assassin.html in 2.60728907585
# -----------------
# Getting script @ http://www.imsdb.com/scripts/9.html.
#       Done parsing script at http://www.imsdb.com/scripts/9.html in 2.43757510185
# -----------------
# ------Caught exception : 'character'
# Getting script @ http://www.imsdb.com/scripts/Inception.html.
#       Done parsing script at http://www.imsdb.com/scripts/Inception.html in 2.55279397964
# -----------------
# Getting script @ http://www.imsdb.com/scripts/How-to-Train-Your-Dragon.html.
#       Done parsing script at http://www.imsdb.com/scripts/How-to-Train-Your-Dragon.html in 2.3387029171
# -----------------
# ------Caught exception : unbalanced parenthesis
# Getting script @ http://www.imsdb.com/scripts/TRON-Legacy.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/TRON-Legacy.html in 2.54328107834
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Clash-of-the-Titans.html.
#       Done parsing script at http://www.imsdb.com/scripts/Clash-of-the-Titans.html in 2.74526715279
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Megamind.html.
#       Done parsing script at http://www.imsdb.com/scripts/Megamind.html in 2.49818491936
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Legion.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Legion.html in 2.8641910553
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Machete.html.
#       Done parsing script at http://www.imsdb.com/scripts/Machete.html in 2.44247078896
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Thor.html.
#       Done parsing script at http://www.imsdb.com/scripts/Thor.html in 2.93513703346
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Rise-of-the-Planet-of-the-Apes.html.
#       Done parsing script at http://www.imsdb.com/scripts/Rise-of-the-Planet-of-the-Apes.html in 2.43399000168
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Cowboys-&-Aliens.html.
#       Done parsing script at http://www.imsdb.com/scripts/Cowboys-&-Aliens.html in 2.63302993774
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Unknown.html.
#       Done parsing script at http://www.imsdb.com/scripts/Unknown.html in 2.58106899261
# -----------------
# ------Caught exception : unbalanced parenthesis
# Getting script @ http://www.imsdb.com/scripts/I-Am-Number-Four.html.
#       Done parsing script at http://www.imsdb.com/scripts/I-Am-Number-Four.html in 2.39714598656
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Hanna.html.
#       Done parsing script at http://www.imsdb.com/scripts/Hanna.html in 3.39202094078
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Colombiana.html.
#       Done parsing script at http://www.imsdb.com/scripts/Colombiana.html in 2.87979698181
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Men-in-Black-3.html.
#       Done parsing script at http://www.imsdb.com/scripts/Men-in-Black-3.html in 2.51106619835
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Snow-White-and-the-Huntsman.html.
#       Done parsing script at http://www.imsdb.com/scripts/Snow-White-and-the-Huntsman.html in 2.52207398415
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Looper.html.
#       Done parsing script at http://www.imsdb.com/scripts/Looper.html in 2.48241400719
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Total-Recall.html.
#       Done parsing script at http://www.imsdb.com/scripts/Total-Recall.html in 2.19142889977
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Oblivion.html.
#       Done parsing script at http://www.imsdb.com/scripts/Oblivion.html in 2.39316105843
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Rush.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Rush.html in 2.48888993263
# -----------------
# Getting script @ http://www.imsdb.com/scripts/American-Sniper.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/American-Sniper.html in 2.41115903854
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Godzilla.html.
#       Done parsing script at http://www.imsdb.com/scripts/Godzilla.html in 4.78270602226
# -----------------
# Getting script @ http://www.imsdb.com/scripts/How-to-Train-Your-Dragon-2.html.
#       Done parsing script at http://www.imsdb.com/scripts/How-to-Train-Your-Dragon-2.html in 2.46401786804
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html.
#       Done parsing script at http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html in 2.49458098412
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Fantastic-Four.html.
#       Done parsing script at http://www.imsdb.com/scripts/Fantastic-Four.html in 2.62161207199
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Point-Break.html.
#       Done parsing script at http://www.imsdb.com/scripts/Point-Break.html in 2.23680186272
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Ghostbusters.html.
#       Done parsing script at http://www.imsdb.com/scripts/Ghostbusters.html in 1.11081409454
# -----------------
# CPU times: user 1min 5s, sys: 488 ms, total: 1min 5s
# Wall time: 5min 45s

# %%
print('The number of errors is %s out of a total %s.' %(nb_of_errors,len(actions_url)))
# Out:
# The number of errors is 30 out of a total 119.

# %%
#construct character info and add it to dataframe
output_actions_=[]
male_nb_speech=[]
female_nb_speech=[]
for df in output_actions:
    try:
        #print(df['text'][0].split('\n')[0])
        test=df['character'].apply(lambda x :clean_character(x))
        df['character_clean']=continued_speech(test)
        char,gender=char_analysis(df)
        output_actions_.append(char)
        #create gender column in dataframe:
        df['gender']=[gender.get(item,item)  for item in list(df['character_clean'])]
        male_nb_speech.append(len(df[df['gender']=='M']))
        female_nb_speech.append(len(df[df['gender']=='F']))
    except Exception as e:
        print('------Caught exception : %s' %e)
        nb_of_errors=nb_of_errors+1
# Out:
# ------Caught exception : unbalanced parenthesis
# ------Caught exception : unbalanced parenthesis
# ------Caught exception : nothing to repeat
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : 'character'
# ------Caught exception : unbalanced parenthesis
# ------Caught exception : unbalanced parenthesis

# %%
print('The number of errors is %s out of a total %s.' %(nb_of_errors,len(actions_url)))
# Out:
# The number of errors is 21 out of a total 86.

# %%
m=sum(male_nb_speech)
f=sum(female_nb_speech)

 
# Data to plot
labels = ["M","F"]
sizes = [m, f]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Repartition des repliques dans les films d'actions") 
plt.axis('equal')
plt.show()

# %%
i=1
male_nb_speech=len(output_actions[i][output_actions[i]['gender']=='M'])
female_nb_speech=len(output_actions[i][output_actions[i]['gender']=='F'])

 
# Data to plot
labels = ["M","F"]
sizes = [male_nb_speech, female_nb_speech]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Repartition des repliques dans %s' %output_actions[i]['text'][0].split('\n')[0]) 
plt.axis('equal')
plt.show()

# %%
i=10
male_nb_speech=len(output_actions[i][output_actions[i]['gender']=='M'])
female_nb_speech=len(output_actions[i][output_actions[i]['gender']=='F'])

 
# Data to plot
labels = ["M","F"]
sizes = [male_nb_speech, female_nb_speech]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Repartition des repliques dans %s' %output_actions[i]['text'][0].split('\n')[0]) 
plt.axis('equal')
plt.show()

# %%
# %%time
romances_url = list(titles[(titles['categorie1']=='Romance') | (titles['categorie2']=='Romance')]['url_script'])
output_romances=[]
nb_of_errors=0
for url in romances_url:
    path='../data/script/romance/'
    name=url.replace(':','').replace('/','')
    try:
        test=parse(url,path+'raw/',name)
        try:
            #print(df['text'][0].split('\n')[0])
            vec=test['character'].apply(lambda x :clean_character(x))
            test['character_clean']=continued_speech(vec)
            char,gender=char_analysis(test)
            #output_actions_.append(char)
            #create gender column in dataframe:
            test['gender']=[gender.get(item,item)  for item in list(test['character_clean'])]
            if not os.path.exists(path+'clean/'):
                os.makedirs(path+'clean/')
            test.to_csv(path+'clean/'+name+'.csv',sep='|',encoding='latin1')
        except Exception as e:
            print('------Caught exception : %s' %e)
            nb_of_errors=nb_of_errors+1
        output_romances.append(test)
    except Exception as e:
        print(e)
        nb_of_errors=nb_of_errors+1
# Out:
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Clueless.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/Sense-and-Sensibility.html.
#       Done parsing script at http://www.imsdb.com/scripts/Sense-and-Sensibility.html in 3.01980900764
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Leaving-Las-Vegas.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/Titanic.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Titanic.html in 2.8695628643
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/There's-Something-About-Mary.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/Runaway-Bride.html.
#       Done parsing script at http://www.imsdb.com/scripts/Runaway-Bride.html in 2.07442903519
# -----------------
# Getting script @ http://www.imsdb.com/scripts/American-Beauty.html.
#       Done parsing script at http://www.imsdb.com/scripts/American-Beauty.html in 2.08309793472
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Cruel-Intentions.html.
#       Done parsing script at http://www.imsdb.com/scripts/Cruel-Intentions.html in 2.02137517929
# -----------------
# Getting script @ http://www.imsdb.com/scripts/At-First-Sight.html.
# list index out of range
# Getting script @ http://www.imsdb.com/scripts/Autumn-in-New-York.html.
#       Done parsing script at http://www.imsdb.com/scripts/Autumn-in-New-York.html in 2.72402095795
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Legally-Blonde.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Legally-Blonde.html in 2.52006912231
# -----------------
# The file @ http://www.imsdb.com/scripts/Monster's-Ball.pdf is a PDF
# ------Caught exception : 'NoneType' object has no attribute '__getitem__'
# Getting script @ http://www.imsdb.com/scripts/Angel-Eyes.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Angel-Eyes.html in 2.502794981
# -----------------
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Eternal-Sunshine-of-the-Spotless-Mind.html.
#       Done parsing script at http://www.imsdb.com/scripts/Eternal-Sunshine-of-the-Spotless-Mind.html in 1.89636301994
# -----------------
# ------Caught exception : unbalanced parenthesis
# Getting script @ http://www.imsdb.com/scripts/Knocked-Up.html.
#       Done parsing script at http://www.imsdb.com/scripts/Knocked-Up.html in 2.78509688377
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Yes-Man.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Yes-Man.html in 2.83465909958
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Up-in-the-Air.html.
#       Done parsing script at http://www.imsdb.com/scripts/Up-in-the-Air.html in 2.83888912201
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Obsessed.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Obsessed.html in 2.79922199249
# -----------------
# Getting script @ http://www.imsdb.com/scripts/All-About-Steve.html.
#       Done parsing script at http://www.imsdb.com/scripts/All-About-Steve.html in 2.44629693031
# -----------------
# Getting script @ http://www.imsdb.com/scripts/She's-Out-of-My-League.html.
#       Done parsing script at http://www.imsdb.com/scripts/She's-Out-of-My-League.html in 2.60940599442
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Bridesmaids.html.
#       Done parsing script at http://www.imsdb.com/scripts/Bridesmaids.html in 2.53333902359
# -----------------
# Getting script @ http://www.imsdb.com/scripts/No-Strings-Attached.html.
#       Done parsing script at http://www.imsdb.com/scripts/No-Strings-Attached.html in 2.38347387314
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Water-for-Elephants.html.
#       Done parsing script at http://www.imsdb.com/scripts/Water-for-Elephants.html in 2.65142679214
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Source-Code.html.
#       Done parsing script at http://www.imsdb.com/scripts/Source-Code.html in 2.23442912102
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Hall-Pass.html.
#       Done parsing script at http://www.imsdb.com/scripts/Hall-Pass.html in 2.7768611908
# -----------------
# ------Caught exception : unbalanced parenthesis
# Getting script @ http://www.imsdb.com/scripts/Arthur.html.
#       Done parsing script at http://www.imsdb.com/scripts/Arthur.html in 2.50005483627
# -----------------
# Getting script @ http://www.imsdb.com/scripts/Her.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Her.html in 2.18292498589
# -----------------
# CPU times: user 14.6 s, sys: 104 ms, total: 14.7 s
# Wall time: 1min 13s

# %%
print('The number of errors is %s out of a total %s.' %(nb_of_errors,len(romances_url)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-0607ee57fa22> in <module>()
# ----> 1 print('The number of errors is %s out of a total %s.' %(nb_of_errors,len(romances_url)))
#
# NameError: name 'romances_url' is not defined

# %%
#construct character info and add it to dataframe
output_romances_=[]
male_nb_speech=[]
female_nb_speech=[]
for df in output_romances:
    try:
        #print(df['text'][0].split('\n')[0])
        test=df['character'].apply(lambda x :clean_character(x))
        df['character_clean']=continued_speech(test)
        char,gender=char_analysis(df)
        output_romances_.append(char)
        #create gender column in dataframe:
        df['gender']=[gender.get(item,item)  for item in list(df['character_clean'])]
        male_nb_speech.append(len(df[df['gender']=='M']))
        female_nb_speech.append(len(df[df['gender']=='F']))
    except Exception as e:
        print('------Caught exception : %s' %e)
        nb_of_errors=nb_of_errors+1
# Out:
# ------Caught exception : 'NoneType' object has no attribute '__getitem__'
# ------Caught exception : unbalanced parenthesis
# ------Caught exception : unbalanced parenthesis

# %%
print('The number of errors is %s out of a total %s.' %(nb_of_errors,len(romances_url)))
# Out:
# The number of errors is 3 out of a total 18.

# %%
m=sum(male_nb_speech)
f=sum(female_nb_speech)

 
# Data to plot
labels = ["M","F"]
sizes = [m, f]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Repartition des repliques dans les films romantiques") 
plt.axis('equal')
plt.show()

# %%
m=len(actions_url)
f=len(romances_url)

 
# Data to plot
labels = ["Actions","Romances"]
sizes = [m, f]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Ratio Actions-Romances parmis les top100") 
plt.axis('equal')
plt.show()

# %%
def find(df,to_find):
    count=0
    for element in df['text']:
        if to_find in normalize_text(element):
            count+=1
    return count

def find_female_in(df,to_find):
    count_female=0
    count_total=0
    idx=0
    try:
        list_female=list(df[df['gender']=='F']['character_clean'].apply(lambda x : normalize_text(x)))
        list_female=list(set(list_female))
        #list_female.append('she').append('her')
    except Exception as e:
        try:
            
            for element in df['text']:
                if to_find in normalize_text(element):
                    count_total+=1
                    if 'she' in element or "her" in element:
                        count_female+=1
            return count_female,count_total
        except Exception as ex:
            print('Warning : %s.' %(ex))
            return 0,0
    list_female.append('she')
    list_female.append("her")
    for element in df['text']:
        if to_find in normalize_text(element):
            count_total+=1
            for indicator in list_female: #she or her
                if indicator in element:
                    count_female+=1
                    break
        idx+=1
    return count_female,count_total

def find_any(df,l):
    for element in df['text']:
        for room in l:
            if room in normalize_text(element):
                print("Found %s" %room)
    return

def normalize_text(text):
    text = text.lower()
    normal = unicodedata.normalize('NFKD', text).encode('ASCII', 'ignore')
    return normal

# %%
l=['KITCHEN','Kitchen','kitchen','bed','BED','BEDROOM','Bed','Bedroom','bedroom','BATH','bath','Bath','BATHROOM',
  'Bathroom','bathroom','toilet','TOILET','Toilet']
l_norm=['kitchen','bed','bedroom','bath','bathroom','toilet']

# %% [raw]
# for df in output_romances:
#     find_any(df,l_norm)

# %%
import random
kitchen_count_action=0
kitchen_count_romance=0
rand_idx = random.sample(range(0,len(output_actions)),  len(output_romances))
for df in [output_actions[i] for i in rand_idx]:
    try:
        kitchen_count_action += find(df,'kitchen')
    except Exception as e:
        print(e)
for df in output_romances:
    try:
        kitchen_count_romance += find(df,'kitchen')
    except Exception as e:
        print(e)
# Out:
# 'NoneType' object has no attribute '__getitem__'

# %%
# Data to plot
labels = ["in actions","in romance"]
sizes = [kitchen_count_action, kitchen_count_romance]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Repartition de la presence des cuisines dans les films actions-romances") 
plt.axis('equal')
plt.show()

print('Actions: %s de présence cuisines' %(kitchen_count_action))
print('Romances: %s  de présence cuisines' %(kitchen_count_romance))
# Out:
# Actions: 76 de présence cuisines
# Romances: 99  de présence cuisines

# %%
kitchen_count_action_f=0
kitchen_count_action =0
kitchen_count_romance_f=0
kitchen_count_romance = 0
for df in output_actions:
    kitchen_count_action_f += find_female_in(df,'kitchen')[0]
    kitchen_count_action += find_female_in(df,'kitchen')[1]
for df in output_romances:
    kitchen_count_romance_f += find_female_in(df,'kitchen')[0]
    kitchen_count_romance += find_female_in(df,'kitchen')[1]
# Out:
# Warning : 'NoneType' object has no attribute '__getitem__'.
# Warning : 'NoneType' object has no attribute '__getitem__'.

# %%
# Data to plot
labels = ["in actions","in romance"]
sizes = [kitchen_count_action_f, kitchen_count_romance_f]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Repartition de la presence des cuisines dans les films actions-romances") 
plt.axis('equal')
plt.show()

print('Actions: %s femmes & cuisines' %(kitchen_count_action_f))
print('Romances: %s femmes & cuisines' %(kitchen_count_romance_f))
# Out:
# Actions: 95 femmes & cuisines
# Romances: 37 femmes & cuisines

# %%
# Data to plot
labels = ["other","women"]
sizes = [kitchen_count_action - kitchen_count_action_f, kitchen_count_action_f]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Repartition H/F & cuisne dans les films d'actions") 
plt.axis('equal')
plt.show()

print(' %s femmes & cuisines' %(kitchen_count_action_f))
print('%s autres & cuisines' %(kitchen_count_action- kitchen_count_action_f))
# Out:
#  95 femmes & cuisines
# 228 autres & cuisines

# %%
# Data to plot
labels = ["other","women"]
sizes = [kitchen_count_romance - kitchen_count_romance_f, kitchen_count_romance_f]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Repartition H/F & cuisine dans les films d'actions") 
plt.axis('equal')
plt.show()

print('Actions: %s femmes & cuisines' %(kitchen_count_action_f))
print('Romances: %s femmes & cuisines' %(kitchen_count_romance_f))
# Out:
# Actions: 95 femmes & cuisines
# Romances: 37 femmes & cuisines
