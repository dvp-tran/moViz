# %% [markdown]
# # Simple gender analysis

# %% [markdown]
# - ## Imports

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import unicodedata

import os, sys, json, re, argparse, urllib2, html5lib
from os import listdir
from os.path import isfile, join
from bs4 import BeautifulSoup, Tag, UnicodeDammit
import pandas as pd
from pandas.io.json import json_normalize
import time
import math
from parse_script import *
from crawler import *
# Out:
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %% [markdown]
# - ## Crawl

# %% [raw]
# #crawl top100 per year
# path_ = '../data/top100 per year/'
# for year in range(1995,2017):
#     try:
#         get_top100(year,path_)
#     except Exception as e:
#         print(e)
#         time.sleep(60)
#         print('Retrying for year : %s' %(year))
#         get_top100(year,path_)

# %% [raw]
# for i in range(1995,2017):
#     compare_top_vs_script(i,'../data/top100 per year/','../data/top100 per year/curated/')

# %% [markdown]
# - ### Extract functions

# %%
path='../data/top100 per year/curated/'
col=['classement','titre','annee','annee_','categorie','realisateur','url','url_script']
titles=pd.DataFrame(columns=col)
for year in range(1995,2017):
    df=get_curated(year,path)
    df['annee_']=year
    titles = pd.concat([titles,df])

# %%
#retraiter la colonne catégorie
titles.reset_index(inplace=True,drop=True)
titles['categorie']=titles['categorie'].apply(lambda x : x.replace('\n','').replace(' ',''))
titles['categorie1'], titles['categorie2'], titles['categorie3']= titles['categorie'].str.split(',', 2).str

# %%
#consolider le dataframe pour les liens qui ont un lien script
titles = titles.dropna(subset=['url_script'],how='any')
titles.reset_index(inplace=True,drop=True)
titles
# Out:
#           annee  annee_                   categorie  classement    duree  \
# 0        (1995)  1995.0  Animation,Adventure,Comedy         1.0   81 min
# 1    (I) (1995)  1995.0     Adventure,Drama,History         3.0  140 min
# 2        (1995)  1995.0         Crime,Drama,Mystery         9.0  127 min
# 3        (1995)  1995.0                 Drama,Music        14.0  143 min
# 4        (1995)  1995.0     Biography,Drama,History        18.0  178 min
# 5        (1995)  1995.0       Comedy,Crime,Thriller        19.0  105 min
# 6        (1995)  1995.0          Action,Crime,Drama        25.0  170 min
# 7        (1995)  1995.0         Action,Comedy,Crime        28.0  119 min
# 8        (1995)  1995.0              Comedy,Romance        32.0   97 min
# 9        (1995)  1995.0               Drama,Romance        39.0  136 min
# 10       (1995)  1995.0       Biography,Crime,Drama        40.0  178 min
# 11       (1995)  1995.0     Action,Adventure,Family        45.0   95 min
# 12       (1995)  1995.0         Action,Crime,Sci-Fi        52.0   96 min
# 13       (1995)  1995.0         Crime,Drama,Mystery        56.0  123 min
# 14       (1995)  1995.0               Drama,Romance        57.0  111 min
# 15       (1995)  1995.0       Action,Crime,Thriller        60.0  132 min
# 16       (1995)  1995.0         Action,Crime,Sci-Fi        71.0  106 min
# 17       (1995)  1995.0         Crime,Drama,Mystery        91.0  102 min
# 18       (1995)  1995.0             Horror,Thriller        94.0   87 min
# 19       (1995)  1995.0     Horror,Mystery,Thriller        99.0  109 min
# 20       (1996)  1996.0     Action,Adventure,Sci-Fi         1.0  145 min
# 21       (1996)  1996.0        Comedy,Drama,Romance         4.0  139 min
# 22       (1996)  1996.0              Horror,Mystery        13.0  111 min
# 23       (1996)  1996.0      Action,Adventure,Drama        17.0  111 min
# 24       (1996)  1996.0       Action,Crime,Thriller        20.0  108 min
# 25       (1996)  1996.0        Action,Drama,Mystery        25.0  116 min
# 26       (1996)  1996.0        Comedy,Drama,Romance        28.0  135 min
# 27       (1996)  1996.0        Crime,Drama,Thriller        63.0   98 min
# 28       (1996)  1996.0         Action,Crime,Horror        66.0  108 min
# 29       (1996)  1996.0                       Drama        71.0  135 min
# ..          ...     ...                         ...         ...      ...
# 337      (2012)  2012.0          Action,Crime,Drama        44.0  119 min
# 338      (2012)  2012.0             Sci-Fi,Thriller        49.0   84 min
# 339  (I) (2012)  2012.0    Action,Adventure,Mystery        54.0  118 min
# 340      (2012)  2012.0  Animation,Adventure,Comedy        57.0   92 min
# 341      (2012)  2012.0      Adventure,Comedy,Drama        69.0   94 min
# 342      (2012)  2012.0     Animation,Comedy,Family        83.0   87 min
# 343      (2012)  2012.0                       Drama        98.0  130 min
# 344  (I) (2013)  2013.0  Animation,Adventure,Comedy         3.0  102 min
# 345      (2013)  2013.0  Animation,Adventure,Comedy         4.0   98 min
# 346      (2013)  2013.0      Adventure,Drama,Sci-Fi         6.0   91 min
# 347      (2013)  2013.0                 Crime,Drama        17.0  138 min
# 348      (2013)  2013.0       Biography,Drama,Sport        36.0  128 min
# 349  (I) (2013)  2013.0    Action,Adventure,Mystery        40.0  124 min
# 350      (2013)  2013.0      Biography,Comedy,Drama        42.0  125 min
# 351      (2013)  2013.0     Biography,Drama,History        61.0  134 min
# 352      (2013)  2013.0     Fantasy,Horror,Thriller        64.0   91 min
# 353      (2013)  2013.0                       Drama        77.0  121 min
# 354      (2013)  2013.0                Drama,Horror        81.0  100 min
# 355      (2013)  2013.0             Biography,Drama        94.0  117 min
# 356  (I) (2013)  2013.0      Action,Biography,Drama        95.0  123 min
# 357      (2013)  2013.0        Drama,Romance,Sci-Fi        99.0  126 min
# 358      (2014)  2014.0      Action,Biography,Drama         1.0  133 min
# 359      (2014)  2014.0     Action,Adventure,Sci-Fi        13.0  123 min
# 360      (2014)  2014.0      Adventure,Drama,Sci-Fi        16.0  169 min
# 361      (2014)  2014.0  Animation,Action,Adventure        17.0  102 min
# 362      (2015)  2015.0    Action,Adventure,Fantasy         1.0  136 min
# 363      (2015)  2015.0     Action,Adventure,Sci-Fi        50.0  100 min
# 364      (2015)  2015.0          Action,Crime,Sport        81.0  114 min
# 365  (I) (2016)  2016.0          Comedy,Drama,Music        19.0  128 min
# 366      (2016)  2016.0       Action,Comedy,Fantasy        22.0  116 min
#
#             realisateur                                    titre  \
# 0         John Lasseter                                Toy Story
# 1            Ron Howard                                Apollo 13
# 2         David Fincher                                    Se7en
# 3         Stephen Herek                       Mr. Holland's Opus
# 4            Mel Gibson                               Braveheart
# 5      Barry Sonnenfeld                               Get Shorty
# 6          Michael Mann                                     Heat
# 7           Michael Bay                                 Bad Boys
# 8        Amy Heckerling                                 Clueless
# 9               Ang Lee                    Sense and Sensibility
# 10      Martin Scorsese                                   Casino
# 11         Bryan Spicer  Mighty Morphin Power Rangers: The Movie
# 12         Danny Cannon                              Judge Dredd
# 13            Jon Amiel                                  Copycat
# 14          Mike Figgis                        Leaving Las Vegas
# 15       Richard Donner                                Assassins
# 16        Brett Leonard                               Virtuosity
# 17        Carl Franklin                    Devil in a Blue Dress
# 18        Joe Chappelle    Halloween: The Curse of Michael Myers
# 19         Clive Barker                        Lord of Illusions
# 20      Roland Emmerich                         Independence Day
# 21        Cameron Crowe                            Jerry Maguire
# 22           Wes Craven                                   Scream
# 23      Jonathan Frakes                 Star Trek: First Contact
# 24             John Woo                             Broken Arrow
# 25         Edward Zwick                       Courage Under Fire
# 26          Ron Shelton                                  Tin Cup
# 27            Joel Coen                                    Fargo
# 28     Robert Rodriguez                      From Dusk Till Dawn
# 29   Billy Bob Thornton                              Sling Blade
# ..                  ...                                      ...
# 337        Rian Johnson                                   Looper
# 338          Josh Trank                                Chronicle
# 339         Len Wiseman                             Total Recall
# 340        Chris Butler                               ParaNorman
# 341        Wes Anderson                         Moonrise Kingdom
# 342          Tim Burton                            Frankenweenie
# 343        Jeff Nichols                                      Mud
# 344          Chris Buck                                   Frozen
# 345       Pierre Coffin                          Despicable Me 2
# 346      Alfonso Cuarón                                  Gravity
# 347    David O. Russell                          American Hustle
# 348     Brian Helgeland                                       42
# 349     Joseph Kosinski                                 Oblivion
# 350    John Lee Hancock                         Saving Mr. Banks
# 351       Steve McQueen                         12 Years a Slave
# 352        Fede Alvarez                                Evil Dead
# 353          John Wells                     August: Osage County
# 354     Kimberly Peirce                                   Carrie
# 355    Jean-Marc Vallée                       Dallas Buyers Club
# 356          Ron Howard                                     Rush
# 357         Spike Jonze                                      Her
# 358      Clint Eastwood                          American Sniper
# 359      Gareth Edwards                                 Godzilla
# 360   Christopher Nolan                             Interstellar
# 361        Dean DeBlois               How to Train Your Dragon 2
# 362         J.J. Abrams             Star Wars: The Force Awakens
# 363          Josh Trank                           Fantastic Four
# 364        Ericson Core                              Point Break
# 365     Damien Chazelle                               La La Land
# 366           Paul Feig                             Ghostbusters
#
#                                                    url  \
# 0    http://www.imsdb.com/Movie Scripts/Toy Story S...
# 1    http://www.imsdb.com/Movie Scripts/Apollo 13 S...
# 2    http://www.imsdb.com/Movie Scripts/Se7en Scrip...
# 3    http://www.imsdb.com/Movie Scripts/Mr. Holland...
# 4    http://www.imsdb.com/Movie Scripts/Braveheart ...
# 5    http://www.imsdb.com/Movie Scripts/Get Shorty ...
# 6    http://www.imsdb.com/Movie Scripts/Heat Script...
# 7    http://www.imsdb.com/Movie Scripts/Bad Boys Sc...
# 8    http://www.imsdb.com/Movie Scripts/Clueless Sc...
# 9    http://www.imsdb.com/Movie Scripts/Sense and S...
# 10   http://www.imsdb.com/Movie Scripts/Casino Scri...
# 11   http://www.imsdb.com/Movie Scripts/Mighty Morp...
# 12   http://www.imsdb.com/Movie Scripts/Judge Dredd...
# 13   http://www.imsdb.com/Movie Scripts/Copycat Scr...
# 14   http://www.imsdb.com/Movie Scripts/Leaving Las...
# 15   http://www.imsdb.com/Movie Scripts/Assassins S...
# 16   http://www.imsdb.com/Movie Scripts/Virtuosity ...
# 17   http://www.imsdb.com/Movie Scripts/Devil in a ...
# 18   http://www.imsdb.com/Movie Scripts/Halloween: ...
# 19   http://www.imsdb.com/Movie Scripts/Lord of Ill...
# 20   http://www.imsdb.com/Movie Scripts/Independenc...
# 21   http://www.imsdb.com/Movie Scripts/Jerry Magui...
# 22   http://www.imsdb.com/Movie Scripts/Scream Scri...
# 23   http://www.imsdb.com/Movie Scripts/Star Trek: ...
# 24   http://www.imsdb.com/Movie Scripts/Broken Arro...
# 25   http://www.imsdb.com/Movie Scripts/Courage Und...
# 26   http://www.imsdb.com/Movie Scripts/Tin Cup Scr...
# 27   http://www.imsdb.com/Movie Scripts/Fargo Scrip...
# 28   http://www.imsdb.com/Movie Scripts/From Dusk T...
# 29   http://www.imsdb.com/Movie Scripts/Sling Blade...
# ..                                                 ...
# 337  http://www.imsdb.com/Movie Scripts/Looper Scri...
# 338  http://www.imsdb.com/Movie Scripts/Chronicle S...
# 339  http://www.imsdb.com/Movie Scripts/Total Recal...
# 340  http://www.imsdb.com/Movie Scripts/ParaNorman ...
# 341  http://www.imsdb.com/Movie Scripts/Moonrise Ki...
# 342  http://www.imsdb.com/Movie Scripts/Frankenween...
# 343  http://www.imsdb.com/Movie Scripts/Mud Script....
# 344  http://www.imsdb.com/Movie Scripts/Frozen Scri...
# 345  http://www.imsdb.com/Movie Scripts/Despicable ...
# 346  http://www.imsdb.com/Movie Scripts/Gravity Scr...
# 347  http://www.imsdb.com/Movie Scripts/American Hu...
# 348  http://www.imsdb.com/Movie Scripts/42 Script.html
# 349  http://www.imsdb.com/Movie Scripts/Oblivion Sc...
# 350  http://www.imsdb.com/Movie Scripts/Saving Mr. ...
# 351  http://www.imsdb.com/Movie Scripts/12 Years a ...
# 352  http://www.imsdb.com/Movie Scripts/Evil Dead S...
# 353  http://www.imsdb.com/Movie Scripts/August: Osa...
# 354  http://www.imsdb.com/Movie Scripts/Carrie Scri...
# 355  http://www.imsdb.com/Movie Scripts/Dallas Buye...
# 356  http://www.imsdb.com/Movie Scripts/Rush Script...
# 357  http://www.imsdb.com/Movie Scripts/Her Script....
# 358  http://www.imsdb.com/Movie Scripts/American Sn...
# 359  http://www.imsdb.com/Movie Scripts/Godzilla Sc...
# 360  http://www.imsdb.com/Movie Scripts/Interstella...
# 361  http://www.imsdb.com/Movie Scripts/How to Trai...
# 362  http://www.imsdb.com/Movie Scripts/Star Wars: ...
# 363  http://www.imsdb.com/Movie Scripts/Fantastic F...
# 364  http://www.imsdb.com/Movie Scripts/Point Break...
# 365  http://www.imsdb.com/Movie Scripts/La La Land ...
# 366  http://www.imsdb.com/Movie Scripts/Ghostbuster...
#
#                                             url_script categorie1 categorie2  \
# 0          http://www.imsdb.com/scripts/Toy-Story.html  Animation  Adventure
# 1          http://www.imsdb.com/scripts/Apollo-13.html  Adventure      Drama
# 2              http://www.imsdb.com/scripts/Se7en.html      Crime      Drama
# 3    http://www.imsdb.com/scripts/Mr.-Holland's-Opu...      Drama      Music
# 4         http://www.imsdb.com/scripts/Braveheart.html  Biography      Drama
# 5         http://www.imsdb.com/scripts/Get-Shorty.html     Comedy      Crime
# 6               http://www.imsdb.com/scripts/Heat.html     Action      Crime
# 7           http://www.imsdb.com/scripts/Bad-Boys.html     Action     Comedy
# 8           http://www.imsdb.com/scripts/Clueless.html     Comedy    Romance
# 9    http://www.imsdb.com/scripts/Sense-and-Sensibi...      Drama    Romance
# 10            http://www.imsdb.com/scripts/Casino.html  Biography      Crime
# 11   http://www.imsdb.com/scripts/Mighty-Morphin-Po...     Action  Adventure
# 12       http://www.imsdb.com/scripts/Judge-Dredd.html     Action      Crime
# 13           http://www.imsdb.com/scripts/Copycat.html      Crime      Drama
# 14   http://www.imsdb.com/scripts/Leaving-Las-Vegas...      Drama    Romance
# 15         http://www.imsdb.com/scripts/Assassins.html     Action      Crime
# 16        http://www.imsdb.com/scripts/Virtuosity.html     Action      Crime
# 17   http://www.imsdb.com/scripts/Devil-in-a-Blue-D...      Crime      Drama
# 18   http://www.imsdb.com/scripts/Halloween-The-Cur...     Horror   Thriller
# 19   http://www.imsdb.com/scripts/Lord-of-Illusions...     Horror    Mystery
# 20   http://www.imsdb.com/scripts/Independence-Day....     Action  Adventure
# 21     http://www.imsdb.com/scripts/Jerry-Maguire.html     Comedy      Drama
# 22            http://www.imsdb.com/scripts/Scream.html     Horror    Mystery
# 23   http://www.imsdb.com/scripts/Star-Trek-First-C...     Action  Adventure
# 24      http://www.imsdb.com/scripts/Broken-Arrow.html     Action      Crime
# 25   http://www.imsdb.com/scripts/Courage-Under-Fir...     Action      Drama
# 26           http://www.imsdb.com/scripts/Tin-Cup.html     Comedy      Drama
# 27             http://www.imsdb.com/scripts/Fargo.html      Crime      Drama
# 28   http://www.imsdb.com/scripts/From-Dusk-Till-Da...     Action      Crime
# 29       http://www.imsdb.com/scripts/Sling-Blade.html      Drama        NaN
# ..                                                 ...        ...        ...
# 337           http://www.imsdb.com/scripts/Looper.html     Action      Crime
# 338        http://www.imsdb.com/scripts/Chronicle.html     Sci-Fi   Thriller
# 339     http://www.imsdb.com/scripts/Total-Recall.html     Action  Adventure
# 340       http://www.imsdb.com/scripts/ParaNorman.html  Animation  Adventure
# 341  http://www.imsdb.com/scripts/Moonrise-Kingdom....  Adventure     Comedy
# 342    http://www.imsdb.com/scripts/Frankenweenie.html  Animation     Comedy
# 343              http://www.imsdb.com/scripts/Mud.html      Drama        NaN
# 344           http://www.imsdb.com/scripts/Frozen.html  Animation  Adventure
# 345  http://www.imsdb.com/scripts/Despicable-Me-2.html  Animation  Adventure
# 346          http://www.imsdb.com/scripts/Gravity.html  Adventure      Drama
# 347  http://www.imsdb.com/scripts/American-Hustle.html      Crime      Drama
# 348               http://www.imsdb.com/scripts/42.html  Biography      Drama
# 349         http://www.imsdb.com/scripts/Oblivion.html     Action  Adventure
# 350  http://www.imsdb.com/scripts/Saving-Mr.-Banks....  Biography     Comedy
# 351  http://www.imsdb.com/scripts/12-Years-a-Slave....  Biography      Drama
# 352        http://www.imsdb.com/scripts/Evil-Dead.html    Fantasy     Horror
# 353  http://www.imsdb.com/scripts/August-Osage-Coun...      Drama        NaN
# 354           http://www.imsdb.com/scripts/Carrie.html      Drama     Horror
# 355  http://www.imsdb.com/scripts/Dallas-Buyers-Clu...  Biography      Drama
# 356             http://www.imsdb.com/scripts/Rush.html     Action  Biography
# 357              http://www.imsdb.com/scripts/Her.html      Drama    Romance
# 358  http://www.imsdb.com/scripts/American-Sniper.html     Action  Biography
# 359         http://www.imsdb.com/scripts/Godzilla.html     Action  Adventure
# 360     http://www.imsdb.com/scripts/Interstellar.html  Adventure      Drama
# 361  http://www.imsdb.com/scripts/How-to-Train-Your...  Animation     Action
# 362  http://www.imsdb.com/scripts/Star-Wars-The-For...     Action  Adventure
# 363   http://www.imsdb.com/scripts/Fantastic-Four.html     Action  Adventure
# 364      http://www.imsdb.com/scripts/Point-Break.html     Action      Crime
# 365       http://www.imsdb.com/scripts/La-La-Land.html     Comedy      Drama
# 366     http://www.imsdb.com/scripts/Ghostbusters.html     Action     Comedy
#
#     categorie3
# 0       Comedy
# 1      History
# 2      Mystery
# 3          NaN
# 4      History
# 5     Thriller
# 6        Drama
# 7        Crime
# 8          NaN
# 9          NaN
# 10       Drama
# 11      Family
# 12      Sci-Fi
# 13     Mystery
# 14         NaN
# 15    Thriller
# 16      Sci-Fi
# 17     Mystery
# 18         NaN
# 19    Thriller
# 20      Sci-Fi
# 21     Romance
# 22         NaN
# 23       Drama
# 24    Thriller
# 25     Mystery
# 26     Romance
# 27    Thriller
# 28      Horror
# 29         NaN
# ..         ...
# 337      Drama
# 338        NaN
# 339    Mystery
# 340     Comedy
# 341      Drama
# 342     Family
# 343        NaN
# 344     Comedy
# 345     Comedy
# 346     Sci-Fi
# 347        NaN
# 348      Sport
# 349    Mystery
# 350      Drama
# 351    History
# 352   Thriller
# 353        NaN
# 354        NaN
# 355        NaN
# 356      Drama
# 357     Sci-Fi
# 358      Drama
# 359     Sci-Fi
# 360     Sci-Fi
# 361  Adventure
# 362    Fantasy
# 363     Sci-Fi
# 364      Sport
# 365      Music
# 366    Fantasy
#
# [367 rows x 12 columns]

# %%
print('Only remains %s movies.'%(len(titles)))
# Out:
# Only remains 367 movies.

# %%
#les différentes catégories:
l=list(titles.categorie1)+list(titles.categorie2)+list(titles.categorie3)
set(l)
# Out:
# {nan,
#  u'Action',
#  u'Adventure',
#  u'Animation',
#  u'Biography',
#  u'Comedy',
#  u'Crime',
#  u'Drama',
#  u'Family',
#  u'Fantasy',
#  u'History',
#  u'Horror',
#  u'Music',
#  u'Musical',
#  u'Mystery',
#  u'Romance',
#  u'Sci-Fi',
#  u'Sport',
#  u'Thriller',
#  u'War',
#  u'Western'}

# %% [markdown]
# - ### Analysis Functions

# %%
def clean_character(char):
    if isinstance(char,unicode) or isinstance(char,str):
        char=char.replace('\n','').replace('*','').replace('O/S','').replace('V.O.','')
        char=re.sub(' +',' ',char)
        if 'CONTINUED' in char:
            return u'CONTINUED'
        if '(' in char or ')' in char:
            regex = re.compile(".*?\((.*?)\)")
            to_delete = re.findall(regex, char)
            for e in to_delete:
                char=char.replace('(%s)' %e,'')
            if char=='' or ')'in char:
                return None
            else:
                return char.rstrip() #delete lose end white space
        else:
            return char.rstrip()
    else:
        return None
    
def continued_speech(char_vector):
    char_vector=list(char_vector)
    while 'CONTINUED' in char_vector:
        count=0
        idx=char_vector.index("CONTINUED")
        for element in char_vector[idx-1::-1]:
            #if (isinstance(element,str) or isinstance(element,unicode)) and (element!='unknown'):
            if element and element!='unknown':
                char_vector[idx]=char_vector[idx-1-count]
                #print('Replaces CONTINUED with %s' %(char_vector[idx-1-count]))
                break
            count=count+1
            if count==len(char_vector[idx-1::-1]):
                char_vector[idx]='unknown'
                break
    return char_vector


# to remove outliers
def principal_characters(char_dic):
    mean = 0
    for i, j in char_dic.items():
        mean = mean + j
    mean = mean / len(char_dic)

    stddev = 0
    for i, j in char_dic.items():
        stddev = stddev + (j - mean)*(j - mean)
    stddev = stddev / len(char_dic)
    stddev = math.sqrt(stddev)

    temp = {}
    for i, j in char_dic.items():
        if (math.fabs(j - mean) < 3*stddev):
            temp[i] = j
    print(stddev,mean)
    return temp


def char_analysis(df):
    d=dict(Counter(df['character_clean']))
    d={key: value for key, value in d.items() 
                 if key}
    charlist = sorted(d)
    gender = dict()
    lines=[element.split('\n') for element in df['text']]
    lines=[item for sublist in lines for item in sublist]

    for char in charlist:
        m, f, p = 0, 0, 0 
        for i in range(len(lines)):
            srch = re.search(char, lines[i], re.I)
            if not srch:
                continue
            if srch.group().isupper():
                continue
            else:
                k, k_range = -1, 2
                while k + i + 1 < len(lines):
                    k = k + 1
                    m = m + len(re.findall("\s+he", lines[k+i], re.I)) + len(re.findall("\s+him", lines[k+i], re.I))
                    f = f + len(re.findall("\s+she", lines[k+i], re.I)) + len(re.findall("\s+her", lines[k+i], re.I))
                    if lines[k+i].isupper():
                        break
                    if k >= k_range:
                        break
                k, k_range = -1, 4
                while k + i + 1 < len(lines):
                    k = k + 1
                    m1, m2, m3, m4 = re.search("\s+he", lines[k+i], re.I), re.search("\s+him", lines[k+i], re.I),\
                                    re.search("\s+she", lines[k+i], re.I), re.search("\s+her", lines[k+i], re.I)
                    if m1:
                        if m2:
                            mc = min(m1.span()[0], m2.span()[0])
                        else:
                            mc = m1.span()[0]
                    else:
                        mc = len(lines[k+i])
                    if m3:
                        if m4:
                            fc = min(m3.span()[0], m4.span()[0])
                        else:
                            fc = m3.span()[0]
                    else:
                        fc = len(lines[k+i])
                    if not(m1 or m2 or m3 or m4):
                        continue
                    else:
                        if (mc < fc):
                            p = p - 1
                        else:
                            p = p + 1
                        break
                    if lines[k+i].isupper():
                        break
                    if k >= k_range:
                        break
        gender[char] = m, f, p

    for char, g in gender.items():
        g_score = 2*g[1] - g[0] 
        g_sum = g[1]+g[0]
        g_score = g_score
        if (g_sum == 0.0) :#or (0 == 1):
            #print(char+" Undetermined ")
            gender[char] = "?" #0, 0, -1
        elif g_score > 0:
            #print(char+" Female "+str(g[0])+","+str(g[1])+","+str(g[2])+","+str(g_score))
            gender[char] = "F" #0, 0, 1
        else:
            #print(char+" Male", " ", str(g[0])+","+str(g[1])+","+str(g[2])+","+str(g_score))
            gender[char] = "M" #0, 0, 0
            
    return d,gender

# %% [markdown]
# - ### Script loader and parser

# %%
def get_all_bygenre(genre,titles):
    urls = list(titles[(titles['categorie1']==genre) | (titles['categorie2']==genre)]['url_script'])
    output=[]
    nb_of_errors=0
    for url in urls:
        path='../data/script/%s/' %(genre.lower())
        name=url.replace(':','').replace('/','')
        name_ = titles[titles['url_script']==url]['titre']
        name_ = list(name_)[0]
        try:
            test=parse(url,path+'raw/',name_)
            try:
                #print(df['text'][0].split('\n')[0])
                vec=test['character'].apply(lambda x :clean_character(x))
                test['character_clean']=continued_speech(vec)
                char,gender=char_analysis(test)
                #output_actions_.append(char)
                #create gender column in dataframe:
                test['gender']=[gender.get(item,item)  for item in list(test['character_clean'])]
                if not os.path.exists(path+'clean/'):
                    os.makedirs(path+'clean/')
                test.to_csv(path+'clean/'+name_+'.csv',sep='|',encoding='latin1')
            except Exception as e:
                print('------Caught exception : %s' %e)
                nb_of_errors=nb_of_errors+1
            output.append(test)
        except Exception as e:
            print(e)
            nb_of_errors=nb_of_errors+1
    return output

def load_bygenre(genre):
    genre=genre.lower()
    mypath = "../data/script/%s/clean/" %(genre)
    onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
    output=[]
    for element in onlyfiles:
        output.append(pd.read_csv(mypath+element,sep='|',encoding='latin1',index_col=0))
    return output

def number_speech(df):
    m=len(df[df['gender']=='M'])
    f=len(df[df['gender']=='F'])
    return m,f

def nb_char_bygender(df):
    #print(set(df[df['gender']=='M']['character_clean']))
    m=len(set(df[df['gender']=='M']['character_clean']))
    f=len(set(df[df['gender']=='F']['character_clean']))
    return m,f

def plot_piechart(m,f,param,genre):
    #m : list of int
    #f : list of int
    #genre : string of genre
    #param : string of what we want to represent
    m=sum(m)
    f=sum(f)

    labels = ["M","F"]
    sizes = [m, f]
    colors = ['lightskyblue', 'pink']
    plt.figure(figsize=(8,8))
    plt.pie(sizes, labels=labels, colors=colors,
            autopct='%1.1f%%', shadow=True, startangle=140)
    plt.title("Repartition des %s dans les films de %s" %(param,genre)) 
    plt.axis('equal')
    plt.show()

# %% [raw]
# liste=[ u'Action',
#  u'Adventure',
#  u'Animation',
#  u'Biography',
#  u'Comedy',
#  u'Crime',
#  u'Drama',
#  u'Family',
#  u'Fantasy',
#  u'History',
#  u'Horror',
#  u'Music',
#  u'Musical',
#  u'Mystery',
#  u'Romance',
#  u'Sci-Fi',
#  u'Sport',
#  u'Thriller',
#  u'War',
#  u'Western']
#
# for element in liste:
#     get_all_bygenre(element,titles)

# %%
#plot year evolution

# %%
genre='Thriller'
dfs = load_bygenre(genre)
m=[]
f=[]
m_nb=[]
f_nb=[]
for df in dfs:
    #print(df.head(1))
    m.append(number_speech(df)[0])
    f.append(number_speech(df)[1])
    m_nb.append(nb_char_bygender(df)[0])
    f_nb.append(nb_char_bygender(df)[1])

plot_piechart(m,f,'repliques',genre)
plot_piechart(m_nb,f_nb,"personnages",genre)
# Out:
#   character                                               text     type  \
# 0       NaN  OCEAN'S TWELVE\nWritten by\nGeorge Nolfi\nROUG...  unknown
#
#   character_clean gender
# 0             NaN    NaN
#   character                                               text     type  \
# 0       NaN  BLACK SWAN\nWritten by\nMark Heyman, Andres He...  unknown
#
#   character_clean gender
# 0             NaN    NaN
#   character                                               text     type  \
# 0       NaN  OCEAN'S 11\nscreenplay by\nTed Griffin\nbased ...  unknown
#
#   character_clean gender
# 0             NaN    NaN
#   character                                               text     type  \
# 0       NaN  FINAL DESTINATION 2\nBy J. Mackye Gruber and E...  unknown
#
#   character_clean gender
# 0             NaN    NaN
#   character                                               text     type  \
# 0       NaN  SYRIANA\nWritten by\nStephen Gaghan\nBased on ...  unknown
#
#   character_clean gender
# 0             NaN    NaN
#   character                   text      type character_clean gender
# 0       NaN  BRINGING OUT THE DEAD  location             NaN    NaN
#   character                                               text     type  \
# 0       NaN  WHEN A STRANGER CALLS\nWritten by\nSteve Feke ...  unknown
#
#   character_clean gender
# 0             NaN    NaN
#   character                                               text  \
# 0       NaN  FADE IN:\n1    INT. DERELICT HOUSE - DAY >\t1\...
#
#               type character_clean gender
# 0  stage direction             NaN    NaN
#   character                                               text     type  \
# 0       NaN  CHRONICLE\nWritten by\nMax Landis\nBased on a ...  unknown
#
#   character_clean gender
# 0             NaN    NaN
#   character                                           text     type  \
# 0       NaN  Jackie Brown\nScreenplay by Quentin Tarantino  unknown
#
#   character_clean gender
# 0             NaN    NaN
#   character                                            text     type  \
# 0       NaN  FLIGHT\nWritten by\nJohn Gatins\nDec. 12, 2011  unknown
#
#   character_clean gender
# 0             NaN    NaN
#   character                          text     type character_clean gender
# 0       NaN  PHONE BOOTH\nby\nLarry Cohen  unknown             NaN    NaN
#   character                                               text     type  \
# 0       NaN  ANGELS & DEMONS\nWritten by\nAkiva Goldsman\nA...  unknown
#
#   character_clean gender
# 0             NaN    NaN

# %%
genre='Romance'
dfs = load_bygenre(genre)
m=[]
f=[]
m_nb=[]
f_nb=[]
for df in dfs:
    m.append(number_speech(df)[0])
    f.append(number_speech(df)[1])
    m_nb.append(nb_char_bygender(df)[0])
    f_nb.append(nb_char_bygender(df)[1])

plot_piechart(m,f,'repliques',genre)
plot_piechart(m_nb,f_nb,"personnages",genre)

# %%
i=1
male_nb_speech=len(output_actions[i][output_actions[i]['gender']=='M'])
female_nb_speech=len(output_actions[i][output_actions[i]['gender']=='F'])

 
# Data to plot
labels = ["M","F"]
sizes = [male_nb_speech, female_nb_speech]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Repartition des repliques dans %s' %output_actions[i]['text'][0].split('\n')[0]) 
plt.axis('equal')
plt.show()

# %%
i=10
male_nb_speech=len(output_actions[i][output_actions[i]['gender']=='M'])
female_nb_speech=len(output_actions[i][output_actions[i]['gender']=='F'])

 
# Data to plot
labels = ["M","F"]
sizes = [male_nb_speech, female_nb_speech]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Repartition des repliques dans %s' %output_actions[i]['text'][0].split('\n')[0]) 
plt.axis('equal')
plt.show()

# %%
# %%time
romances_url = list(titles[(titles['categorie1']=='Romance') | (titles['categorie2']=='Romance')]['url_script'])
output_romances=[]
nb_of_errors=0
for url in romances_url:
    path='../data/script/romance/'
    name=url.replace(':','').replace('/','')
    try:
        test=parse(url,path+'raw/',name)
        try:
            #print(df['text'][0].split('\n')[0])
            vec=test['character'].apply(lambda x :clean_character(x))
            test['character_clean']=continued_speech(vec)
            char,gender=char_analysis(test)
            #output_actions_.append(char)
            #create gender column in dataframe:
            test['gender']=[gender.get(item,item)  for item in list(test['character_clean'])]
            if not os.path.exists(path+'clean/'):
                os.makedirs(path+'clean/')
            test.to_csv(path+'clean/'+name+'.csv',sep='|',encoding='latin1')
        except Exception as e:
            print('------Caught exception : %s' %e)
            nb_of_errors=nb_of_errors+1
        output_romances.append(test)
    except Exception as e:
        print(e)
        nb_of_errors=nb_of_errors+1

# %%
print('The number of errors is %s out of a total %s.' %(nb_of_errors,len(romances_url)))

# %%
#construct character info and add it to dataframe
output_romances_=[]
male_nb_speech=[]
female_nb_speech=[]
for df in output_romances:
    try:
        #print(df['text'][0].split('\n')[0])
        test=df['character'].apply(lambda x :clean_character(x))
        df['character_clean']=continued_speech(test)
        char,gender=char_analysis(df)
        output_romances_.append(char)
        #create gender column in dataframe:
        df['gender']=[gender.get(item,item)  for item in list(df['character_clean'])]
        male_nb_speech.append(len(df[df['gender']=='M']))
        female_nb_speech.append(len(df[df['gender']=='F']))
    except Exception as e:
        print('------Caught exception : %s' %e)
        nb_of_errors=nb_of_errors+1

# %%
print('The number of errors is %s out of a total %s.' %(nb_of_errors,len(romances_url)))

# %%
m=sum(male_nb_speech)
f=sum(female_nb_speech)

 
# Data to plot
labels = ["M","F"]
sizes = [m, f]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Repartition des repliques dans les films romantiques") 
plt.axis('equal')
plt.show()

# %%
m=len(actions_url)
f=len(romances_url)

 
# Data to plot
labels = ["Actions","Romances"]
sizes = [m, f]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Ratio Actions-Romances parmis les top100") 
plt.axis('equal')
plt.show()

# %%
def find(df,to_find):
    count=0
    for element in df['text']:
        if to_find in normalize_text(element):
            count+=1
    return count

def find_female_in(df,to_find):
    count_female=0
    count_total=0
    idx=0
    try:
        list_female=list(df[df['gender']=='F']['character_clean'].apply(lambda x : normalize_text(x)))
        list_female=list(set(list_female))
        #list_female.append('she').append('her')
    except Exception as e:
        try:
            
            for element in df['text']:
                if to_find in normalize_text(element):
                    count_total+=1
                    if 'she' in element or "her" in element:
                        count_female+=1
            return count_female,count_total
        except Exception as ex:
            print('Warning : %s.' %(ex))
            return 0,0
    list_female.append('she')
    list_female.append("her")
    for element in df['text']:
        if to_find in normalize_text(element):
            count_total+=1
            for indicator in list_female: #she or her
                if indicator in element:
                    count_female+=1
                    break
        idx+=1
    return count_female,count_total

def find_any(df,l):
    for element in df['text']:
        for room in l:
            if room in normalize_text(element):
                print("Found %s" %room)
    return

def normalize_text(text):
    text = text.lower()
    normal = unicodedata.normalize('NFKD', text).encode('ASCII', 'ignore')
    return normal

# %%
l=['KITCHEN','Kitchen','kitchen','bed','BED','BEDROOM','Bed','Bedroom','bedroom','BATH','bath','Bath','BATHROOM',
  'Bathroom','bathroom','toilet','TOILET','Toilet']
l_norm=['kitchen','bed','bedroom','bath','bathroom','toilet']

# %% [raw]
# for df in output_romances:
#     find_any(df,l_norm)

# %%
import random
kitchen_count_action=0
kitchen_count_romance=0
rand_idx = random.sample(range(0,len(output_actions)),  len(output_romances))
for df in [output_actions[i] for i in rand_idx]:
    try:
        kitchen_count_action += find(df,'kitchen')
    except Exception as e:
        print(e)
for df in output_romances:
    try:
        kitchen_count_romance += find(df,'kitchen')
    except Exception as e:
        print(e)

# %%
# Data to plot
labels = ["in actions","in romance"]
sizes = [kitchen_count_action, kitchen_count_romance]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Repartition de la presence des cuisines dans les films actions-romances") 
plt.axis('equal')
plt.show()

print('Actions: %s de présence cuisines' %(kitchen_count_action))
print('Romances: %s  de présence cuisines' %(kitchen_count_romance))

# %%
kitchen_count_action_f=0
kitchen_count_action =0
kitchen_count_romance_f=0
kitchen_count_romance = 0
for df in output_actions:
    kitchen_count_action_f += find_female_in(df,'kitchen')[0]
    kitchen_count_action += find_female_in(df,'kitchen')[1]
for df in output_romances:
    kitchen_count_romance_f += find_female_in(df,'kitchen')[0]
    kitchen_count_romance += find_female_in(df,'kitchen')[1]

# %%
# Data to plot
labels = ["in actions","in romance"]
sizes = [kitchen_count_action_f, kitchen_count_romance_f]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Repartition de la presence des cuisines dans les films actions-romances") 
plt.axis('equal')
plt.show()

print('Actions: %s femmes & cuisines' %(kitchen_count_action_f))
print('Romances: %s femmes & cuisines' %(kitchen_count_romance_f))

# %%
# Data to plot
labels = ["other","women"]
sizes = [kitchen_count_action - kitchen_count_action_f, kitchen_count_action_f]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Repartition H/F & cuisne dans les films d'actions") 
plt.axis('equal')
plt.show()

print(' %s femmes & cuisines' %(kitchen_count_action_f))
print('%s autres & cuisines' %(kitchen_count_action- kitchen_count_action_f))

# %%
# Data to plot
labels = ["other","women"]
sizes = [kitchen_count_romance - kitchen_count_romance_f, kitchen_count_romance_f]
colors = ['lightskyblue', 'pink']
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Repartition H/F & cuisine dans les films d'actions") 
plt.axis('equal')
plt.show()

print('Actions: %s femmes & cuisines' %(kitchen_count_action_f))
print('Romances: %s femmes & cuisines' %(kitchen_count_romance_f))
