# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
#Generate lists
A=[]
B=[]
C=[]
D=[]
E=[]
F=[]
G=[]

# %%
year="2000"
request_headers = {
"Accept-Language": "en-US,en;q=0.5"}
for page in "1","2":
    wiki = "http://www.imdb.com/search/title?release_date="+year+"&sort=boxoffice_gross_us,desc&page="+page+"&ref_=adv_prv"
    
    #Query the website and return the html to the variable 'page'
    page = urlopen(wiki)
    soup = BeautifulSoup(page,"html.parser")
    
    for film in soup.body.div.div.find('div', class_='pagecontent').find('div', class_='redesign').div.div.div.find('div', class_='lister-list').findAll('div', class_='lister-item mode-advanced'):
        A.append(film.find('div', class_='lister-item-content').h3.find('span', class_='lister-item-index unbold text-primary').string)
        B.append(film.find('div', class_='lister-item-content').h3.a.string)
        C.append(film.find('div', class_='lister-item-content').h3.find('span', class_='lister-item-year text-muted unbold').string)
        D.append(film.find('div', class_='lister-item-content').p.span.string)

# %%
#import pandas to convert list to data frame
import pandas as pd
df=pd.DataFrame(A,columns=['classement'])
df['titre']=B
df['annee']=C
df['categorie']=D
df
# Out:
#    classement                                        titre       annee  \
# 0          1.                                    Le Grinch      (2000)
# 1          2.                                Seul au monde      (2000)
# 2          3.                  M-I:2 Mission: Impossible 2      (2000)
# 3          4.                                    Gladiator      (2000)
# 4          5.                    Ce que veulent les femmes      (2000)
# 5          6.                            En pleine tempête      (2000)
# 6          7.                         Mon beau-père et moi      (2000)
# 7          8.                                        X-Men      (2000)
# 8          9.                                  Scary Movie      (2000)
# 9         10.                                   Apparences      (2000)
# 10        11.                                    Dinosaure      (2000)
# 11        12.                              Tigre et dragon      (2000)
# 12        13.           Erin Brockovich, seule contre tous      (2000)
# 13        14.               Charlie et ses drôles de dames      (2000)
# 14        15.                                      Traffic      (2000)
# 15        16.                         La famille Foldingue      (2000)
# 16        17.                                    Big Mamma      (2000)
# 17        18.                     Le plus beau des combats      (2000)
# 18        19.         The patriot: Le chemin de la liberté      (2000)
# 19        20.                               Miss Détective      (2000)
# 20        21.                                  Chicken Run      (2000)
# 21        22.                           60 secondes chrono      (2000)
# 22        23.                                   Incassable      (2000)
# 23        24.                               Fou(s) d'Irène      (2000)
# 24        25.                                Space Cowboys      (2000)
# 25        26.                     Kuzco, l'empereur mégalo      (2000)
# 26        27.                                     Scream 3      (2000)
# 27        28.                                        U-571      (2000)
# 28        29.                Les Razmoket à Paris, le film      (2000)
# 29        30.                                   Family Man      (2000)
# ..        ...                                          ...         ...
# 70        71.                               Mon chien Skip      (2000)
# 71        72.                        Où le coeur nous mène      (2000)
# 72        73.                            Un monde meilleur      (2000)
# 73        74.                                 Dracula 2001      (2000)
# 74        75.                               Droit au coeur      (2000)
# 75        76.                                    L'échange      (2000)
# 76        77.                              Presque célèbre      (2000)
# 77        78.                   La légende de Bagger Vance      (2000)
# 78        79.                           L'art de la guerre      (2000)
# 79        80.             Snatch - Tu braques ou tu raques      (2000)
# 80        81.                                       L'élue      (2000)
# 81        82.                                  The Watcher  (I) (2000)
# 82        83.                            Love & Basketball      (2000)
# 83        84.                                High Fidelity      (2000)
# 84        85.           Blair Witch 2: Le Livre des ombres      (2000)
# 85        86.          Les aventures de Rocky & Bullwinkle      (2000)
# 86        87.                                      Memento      (2000)
# 87        88.                                  Nurse Betty      (2000)
# 88        89.                                  Piège fatal      (2000)
# 89        90.                                   Titan A.E.      (2000)
# 90        91.                                 Billy Elliot      (2000)
# 91        92.  Battlefield Earth - Terre champ de bataille      (2000)
# 92        93.                Urban Legend 2: Coup de grâce      (2000)
# 93        94.                               Boys and Girls      (2000)
# 94        95.                                      In Love      (2000)
# 95        96.                                  Wonder Boys      (2000)
# 96        97.                    Michael Jordan to the Max      (2000)
# 97        98.                               Bêtes de scène      (2000)
# 98        99.                                Manipulations      (2000)
# 99       100.                                Planète rouge      (2000)
#
#        categorie
# 0   Tous publics
# 1   Tous publics
# 2   Tous publics
# 3   Tous publics
# 4   Tous publics
# 5   Tous publics
# 6   Tous publics
# 7   Tous publics
# 8             12
# 9             12
# 10  Tous publics
# 11  Tous publics
# 12  Tous publics
# 13  Tous publics
# 14  Tous publics
# 15  Tous publics
# 16  Tous publics
# 17  Tous publics
# 18  Tous publics
# 19  Tous publics
# 20  Tous publics
# 21  Tous publics
# 22            12
# 23  Tous publics
# 24  Tous publics
# 25  Tous publics
# 26            12
# 27  Tous publics
# 28  Tous publics
# 29  Tous publics
# ..           ...
# 70  Tous publics
# 71  Tous publics
# 72  Tous publics
# 73            12
# 74  Tous publics
# 75  Tous publics
# 76  Tous publics
# 77  Tous publics
# 78  Tous publics
# 79  Tous publics
# 80            12
# 81  Tous publics
# 82         PG-13
# 83  Tous publics
# 84            12
# 85  Tous publics
# 86  Tous publics
# 87  Tous publics
# 88            12
# 89  Tous publics
# 90  Tous publics
# 91  Tous publics
# 92  Tous publics
# 93  Tous publics
# 94  Tous publics
# 95  Tous publics
# 96        46 min
# 97  Tous publics
# 98  Tous publics
# 99  Tous publics
#
# [100 rows x 4 columns]
