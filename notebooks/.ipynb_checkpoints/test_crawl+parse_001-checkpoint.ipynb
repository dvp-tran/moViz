# %% [markdown]
# # Movie script crawler and parser

# %% [markdown]
# - ## Imports

# %%
import os, sys, json, re, argparse, urllib2, html5lib
from bs4 import BeautifulSoup, Tag, UnicodeDammit
import pandas as pd
from pandas.io.json import json_normalize
import time
# Out:
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %% [markdown]
# - ### Extract functions

# %% [markdown]
# - ### Script loader and parser

# %%
#load script
script_url = 'http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html'
is_webpage_fetched = False
request_headers = {
"Accept-Language": "en-US,en;q=0.5",
"User-Agent": "Mozilla/5.0 (Windows NT 10.0; WOW64; rv:40.0) Gecko/20100101 Firefox/40.0",
#"Connection": "keep-alive" 
}


while not is_webpage_fetched:
    # get the script's URL from the parameters if it was passed
    try:
        request = urllib2.Request(script_url, headers=request_headers)
        contents = urllib2.urlopen(request)#.read()
        soup = BeautifulSoup(contents, 'lxml')
        print('Detected encoding is ', soup.original_encoding)
        is_webpage_fetched = True
    except urllib2.URLError as err:
        print('Catched an URLError while fetching the URL:', err)
        pass
    except ValueError as err:
        print('Catched a ValueError while fetching the URL:', err)
        pass
    except:
        print('Catched an unrecognized error')
        raise
    else:
        #script_text = soup.find("td", class_="scrtext").find("pre")
        script_text = soup.find("pre")

        if( script_text.find("pre") ):
            print('Found a <pre> inside the <pre>')
            script_text = script_text.find("pre")

        print('Parsing {} and extracting the first <pre> resulted in the following text:'.format(script_url))
        print(str(script_text)[:256])
        is_webpage_fetched = True




print('\n \n OK, we have the text. A few questions before we get parsing:')
# Out:
# ('Detected encoding is ', u'iso-8859-1')
# Parsing http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html and extracting the first <pre> resulted in the following text:
# <pre>
#
#
# <b>                               STAR WARS: THE FORCE AWAKENS
# </b>
#
#
#
#
#                                        Written by
#
#
#                       Lawrence Kasda
#
#
#  OK, we have the text. A few questions before we get parsing:

# %% [markdown]
# - ### White space analysis

# %%
def white_space_analysis(script_text):
    spaces_regex = re.compile("^(\s*).*")
    space_vector=[]

    for block in script_text.descendants:
        # Si block est une instance de bs4.Tag, il est entouré de balises HTML
        # Le prochain block contiendra le même texte sans les balises
        # Donc on continue sans parser ce bloc
        if(isinstance(block, Tag)):
            continue

        # UnicodeDammit converts any string to UTF-8
        # does not work so well
        block = UnicodeDammit(block, soup.original_encoding).unicode_markup
        # remove leading and ending end of lines
        block = block.strip('\n').strip('\r\n')

        # if the block doesn't have any text, skip it
        if( re.search('\w', block) == None ):
            continue

        for line in block.split('\n'):
            stripped_line = line.strip(' \n\t\r')
            if( re.search('\w', line) == None ):
                continue    
            # Counting the number of spaces at the beginning of the line
            spmatch = spaces_regex.search(line)
            space_vector.append(len(spmatch.group(1)))

    return space_vector

# %%
space_vector = white_space_analysis(script_text)

# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

space_vector_=np.array(space_vector)
plt.figure(figsize=(20,10))
plt.hist(space_vector_, bins=np.arange(space_vector_.min(), space_vector_.max()+1)-0.5)
plt.title('White space (head of line) distributions')
plt.xlabel('Number of white spaces')
plt.ylabel('Count')

# %%
from collections import Counter
Counter(space_vector)

    #all the occurences except the top 3 are occurences from global stage references
# Out:
# Counter({10: 2041,
#          11: 1565,
#          22: 1,
#          23: 1,
#          25: 88,
#          26: 947,
#          31: 1,
#          36: 1,
#          39: 2,
#          40: 1})

# %%
sorted(Counter(space_vector),key=Counter(space_vector).get,reverse=True)
# Out:
# [10, 11, 26, 25, 39, 36, 40, 22, 23, 31]

# %% [markdown]
# ## Parsing functions

# %%
def get_script(url):
    #load script
    script_url = url
    is_webpage_fetched = False
    request_headers = {
    "Accept-Language": "en-US,en;q=0.5",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; WOW64; rv:40.0) Gecko/20100101 Firefox/40.0",
    #"Connection": "keep-alive" 
    }


    while not is_webpage_fetched:
        # get the script's URL from the parameters if it was passed
        try:
            request = urllib2.Request(script_url, headers=request_headers)
            contents = urllib2.urlopen(request)#.read()
            soup = BeautifulSoup(contents, 'lxml')
            print('Detected encoding is ', soup.original_encoding)
            is_webpage_fetched = True
        except urllib2.URLError as err:
            print('Catched an URLError while fetching the URL:', err)
            pass
        except ValueError as err:
            print('Catched a ValueError while fetching the URL:', err)
            pass
        except:
            print('Catched an unrecognized error')
            raise
        else:
            #script_text = soup.find("td", class_="scrtext").find("pre")
            script_text = soup.find("pre")

            if( script_text.find("pre") ):
                print('Found a <pre> inside the <pre>')
                script_text = script_text.find("pre")
            is_webpage_fetched = True
    print('Getting script @ %s.' %(url))
    return script_text


def white_space_analysis(script_text):
    spaces_regex = re.compile("^(\s*).*")
    space_vector=[]

    for block in script_text.descendants:
        # Si block est une instance de bs4.Tag, il est entouré de balises HTML
        # Le prochain block contiendra le même texte sans les balises
        # Donc on continue sans parser ce bloc
        if(isinstance(block, Tag)):
            continue

        # UnicodeDammit converts any string to UTF-8
        # does not work so well
        block = UnicodeDammit(block, soup.original_encoding).unicode_markup
        # remove leading and ending end of lines
        block = block.strip('\n').strip('\r\n')

        # if the block doesn't have any text, skip it
        if( re.search('\w', block) == None ):
            continue

        for line in block.split('\n'):
            stripped_line = line.strip(' \n\t\r')
            if( re.search('\w', line) == None ):
                continue    
            # Counting the number of spaces at the beginning of the line
            spmatch = spaces_regex.search(line)
            space_vector.append(len(spmatch.group(1)))

    return space_vector


def identify_usual_spaces(space_vector):
    a=Counter(space_vector)
    b=sorted(a,key=a.get,reverse=True)
    ratio=float((a[b[0]]+a[b[1]]+a[b[2]]+a[b[3]]))/float(len(space_vector))
    #print(ratio)
    if ratio > 0.9:
        usual_spaces=[[b[2]],[b[1]],[b[0]],[b[3]],[]]
        return  usual_spaces,True
    else:
        print('This script is too unstable to parse')
        usual_spaces=[[b[2]],[b[1]],[b[0]],[b[3]],[]]
        return usual_spaces,False

def write_csv(data,name,path):
    #if folder does not exist
    if not os.path.exists(path):
        os.makedirs(path)
    data.to_csv('%s%s.csv' %(path,name),sep='|',encoding='latin1')
    return

def get_line_type(line, stripped_line, usual_spaces):
    # Counting the number of spaces at the beginning of the line
    spaces_regex = re.compile("^(\s*).*")
    location_regex = re.compile("^\s*(INT\.|EXT\.)")
    BLOCK_TYPES=['character', 'speech', 'stage direction', 'location','unknown']
    CHARACTER=0
    SPEECH=1
    DIRECTIONS=2
    LOCATION=3
    
    spmatch = spaces_regex.search(line)
    spaces_number = len(spmatch.group(1))
    block_type = 4

    if( location_regex.search(line) != None ):
        #print('location')
        return LOCATION

    #if stripped_line in characters:
        #print(character)
        #return CHARACTER

    # Look for space
    for block_type_usual_spaces in usual_spaces:
        if spaces_number in block_type_usual_spaces:
            block_type = usual_spaces.index(block_type_usual_spaces)
            #print('We consider {:d} leading spaces as a \'{:s}\' block.'.format(
            #      spaces_number, BLOCK_TYPES[block_type]))
            #print(BLOCK_TYPES[block_type])
            return usual_spaces.index(block_type_usual_spaces)
            

      
    #print('failure for identifying : %s categorizing it as unknown' %(repr(line)))
    return block_type #return code 5 for unknown

# %%
def parse(url,path,name):
    #init variables
    spaces_regex = re.compile("^(\s*).*")
    location_regex = re.compile("^\s*(INT\.|EXT\.)")

    BLOCK_TYPES=['character', 'speech', 'stage direction', 'location','unknown']
    CHARACTER=0
    SPEECH=1
    DIRECTIONS=2
    LOCATION=3
    
    time_start=time.time()
    
    if url.endswith('.pdf'):
        print('The file @ %s is a PDF' %(url))
        return
    
    script_text=get_script(url)
    space_vector = white_space_analysis(script_text)
    usual_spaces,flag=identify_usual_spaces(space_vector)

    # Ici on définit les variables qu'on remplira de texte
    is_intro = True
    movie_script = []
    intro = []
    last_line_type = -1
    last_character = 'unknown'
    text = []
    characters=[]

    for block in script_text.descendants:
        # Si block est une instance de bs4.Tag, il est entouré de balises HTML
        # Le prochain block contiendra le même texte sans les balises
        # Donc on continue sans parser ce bloc
        if(isinstance(block, Tag)):
            continue

        # UnicodeDammit converts any string to UTF-8
        # does not work so well
        block = UnicodeDammit(block, soup.original_encoding).unicode_markup
        # remove leading and ending end of lines
        block = block.strip('\n').strip('\n\r')

        # if the block doesn't have any text, skip it
        if( re.search('\w', block) == None ):
            continue

        for line in block.split('\n'):
            stripped_line = line.strip(' \n\t\r')
            if( re.search('\w', line) == None ):
                continue    
            # Counting the number of spaces at the beginning of the line
            spmatch = spaces_regex.search(line)
            space_vector.append(len(spmatch.group(1)))
            #print(block)
            #print(line)
            #print(len(spmatch.group(1)))
            line_type = get_line_type(line, stripped_line, usual_spaces)
            #print(line_type)
            #print(line)

            if(last_line_type == -1 # -1 = not initialized
               or last_line_type == line_type):
                text.append(stripped_line)
            else:
                if(last_line_type == CHARACTER):
                    last_character='\n'.join(text) #regex to supress (parenthesis) & replicate speaker
                    if not last_character in characters:
                        characters.append(last_character)
                elif(last_line_type == SPEECH):
                    movie_script.append({
                        'type': BLOCK_TYPES[last_line_type],
                        BLOCK_TYPES[CHARACTER]: last_character,
                        'text': '\n'.join(text)})
                    #print('We just parsed this JSON block:')
                    #print(movie_script[-1])
                else:
                    movie_script.append({
                        'type': BLOCK_TYPES[last_line_type],
                        'text': '\n'.join(text)})
                    #print('We just parsed this JSON block:')
                    #print(movie_script[-1])
                text=[stripped_line]

            last_line_type = line_type
            #print('----------------')

    result = json_normalize(movie_script)
    if flag:
        write_csv(result,name,path)
        print('      Done parsing script at %s in %s' %(url,time.time()-time_start))
        print('-----------------')
        return(result)
    else:
        path=path+'doubtful/'
        write_csv(result,name,path)
        print('      Done parsing script at %s in %s' %(url,time.time()-time_start))
        print('-----------------')
        return(result)

# %%
# %%time

url='http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html'
path='../data/script/'
name='Starwars'
test=parse(url,path,name)
# Out:
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html.
#       Done parsing script at http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html in 2.44874811172
# -----------------
# CPU times: user 188 ms, sys: 8 ms, total: 196 ms
# Wall time: 2.45 s

# %%
test
# Out:
#           character                                               text  \
# 0               NaN  STAR WARS: THE FORCE AWAKENS\nWritten by\nLawr...
# 1               NaN       A long time ago in a galaxy far, far away...
# 2               NaN          STAR WARS\nEPISODE VII\nTHE FORCE AWAKENS
# 3           unknown  Luke Skywalker has vanished. In his absence,\n...
# 4               NaN  PAN across the star field to a bright moon. A ...
# 5               NaN      ARE IN:\nINT. TROOP TRANSPORT VEHICLE - NIGHT
# 6               NaN  TWENTY STORMTROOPERS. Holding on at attention,...
# 7               NaN                 QUIET:\nEXT. JAKKU VILLAGE - NIGHT
# 8               NaN  WIDE SHOT of a small, peaceful village. Distan...
# 9               NaN                             INT. LARGE HUT - NIGHT
# 10              NaN  CLOSE ON A HAND: a small LEATHER SACK is place...
# 11          unknown  LOR SAN TEKKA\nThis will begin to make things ...
# 12              POE  Well, because of you now we have a\nchance. Th...
# 13              NaN  BB-8 ENTERS FRANTIC, BEEPS. Concerned, Poe tur...
# 14     POE (CONT'D)                                 We've got company.
# 15              NaN                             EXT. LARGE HUT - NIGHT
# 16              NaN  The men exit fast. Poe moves TO CAMERA, raises...
# 17              POE  You have to hide.\nLOR SAN TEKKA\nYou have to ...
# 18              NaN  Poe turns to him. Conflicted. Finally nods, hu...
# 19              NaN                         EXT. JAKKU VILLAGE - NIGHT
# 20              NaN  TRACK FAST with Poe as he and BB-8 hurry throu...
# 21              NaN                         EXT. JAKKU VILLAGE - NIGHT
# 22              NaN  A ROAR of WIND and DUST: the TRANSPORTS LAND. ...
# 23              NaN              EXT. RISE ADJACENT TO VILLAGE - NIGHT
# 24              NaN  Poe runs to an X-WING fighter, parked at a dis...
# 25              POE                              Come on, BB-8! Hurry!
# 26              NaN  Poe sends BB-8 into the droid socket / co-pilo...
# 27     POE (CONT'D)                                         I see 'em!
# 28              NaN  BB-8 BEEPS nervously as Poe GRABS HIS CONTROLS...
# 29              NaN                         EXT. JAKKU VILLAGE - NIGHT
# ...             ...                                                ...
# 1781            NaN  Rey stands with Leia, Poe C-3PO, BB-8 and a ha...
# 1782            POE                 Yeah, all right, buddy, hold on --
# 1783            NaN  Poe runs over -- removes the ancient data devi...
# 1784          C-3PO                       Oh! The map! It is complete!
# 1785           LEIA                    (hand on her heart)\n-- Luke --
# 1786            NaN  Suddenly there are CHEERS AND EMBRACES.\nC-3PO...
# 1787          C-3PO  (to R2-D2)\nOh my dear friend. How I've missed...
# 1788            NaN                INT. RESISTANCE BASE - I.C.U. - DAY
# 1789            NaN  A NEW DAY. Finn, unconscious in an I.C.U. POD....
# 1790            REY  We'll see each other again. I believe\nthat. T...
# 1791            NaN                                   EXT. D'QAR - DAY
# 1792            NaN  Chewie does last minute checks of the Falcon. ...
# 1793           LEIA                                               Rey.
# 1794            NaN                                  Rey turns around.
# 1795  LEIA (CONT'D)                         May the Force be with you.
# 1796            NaN  This fills Rey up. She smiles gratefully. Rey ...
# 1797            NaN             INT. MILLENNIUM FALCON - COCKPIT - DAY
# 1798            NaN  Rey sits in the pilot seat, Chewie as co-pilot...
# 1799            NaN                                   EXT. D'QAR - DAY
# 1800            NaN  The Millennium Falcon RISES.\nLeia, with Poe, ...
# 1801            NaN                                   EXT. SPACE - DAY
# 1802            NaN  The Falcon FLIES through space and BLASTS to L...
# 1803            NaN                                 EXT. AHCH-TO - DAY
# 1804            NaN  A pristine and mighty OCEAN. Endless BLUE, dot...
# 1805            NaN                          EXT. AHCH-TO ISLAND - DAY
# 1806            NaN  Rey, her staff strapped to her back, begins he...
# 1807            NaN           EXT. AHCH-TO ISLAND - STONE STAIRS - DAY
# 1808            NaN  Built within the rock and foliage of this idyl...
# 1809            NaN       EXT. AHCH-TO ISLAND - STONE STRUCTURES - DAY
# 1810            NaN  Rey arrives at a clearing. Small, modest, prim...
#
#                  type
# 0             unknown
# 1     stage direction
# 2             unknown
# 3              speech
# 4     stage direction
# 5            location
# 6     stage direction
# 7            location
# 8     stage direction
# 9            location
# 10    stage direction
# 11             speech
# 12             speech
# 13    stage direction
# 14             speech
# 15           location
# 16    stage direction
# 17             speech
# 18    stage direction
# 19           location
# 20    stage direction
# 21           location
# 22    stage direction
# 23           location
# 24    stage direction
# 25             speech
# 26    stage direction
# 27             speech
# 28    stage direction
# 29           location
# ...               ...
# 1781  stage direction
# 1782           speech
# 1783  stage direction
# 1784           speech
# 1785           speech
# 1786  stage direction
# 1787           speech
# 1788         location
# 1789  stage direction
# 1790           speech
# 1791         location
# 1792  stage direction
# 1793           speech
# 1794  stage direction
# 1795           speech
# 1796  stage direction
# 1797         location
# 1798  stage direction
# 1799         location
# 1800  stage direction
# 1801         location
# 1802  stage direction
# 1803         location
# 1804  stage direction
# 1805         location
# 1806  stage direction
# 1807         location
# 1808  stage direction
# 1809         location
# 1810  stage direction
#
# [1811 rows x 3 columns]

# %%
urls=['http://www.imsdb.com/scripts/La-La-Land.html','http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html',
      'http://www.imsdb.com/scripts/V-for-Vendetta.html']
output=[]

for url in urls:
    path='../data/script/'
    name=url.replace(':','').replace('/','')
    test=parse(url,path,name)
    output.append(test)
# Out:
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/La-La-Land.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/La-La-Land.html in 1.90941309929
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html.
#       Done parsing script at http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html in 2.50909900665
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/V-for-Vendetta.html.
#       Done parsing script at http://www.imsdb.com/scripts/V-for-Vendetta.html in 3.21471095085
# -----------------

# %%
output_=[]

for url in urls:
    script_text=get_script(url)
    space_vector = white_space_analysis(script_text)
    usual_spaces=identify_usual_spaces(space_vector)
    output_.append(space_vector)
# Out:
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/La-La-Land.html.
# This script is too unstable to parse
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html.
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/V-for-Vendetta.html.

# %%
def white_space_analysis(script_text):
    spaces_regex = re.compile("^(\s*).*")
    space_vector=[]
    character_presence=[]

    for block in script_text.descendants:
        # Si block est une instance de bs4.Tag, il est entouré de balises HTML
        # Le prochain block contiendra le même texte sans les balises
        # Donc on continue sans parser ce bloc
        if(isinstance(block, Tag)):
            continue

        # UnicodeDammit converts any string to UTF-8
        # does not work so well
        block = UnicodeDammit(block, soup.original_encoding).unicode_markup
        # remove leading and ending end of lines
        block = block.strip('\n').strip('\r\n')

        # if the block doesn't have any text, skip it
        if( re.search('\w', block) == None ):
            continue

        for line in block.split('\n'):
            stripped_line = line.strip(' \n\t\r')
            if( re.search('\w', line) == None ):
                continue    
            # Counting the number of spaces at the beginning of the line
            spmatch = spaces_regex.search(line)
            space_vector.append(len(spmatch.group(1)))
            if (stripped_line.isupper()) & (len(stripped_line.split(' '))<=3):
                character_presence.append(len(spmatch.group(1)))

            else:
                character_presence.append(None)
                                            


            
    return space_vector,character_presence #,speech_presence


def identify_usual_spaces(space_vector,character_presence):
    #identify space for characters
    c=Counter([a for a in character_presence if a])
    char=sorted(c,key=c.get,reverse=True)[0]
    #identify space for speech
    indexes=[index+1 for index, value in enumerate(space_vector) if value == char]
    del indexes[-1]
    speech_presence=[space_vector[a] for a in indexes]
    c=Counter([a for a in speech_presence if a])
    speech=sorted(c,key=c.get,reverse=True)[0]
    #compute ratio
    a=Counter(space_vector)
    other=Counter([e for e in space_vector if e!=char and e!=speech])
    b=sorted(other,key=other.get,reverse=True)
    ratio=float((a[char]+a[speech]+a[b[0]]+a[b[1]]))/float(len(space_vector))
    #print(ratio)
    if ratio > 0.9:
        usual_spaces=[[char],[speech],[b[0]],[b[1]],[]]
        return  usual_spaces,True
    else:
        print('This script is too unstable to parse')
        usual_spaces=[[char],[speech],[b[0]],[b[1]],[]]
        return usual_spaces,False

def parse(url,path,name):
    #init variables
    spaces_regex = re.compile("^(\s*).*")
    location_regex = re.compile("^\s*(INT\.|EXT\.)")

    BLOCK_TYPES=['character', 'speech', 'stage direction', 'location','unknown']
    CHARACTER=0
    SPEECH=1
    DIRECTIONS=2
    LOCATION=3
    
    time_start=time.time()
    
    if url.endswith('.pdf'):
        print('The file @ %s is a PDF' %(url))
        return
    
    script_text=get_script(url)
    space_vector,character_presence = white_space_analysis(script_text)
    usual_spaces,flag=identify_usual_spaces(space_vector,character_presence)

    # Ici on définit les variables qu'on remplira de texte
    is_intro = True
    movie_script = []
    intro = []
    last_line_type = -1
    last_character = 'unknown'
    text = []
    characters=[]

    for block in script_text.descendants:
        # Si block est une instance de bs4.Tag, il est entouré de balises HTML
        # Le prochain block contiendra le même texte sans les balises
        # Donc on continue sans parser ce bloc
        if(isinstance(block, Tag)):
            continue

        # UnicodeDammit converts any string to UTF-8
        # does not work so well
        block = UnicodeDammit(block, soup.original_encoding).unicode_markup
        # remove leading and ending end of lines
        block = block.strip('\n').strip('\n\r')

        # if the block doesn't have any text, skip it
        if( re.search('\w', block) == None ):
            continue

        for line in block.split('\n'):
            stripped_line = line.strip(' \n\t\r')
            if( re.search('\w', line) == None ):
                continue    
            # Counting the number of spaces at the beginning of the line
            spmatch = spaces_regex.search(line)
            space_vector.append(len(spmatch.group(1)))
            #print(block)
            #print(line)
            #print(len(spmatch.group(1)))
            line_type = get_line_type(line, stripped_line, usual_spaces)
            #print(line_type)
            #print(line)

            if(last_line_type == -1 # -1 = not initialized
               or last_line_type == line_type):
                text.append(stripped_line)
            else:
                if(last_line_type == CHARACTER):
                    last_character='\n'.join(text) #regex to supress (parenthesis) & replicate speaker
                    if not last_character in characters:
                        characters.append(last_character)
                elif(last_line_type == SPEECH):
                    movie_script.append({
                        'type': BLOCK_TYPES[last_line_type],
                        BLOCK_TYPES[CHARACTER]: last_character,
                        'text': '\n'.join(text)})
                    #print('We just parsed this JSON block:')
                    #print(movie_script[-1])
                else:
                    movie_script.append({
                        'type': BLOCK_TYPES[last_line_type],
                        'text': '\n'.join(text)})
                    #print('We just parsed this JSON block:')
                    #print(movie_script[-1])
                text=[stripped_line]

            last_line_type = line_type
            #print('----------------')

    result = json_normalize(movie_script)
    if flag:
        write_csv(result,name,path)
        print('      Done parsing script at %s in %s' %(url,time.time()-time_start))
        print('-----------------')
        return(result)
    else:
        path=path+'doubtful/'
        write_csv(result,name,path)
        print('      Done parsing script at %s in %s' %(url,time.time()-time_start))
        print('-----------------')
        return(result)

# %%
urls=['http://www.imsdb.com/scripts/La-La-Land.html','http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html',
      'http://www.imsdb.com/scripts/V-for-Vendetta.html']
output=[]

for url in urls:
    path='../data/script/'
    name=url.replace(':','').replace('/','')
    test=parse(url,path,name)
    output.append(test)
# Out:
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/La-La-Land.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/La-La-Land.html in 1.90995502472
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html.
#       Done parsing script at http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html in 2.49408793449
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/V-for-Vendetta.html.
#       Done parsing script at http://www.imsdb.com/scripts/V-for-Vendetta.html in 3.1854300499
# -----------------

# %%
output[1]
# Out:
#           character                                               text  \
# 0               NaN  STAR WARS: THE FORCE AWAKENS\nWritten by\nLawr...
# 1               NaN       A long time ago in a galaxy far, far away...
# 2               NaN          STAR WARS\nEPISODE VII\nTHE FORCE AWAKENS
# 3           unknown  Luke Skywalker has vanished. In his absence,\n...
# 4               NaN  PAN across the star field to a bright moon. A ...
# 5               NaN      ARE IN:\nINT. TROOP TRANSPORT VEHICLE - NIGHT
# 6               NaN  TWENTY STORMTROOPERS. Holding on at attention,...
# 7               NaN                 QUIET:\nEXT. JAKKU VILLAGE - NIGHT
# 8               NaN  WIDE SHOT of a small, peaceful village. Distan...
# 9               NaN                             INT. LARGE HUT - NIGHT
# 10              NaN  CLOSE ON A HAND: a small LEATHER SACK is place...
# 11          unknown  LOR SAN TEKKA\nThis will begin to make things ...
# 12              POE  Well, because of you now we have a\nchance. Th...
# 13              NaN  BB-8 ENTERS FRANTIC, BEEPS. Concerned, Poe tur...
# 14     POE (CONT'D)                                 We've got company.
# 15              NaN                             EXT. LARGE HUT - NIGHT
# 16              NaN  The men exit fast. Poe moves TO CAMERA, raises...
# 17              POE  You have to hide.\nLOR SAN TEKKA\nYou have to ...
# 18              NaN  Poe turns to him. Conflicted. Finally nods, hu...
# 19              NaN                         EXT. JAKKU VILLAGE - NIGHT
# 20              NaN  TRACK FAST with Poe as he and BB-8 hurry throu...
# 21              NaN                         EXT. JAKKU VILLAGE - NIGHT
# 22              NaN  A ROAR of WIND and DUST: the TRANSPORTS LAND. ...
# 23              NaN              EXT. RISE ADJACENT TO VILLAGE - NIGHT
# 24              NaN  Poe runs to an X-WING fighter, parked at a dis...
# 25              POE                              Come on, BB-8! Hurry!
# 26              NaN  Poe sends BB-8 into the droid socket / co-pilo...
# 27     POE (CONT'D)                                         I see 'em!
# 28              NaN  BB-8 BEEPS nervously as Poe GRABS HIS CONTROLS...
# 29              NaN                         EXT. JAKKU VILLAGE - NIGHT
# ...             ...                                                ...
# 1781            NaN  Rey stands with Leia, Poe C-3PO, BB-8 and a ha...
# 1782            POE                 Yeah, all right, buddy, hold on --
# 1783            NaN  Poe runs over -- removes the ancient data devi...
# 1784          C-3PO                       Oh! The map! It is complete!
# 1785           LEIA                    (hand on her heart)\n-- Luke --
# 1786            NaN  Suddenly there are CHEERS AND EMBRACES.\nC-3PO...
# 1787          C-3PO  (to R2-D2)\nOh my dear friend. How I've missed...
# 1788            NaN                INT. RESISTANCE BASE - I.C.U. - DAY
# 1789            NaN  A NEW DAY. Finn, unconscious in an I.C.U. POD....
# 1790            REY  We'll see each other again. I believe\nthat. T...
# 1791            NaN                                   EXT. D'QAR - DAY
# 1792            NaN  Chewie does last minute checks of the Falcon. ...
# 1793           LEIA                                               Rey.
# 1794            NaN                                  Rey turns around.
# 1795  LEIA (CONT'D)                         May the Force be with you.
# 1796            NaN  This fills Rey up. She smiles gratefully. Rey ...
# 1797            NaN             INT. MILLENNIUM FALCON - COCKPIT - DAY
# 1798            NaN  Rey sits in the pilot seat, Chewie as co-pilot...
# 1799            NaN                                   EXT. D'QAR - DAY
# 1800            NaN  The Millennium Falcon RISES.\nLeia, with Poe, ...
# 1801            NaN                                   EXT. SPACE - DAY
# 1802            NaN  The Falcon FLIES through space and BLASTS to L...
# 1803            NaN                                 EXT. AHCH-TO - DAY
# 1804            NaN  A pristine and mighty OCEAN. Endless BLUE, dot...
# 1805            NaN                          EXT. AHCH-TO ISLAND - DAY
# 1806            NaN  Rey, her staff strapped to her back, begins he...
# 1807            NaN           EXT. AHCH-TO ISLAND - STONE STAIRS - DAY
# 1808            NaN  Built within the rock and foliage of this idyl...
# 1809            NaN       EXT. AHCH-TO ISLAND - STONE STRUCTURES - DAY
# 1810            NaN  Rey arrives at a clearing. Small, modest, prim...
#
#                  type
# 0             unknown
# 1     stage direction
# 2             unknown
# 3              speech
# 4     stage direction
# 5            location
# 6     stage direction
# 7            location
# 8     stage direction
# 9            location
# 10    stage direction
# 11             speech
# 12             speech
# 13    stage direction
# 14             speech
# 15           location
# 16    stage direction
# 17             speech
# 18    stage direction
# 19           location
# 20    stage direction
# 21           location
# 22    stage direction
# 23           location
# 24    stage direction
# 25             speech
# 26    stage direction
# 27             speech
# 28    stage direction
# 29           location
# ...               ...
# 1781  stage direction
# 1782           speech
# 1783  stage direction
# 1784           speech
# 1785           speech
# 1786  stage direction
# 1787           speech
# 1788         location
# 1789  stage direction
# 1790           speech
# 1791         location
# 1792  stage direction
# 1793           speech
# 1794  stage direction
# 1795           speech
# 1796  stage direction
# 1797         location
# 1798  stage direction
# 1799         location
# 1800  stage direction
# 1801         location
# 1802  stage direction
# 1803         location
# 1804  stage direction
# 1805         location
# 1806  stage direction
# 1807         location
# 1808  stage direction
# 1809         location
# 1810  stage direction
#
# [1811 rows x 3 columns]

# %%
output[2]
# Out:
#         character                                               text  \
# 0             NaN  V FOR VENDETTA\nWritten by\nLarry and Andy Wac...
# 1             NaN  FADE IN:\nIn the darkness, we hear a voice, a ...
# 2     EVEY (V.O.)  "Remember, remember, the fifth of\nNovember, t...
# 3             NaN  Her voice has a strength that is metered by a ...
# 4     EVEY (V.O.)  Those were almost the very first\nwords he spo...
# 5             NaN  In the darkness, we find a lantern.  Guy Fawke...
# 6     EVEY (V.O.)  In 1605, Guy Fawkes attempted to\nblow up the ...
# 7             NaN  The wheelbarrow bumps over the heavy stone mor...
# 8     EVEY (V.O.)  He was caught in the cellars with\nenough gunp...
# 9             NaN  Guy sees lanterns coming from both sides.  He ...
# 10    EVEY (V.O.)  Sometimes I wonder where we would\nbe if he ha...
# 11            NaN  In the dim pre-dawn light, Guy is led to the g...
# 12    EVEY (V.O.)  I suppose the answer is in the\nrhyme.  More t...
# 13            NaN  The coarse noose of rope is snugged up to Guy'...
# 14    EVEY (V.O.)  For in the plot we find more than\njust a man,...
# 15            NaN  The lever is thrown and the woman looks down, ...
# 16    EVEY (V.O.)  This, then, is the story of that\nidea, of tha...
# 17            NaN  Guy's body hangs in silhouette, lifeless again...
# 18            NaN                                          FADE OUT.
# 19            NaN                                           FADE IN:
# 20            NaN                               INT.  SUBURBAN HOUSE
# 21            NaN  A young Evey sits on her father's lap, combing...
# 22    EVEY (V.O.)  I was born near the end of the\nmillennium, th...
# 23            NaN  Her father sits beside her mother on the livin...
# 24    EVEY (V.O.)  I don't remember much of the\ncentury's turn. ...
# 25            NaN  The television flickers with images of heavily...
# 26    EVEY (V.O.)  I've read about them since but I\ndon't recall...
# 27            NaN  Little Evey sees her father staring at her mot...
# 28    EVEY (V.O.)                               But I could feel it.
# 29            NaN                                  EXT.  CITY STREET
# ...           ...                                                ...
# 2074          NaN                                    INT.  TRAIN CAR
# 2075          NaN  Inside the rattling train, V lays in perfect r...
# 2076     V (V.O.)          Let me be there, Evey, when it\nbegins...
# 2077          NaN                                     EXT.  ROOFTOPS
# 2078          NaN  Hidden and alone, Evey pulls the mask from her...
# 2079     V (V.O.)  Please let me hear the music... one\nlast time...
# 2080          NaN  Almost unconsciously, Evey raises her hand and...
# 2081     V (V.O.)           At first, you have to listen\ncarefully.
# 2082          NaN    The violins of the 1812 overture steadily rise.
# 2083     V (V.O.)     Ah, yes.  There it is.  Beautiful,\nis it not?
# 2084          NaN     Evey smiles, her hand still gently conducting.
# 2085         EVEY                          Yes, my love.  Yes it is.
# 2086          NaN                                       INT.  SUBWAY
# 2087          NaN  With the clash of cymbals, the train crashes i...
# 2088          NaN                      EXT.  NEW GOVERNMENT BUILDING
# 2089          NaN  The entire building opens like a time-lapsed r...
# 2090          NaN                                  EXT.  CITY STREET
# 2091          NaN  The crowd is awash in the baptismal glow of er...
# 2092          NaN                                      EXT.  ROOFTOP
# 2093          NaN  Evey watches the explosion, a star-burst of fl...
# 2094          NaN                                  EXT.  CITY STREET
# 2095          NaN  The masses burst through the barricades with a...
# 2096          NaN                                      EXT.  ROOFTOP
# 2097          NaN                The explosion begins to slowly die.
# 2098  EVEY (V.O.)  I know that there is only one way\nto repay hi...
# 2099          NaN                        She looks down at the mask.
# 2100  EVEY (V.O.)  And I know that that way is going\nto take a l...
# 2101          NaN                                        She smiles.
# 2102  EVEY (V.O.)  I know this like I know the sun\nwill rise tom...
# 2103          NaN  The fire fades and Evey turns, cradling the ma...
#
#                  type
# 0             unknown
# 1     stage direction
# 2              speech
# 3     stage direction
# 4              speech
# 5     stage direction
# 6              speech
# 7     stage direction
# 8              speech
# 9     stage direction
# 10             speech
# 11    stage direction
# 12             speech
# 13    stage direction
# 14             speech
# 15    stage direction
# 16             speech
# 17    stage direction
# 18           location
# 19    stage direction
# 20           location
# 21    stage direction
# 22             speech
# 23    stage direction
# 24             speech
# 25    stage direction
# 26             speech
# 27    stage direction
# 28             speech
# 29           location
# ...               ...
# 2074         location
# 2075  stage direction
# 2076           speech
# 2077         location
# 2078  stage direction
# 2079           speech
# 2080  stage direction
# 2081           speech
# 2082  stage direction
# 2083           speech
# 2084  stage direction
# 2085           speech
# 2086         location
# 2087  stage direction
# 2088         location
# 2089  stage direction
# 2090         location
# 2091  stage direction
# 2092         location
# 2093  stage direction
# 2094         location
# 2095  stage direction
# 2096         location
# 2097  stage direction
# 2098           speech
# 2099  stage direction
# 2100           speech
# 2101  stage direction
# 2102           speech
# 2103  stage direction
#
# [2104 rows x 3 columns]
