# %% [markdown]
# # Simple gender analysis

# %% [markdown]
# - ## Imports

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import unicodedata

import os, sys, json, re, argparse, urllib2, html5lib
from bs4 import BeautifulSoup, Tag, UnicodeDammit
import pandas as pd
from pandas.io.json import json_normalize
import time
import math
from parse_script import *

# %% [markdown]
# - ### Extract functions

# %% [raw]
# cf. parse_script.py

# %% [markdown]
# - ### Script loader and parser

# %%
def clean_character(char):
    if isinstance(char,unicode) or isinstance(char,str):
        char=char.replace('\n','').replace('*','').replace('O/S','').replace('V.O.','')
        char=re.sub(' +',' ',char)
        if 'CONTINUED' in char:
            return u'CONTINUED'
        if '(' in char or ')' in char:
            regex = re.compile(".*?\((.*?)\)")
            to_delete = re.findall(regex, char)
            for e in to_delete:
                char=char.replace('(%s)' %e,'')
            if char=='' or ')'in char:
                return None
            else:
                return char.rstrip() #delete lose end white space
        else:
            return char.rstrip()
    else:
        return None
    
def continued_speech(char_vector):
    char_vector=list(char_vector)
    while 'CONTINUED' in char_vector:
        count=0
        idx=char_vector.index("CONTINUED")
        for element in char_vector[idx-1::-1]:
            #if (isinstance(element,str) or isinstance(element,unicode)) and (element!='unknown'):
            if element and element!='unknown':
                char_vector[idx]=char_vector[idx-1-count]
                #print('Replaces CONTINUED with %s' %(char_vector[idx-1-count]))
                break
            count=count+1   
    return char_vector


# to remove outliers
def principal_characters(char_dic):
    mean = 0
    for i, j in char_dic.items():
        mean = mean + j
    mean = mean / len(char_dic)

    stddev = 0
    for i, j in char_dic.items():
        stddev = stddev + (j - mean)*(j - mean)
    stddev = stddev / len(char_dic)
    stddev = math.sqrt(stddev)

    temp = {}
    for i, j in char_dic.items():
        if (math.fabs(j - mean) < 3*stddev):
            temp[i] = j
    print(stddev,mean)
    return temp


def char_analysis(df):
    d=dict(Counter(df['character_clean']))
    d={key: value for key, value in d.items() 
                 if key}
    charlist = sorted(d)
    gender = dict()
    #lines=[element.split('\n') for element in output[1]['text']]
    lines=[element.split('\n') for element in df['text']]
    lines=[item for sublist in lines for item in sublist]

    for char in charlist:
        m, f, p = 0, 0, 0 
        for i in range(len(lines)):
            srch = re.search(char, lines[i], re.I)
            if not srch:
                continue
            if srch.group().isupper():
                continue
            else:
                k, k_range = -1, 2
                while k + i + 1 < len(lines):
                    k = k + 1
                    m = m + len(re.findall("\s+he", lines[k+i], re.I)) + len(re.findall("\s+him", lines[k+i], re.I))
                    f = f + len(re.findall("\s+she", lines[k+i], re.I)) + len(re.findall("\s+her", lines[k+i], re.I))
                    if lines[k+i].isupper():
                        break
                    if k >= k_range:
                        break
                k, k_range = -1, 4
                while k + i + 1 < len(lines):
                    k = k + 1
                    m1, m2, m3, m4 = re.search("\s+he", lines[k+i], re.I), re.search("\s+him", lines[k+i], re.I),\
                                    re.search("\s+she", lines[k+i], re.I), re.search("\s+her", lines[k+i], re.I)
                    if m1:
                        if m2:
                            mc = min(m1.span()[0], m2.span()[0])
                        else:
                            mc = m1.span()[0]
                    else:
                        mc = len(lines[k+i])
                    if m3:
                        if m4:
                            fc = min(m3.span()[0], m4.span()[0])
                        else:
                            fc = m3.span()[0]
                    else:
                        fc = len(lines[k+i])
                    if not(m1 or m2 or m3 or m4):
                        continue
                    else:
                        if (mc < fc):
                            p = p - 1
                        else:
                            p = p + 1
                        break
                    if lines[k+i].isupper():
                        break
                    if k >= k_range:
                        break
        gender[char] = m, f, p

    for char, g in gender.items():
        g_score = 2*g[1] - g[0] 
        g_sum = g[1]+g[0]
        g_score = g_score
        if (g_sum == 0.0) :#or (0 == 1):
            #print(char+" Undetermined ")
            gender[char] = "?" #0, 0, -1
        elif g_score > 0:
            #print(char+" Female "+str(g[0])+","+str(g[1])+","+str(g[2])+","+str(g_score))
            gender[char] = "F" #0, 0, 1
        else:
            #print(char+" Male", " ", str(g[0])+","+str(g[1])+","+str(g[2])+","+str(g_score))
            gender[char] = "M" #0, 0, 0
            
    return d,gender

# %%
actions=['http://www.imsdb.com/scripts/2012.html','http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html',
      'http://www.imsdb.com/scripts/V-for-Vendetta.html','http://www.imsdb.com/scripts/Above-the-Law.html',
        'http://www.imsdb.com/scripts/Alien-3.html','http://www.imsdb.com/scripts/Blade-Runner.html',
        'http://www.imsdb.com/scripts/G.I.-Joe-The-Rise-of-Cobra.html','http://www.imsdb.com/scripts/Godzilla.html',
        'http://www.imsdb.com/scripts/Gladiator.html','http://www.imsdb.com/scripts/Lord-of-the-Rings-Return-of-the-King.html']
output_actions=[]

for url in actions:
    path='../data/script/'
    name=url.replace(':','').replace('/','')
    test=parse(url,path,name)
    output_actions.append(test)
# Out:
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/2012.html.
#       Done parsing script at http://www.imsdb.com/scripts/2012.html in 1.46713709831
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html.
#       Done parsing script at http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html in 1.29713797569
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/V-for-Vendetta.html.
#       Done parsing script at http://www.imsdb.com/scripts/V-for-Vendetta.html in 1.41570305824
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/Above-the-Law.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Above-the-Law.html in 1.23356604576
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/Alien-3.html.
#       Done parsing script at http://www.imsdb.com/scripts/Alien-3.html in 1.03572297096
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Blade-Runner.html.
#       Done parsing script at http://www.imsdb.com/scripts/Blade-Runner.html in 1.2888879776
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/G.I.-Joe-The-Rise-of-Cobra.html.
#       Done parsing script at http://www.imsdb.com/scripts/G.I.-Joe-The-Rise-of-Cobra.html in 1.22886109352
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Godzilla.html.
#       Done parsing script at http://www.imsdb.com/scripts/Godzilla.html in 1.21901512146
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/Gladiator.html.
#       Done parsing script at http://www.imsdb.com/scripts/Gladiator.html in 1.03411817551
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/Lord-of-the-Rings-Return-of-the-King.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Lord-of-the-Rings-Return-of-the-King.html in 2.93669199944
# -----------------

# %%
romance=['http://www.imsdb.com/scripts/10-Things-I-Hate-About-You.html','http://www.imsdb.com/scripts/Amour.html',
        'http://www.imsdb.com/scripts/Barry-Lyndon.html','http://www.imsdb.com/scripts/Color-of-Night.html',
        'http://www.imsdb.com/scripts/Date-Night.html','http://www.imsdb.com/scripts/Her.html',
        'http://www.imsdb.com/scripts/Kate-&-Leopold.html','http://www.imsdb.com/scripts/500-Days-of-Summer.html',
        'http://www.imsdb.com/scripts/Wild-At-Heart.html']
output_romances=[]

for url in romance:
    path='../data/script/'
    name=url.replace(':','').replace('/','')
    test=parse(url,path,name)
    output_romances.append(test)
# Out:
# ('Detected encoding is ', u'iso-8859-1')
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/10-Things-I-Hate-About-You.html.
#       Done parsing script at http://www.imsdb.com/scripts/10-Things-I-Hate-About-You.html in 1.27091217041
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/Amour.html.
#       Done parsing script at http://www.imsdb.com/scripts/Amour.html in 1.02225399017
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Barry-Lyndon.html.
#       Done parsing script at http://www.imsdb.com/scripts/Barry-Lyndon.html in 1.16310095787
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/Color-of-Night.html.
#       Done parsing script at http://www.imsdb.com/scripts/Color-of-Night.html in 1.24628710747
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/Date-Night.html.
#       Done parsing script at http://www.imsdb.com/scripts/Date-Night.html in 1.29665493965
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/Her.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/Her.html in 1.1265900135
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/Kate-&-Leopold.html.
#       Done parsing script at http://www.imsdb.com/scripts/Kate-&-Leopold.html in 1.20782899857
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Getting script @ http://www.imsdb.com/scripts/500-Days-of-Summer.html.
# This script is too unstable to parse
#       Done parsing script at http://www.imsdb.com/scripts/500-Days-of-Summer.html in 1.34694099426
# -----------------
# ('Detected encoding is ', u'iso-8859-1')
# Found a <pre> inside the <pre>
# Getting script @ http://www.imsdb.com/scripts/Wild-At-Heart.html.
#       Done parsing script at http://www.imsdb.com/scripts/Wild-At-Heart.html in 1.11102080345
# -----------------

# %%
#construct character info and add it to dataframe
output_actions_=[]
male_nb_speech=[]
female_nb_speech=[]
for df in output_actions:
    try:
        test=df['character'].apply(lambda x :clean_character(x))
        df['character_clean']=continued_speech(test)
        char,gender=char_analysis(df)
        output_actions_.append(char)
        #create gender column in dataframe:
        df['gender']=[gender.get(item,item)  for item in list(df['character_clean'])]
        male_nb_speech.append(len(df[df['gender']=='M']))
        female_nb_speech.append(len(df[df['gender']=='F']))
    except Exception as e:
        print('Caught exception : %s' %e)
# Out:
# Caught exception : 'character'

# %%
#construct character info and add it to dataframe
output_romances_=[]
male_nb_speech=[]
female_nb_speech=[]
for df in output_romances:
    try:
        test=df['character'].apply(lambda x :clean_character(x))
        df['character_clean']=continued_speech(test)
        char,gender=char_analysis(df)
        output_romances_.append(char)
        #create gender column in dataframe:
        df['gender']=[gender.get(item,item)  for item in list(df['character_clean'])]
        male_nb_speech.append(len(df[df['gender']=='M']))
        female_nb_speech.append(len(df[df['gender']=='F']))
    except Exception as e:
        print('Caught exception : %s' %e)
# Out:
# Caught exception : unbalanced parenthesis
# Caught exception : unbalanced parenthesis

# %%
#exemple de sortie:
output_actions[1].head()

    #il faut majoritairement ce servir de cette liste de dataframe
# Out:
#   character                                               text  \
# 0       NaN  STAR WARS: THE FORCE AWAKENS\nWritten by\nLawr...
# 1       NaN       A long time ago in a galaxy far, far away...
# 2       NaN          STAR WARS\nEPISODE VII\nTHE FORCE AWAKENS
# 3   unknown  Luke Skywalker has vanished. In his absence,\n...
# 4       NaN  PAN across the star field to a bright moon. A ...
#
#               type character_clean gender
# 0          unknown            None   None
# 1  stage direction            None   None
# 2          unknown            None   None
# 3           speech         unknown      ?
# 4  stage direction            None   None

# %%
#exemple de sortie:
output_actions_[0]

    #cette liste de dictionnaire contient le nombre d'occurences des personnages par films (peu utile)
# Out:
# {u'ADRIAN': 119,
#  u'ALEC': 6,
#  u'ANHEUSER': 51,
#  u'BOXING ANNOUNCER': 3,
#  u'CAPTAIN MICHAELS': 27,
#  u'CASHIER': 1,
#  u'CHARLIE FROST': 34,
#  u"CHARLIE'S VOICE": 11,
#  u'CHINESE COMMANDER': 3,
#  u'CHINESE OFFICER': 1,
#  u'CHINESE STEWARD': 1,
#  u'CNN ANCHOR': 1,
#  u'COACH': 1,
#  u'COLONEL': 2,
#  u'COMMUNICATIONS OFFICER': 2,
#  u'COMMUNICATIONS OFFICER #1': 1,
#  u'COMMUNICATIONS OFFICER #2': 1,
#  u'COMPUTER VOICE': 1,
#  u'DECK OFFICER': 4,
#  u'EVERYBODY': 1,
#  u'FIRE MAN': 1,
#  u'GERMAN CHANCELLOR': 4,
#  u'GORDON': 46,
#  u'GOVERNOR': 2,
#  u'HARRY': 25,
#  u'HARRY HELMSLEY': 1,
#  u'INTERCOM': 1,
#  u'ITALIAN PRIME MINISTER': 1,
#  u'JACKSON': 135,
#  u'JACKSON AND LILLY': 1,
#  u'KATE': 55,
#  u'LAMA YAK LA': 3,
#  u'LAURA': 29,
#  u'LIEUTENANT #2': 1,
#  u'LILLY': 24,
#  u'LIN': 14,
#  u'MANFRED': 1,
#  u'MANFRED PICARD': 8,
#  u'MI-6 OFFICER': 2,
#  u'MR. PANG': 1,
#  u'MR.PANG': 1,
#  u'MRS. PANG': 6,
#  u'NAVAL OFFICER': 1,
#  u'NAVIGATION OFFICER': 1,
#  u'NEIGHBOR': 1,
#  u'NENG': 11,
#  u"NENG'S MOTHER": 1,
#  u'NEWS ANCHOR': 1,
#  u'NEWSCASTER': 4,
#  u'NOAH': 30,
#  u'OFFICER': 5,
#  u'OFFICERS': 1,
#  u'OLD LADY': 2,
#  u'OLEG': 11,
#  u'ON THE RADIO': 6,
#  u'POLITICAL AID #1': 1,
#  u'POLITICAL AID #2': 2,
#  u'PREACHER': 1,
#  u'PRESIDENT': 1,
#  u'PRESIDENT WILSON': 28,
#  u'PROF. WEST': 8,
#  u'PUBLIC RADIO NEWS': 2,
#  u'RADIO HOST': 6,
#  u'RED CROSS VOLUNTEER': 2,
#  u'RESCUE WORKER': 3,
#  u'RUSSIAN INTERPRETER': 1,
#  u'RUSSIAN PRESIDENT': 2,
#  u'SALLY': 3,
#  u'SASHA': 32,
#  u'SATNAM': 10,
#  u'SAUDI PRINCE': 3,
#  u'SCIENCE OFFICER': 3,
#  u'SCIENCE OFFICER #1': 3,
#  u'SCIENCE OFFICER #2': 1,
#  u'SOLDIER': 3,
#  u'SURVEILLANCE OFFICER': 6,
#  u'TAMARA': 15,
#  u'TECHNICAL OFFICER': 2,
#  u'TONY': 9,
#  u'VOICE': 6,
#  u'WAITER': 3,
#  u'YURI': 40,
#  u'ZULTAN': 1,
#  'unknown': 1}
