# %% [markdown]
# # Movie script crawler and parser

# %% [markdown]
# - ## Imports

# %%
import os, sys, json, re, argparse, urllib2, html5lib
from bs4 import BeautifulSoup, Tag, UnicodeDammit

# %% [markdown]
# - ### Extract functions

# %% [markdown]
# - ### Script loader and parser

# %%
#load script
script_url = 'http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html'
is_webpage_fetched = False
request_headers = {
"Accept-Language": "en-US,en;q=0.5",
"User-Agent": "Mozilla/5.0 (Windows NT 10.0; WOW64; rv:40.0) Gecko/20100101 Firefox/40.0",
#"Connection": "keep-alive" 
}


while not is_webpage_fetched:
    # get the script's URL from the parameters if it was passed
    try:
        request = urllib2.Request(script_url, headers=request_headers)
        contents = urllib2.urlopen(request)#.read()
        soup = BeautifulSoup(contents, 'lxml')
        print('Detected encoding is ', soup.original_encoding)
        is_webpage_fetched = True
    except urllib2.URLError as err:
        print('Catched an URLError while fetching the URL:', err)
        pass
    except ValueError as err:
        print('Catched a ValueError while fetching the URL:', err)
        pass
    except:
        print('Catched an unrecognized error')
        raise
    else:
        #script_text = soup.find("td", class_="scrtext").find("pre")
        script_text = soup.find("pre")

        if( script_text.find("pre") ):
            print('Found a <pre> inside the <pre>')
            script_text = script_text.find("pre")

        print('Parsing {} and extracting the first <pre> resulted in the following text:'.format(script_url))
        print(str(script_text)[:256])
        is_webpage_fetched = True




print('\n \n OK, we have the text. A few questions before we get parsing:')
# Out:
# ('Detected encoding is ', u'iso-8859-1')
# Parsing http://www.imsdb.com/scripts/Star-Wars-The-Force-Awakens.html and extracting the first <pre> resulted in the following text:
# <pre>
#
#
# <b>                               STAR WARS: THE FORCE AWAKENS
# </b>
#
#
#
#
#                                        Written by
#
#
#                       Lawrence Kasda
#
#
#  OK, we have the text. A few questions before we get parsing:

# %% [markdown]
# - ### White space analysis

# %%
# %%time
n=0
spaces_regex = re.compile("^(\s*).*")
location_regex = re.compile("^\s*(INT\.|EXT\.)")
space_vector=[]

for block in script_text.descendants:
    # Si block est une instance de bs4.Tag, il est entouré de balises HTML
    # Le prochain block contiendra le même texte sans les balises
    # Donc on continue sans parser ce bloc
    if(isinstance(block, Tag)):
        continue

    # UnicodeDammit converts any string to UTF-8
    # does not work so well
    block = UnicodeDammit(block, soup.original_encoding).unicode_markup
    # remove leading and ending end of lines
    block = block.strip('\n').strip('\r\n')
    
    # if the block doesn't have any text, skip it
    if( re.search('\w', block) == None ):
        continue

    for line in block.split('\n'):
        stripped_line = line.strip(' \n\t\r')
        if( re.search('\w', line) == None ):
            continue    
        # Counting the number of spaces at the beginning of the line
        spmatch = spaces_regex.search(line)
        space_vector.append(len(spmatch.group(1)))
        #print(block)
        #print(line)
        #print(len(spmatch.group(1)))
        #print('----------------')
    if n==151:
        break
    else:
        n+=1
# Out:
# CPU times: user 0 ns, sys: 4 ms, total: 4 ms
# Wall time: 3.48 ms

# %%
block
# Out:
# u'          of her canteen-hitting. She sets her things on a piece of\r\n          sheet metal and sits next to it, sliding down the sand dune.\r\n          She RIDES DOWN THE MOUNTAIN OF SAND. WE HOLD FOR A LONG\r\n          TIME, looking down, as she recedes from us, toward the distant\r\n          SALT FLATS below. Random SCATTERED DEBRIS. Her SPEEDER,\r\n          tiny from here.\r\n          Rey moves to her junker SPEEDER, jumps on, fires the sputtery\r\n          engine and DRIVES OFF.'

# %%
block.split('\n')
# Out:
# [u'          of her canteen-hitting. She sets her things on a piece of\r',
#  u'          sheet metal and sits next to it, sliding down the sand dune.\r',
#  u'          She RIDES DOWN THE MOUNTAIN OF SAND. WE HOLD FOR A LONG\r',
#  u'          TIME, looking down, as she recedes from us, toward the distant\r',
#  u'          SALT FLATS below. Random SCATTERED DEBRIS. Her SPEEDER,\r',
#  u'          tiny from here.\r',
#  u'          Rey moves to her junker SPEEDER, jumps on, fires the sputtery\r',
#  u'          engine and DRIVES OFF.']

# %%
line
# Out:
# u'          engine and DRIVES OFF.'

# %%
stripped_line
# Out:
# u'engine and DRIVES OFF.'

# %%
len(line)
# Out:
# 32

# %%
BLOCK_TYPES=['character', 'speech', 'stage direction', 'location','unknown']
CHARACTER=0
SPEECH=1
DIRECTIONS=2
LOCATION=3


usual_spaces=[[26],[11],[10],[25],[]]

# Ici on définit les variables qu'on remplira de texte
is_intro = True
movie_script = []
intro = []
last_line_type = -1
last_character = ''
text = []
characters=[]



def get_line_type(line, stripped_line, usual_spaces):
    # Counting the number of spaces at the beginning of the line
    spmatch = spaces_regex.search(line)
    spaces_number = len(spmatch.group(1))
    block_type = 4

    if( location_regex.search(line) != None ):
        #print('location')
        return LOCATION

    #if stripped_line in characters:
        #print(character)
        #return CHARACTER

    # Look for space
    for block_type_usual_spaces in usual_spaces:
        if spaces_number in block_type_usual_spaces:
            block_type = usual_spaces.index(block_type_usual_spaces)
            #print('We consider {:d} leading spaces as a \'{:s}\' block.'.format(
            #      spaces_number, BLOCK_TYPES[block_type]))
            #print(BLOCK_TYPES[block_type])
            return usual_spaces.index(block_type_usual_spaces)
            

      
    print('failure for identifying : %s categorizing it as unknown' %(repr(line)))
    return block_type #return code 5 for unknown


line_type = get_line_type(line, stripped_line, usual_spaces)

# %%
# %%time
n=0
spaces_regex = re.compile("^(\s*).*")
location_regex = re.compile("^\s*(INT\.|EXT\.)")
space_vector=[]


BLOCK_TYPES=['character', 'speech', 'stage direction', 'location','unknown']
CHARACTER=0
SPEECH=1
DIRECTIONS=2
LOCATION=3


usual_spaces=[[26],[11],[10],[25],[]]

# Ici on définit les variables qu'on remplira de texte
is_intro = True
movie_script = []
intro = []
last_line_type = -1
last_character = ''
text = []
characters=[]



for block in script_text.descendants:
    # Si block est une instance de bs4.Tag, il est entouré de balises HTML
    # Le prochain block contiendra le même texte sans les balises
    # Donc on continue sans parser ce bloc
    if(isinstance(block, Tag)):
        continue

    # UnicodeDammit converts any string to UTF-8
    # does not work so well
    block = UnicodeDammit(block, soup.original_encoding).unicode_markup
    # remove leading and ending end of lines
    block = block.strip('\n').strip('\n\r')
    
    # if the block doesn't have any text, skip it
    if( re.search('\w', block) == None ):
        continue

    for line in block.split('\n'):
        stripped_line = line.strip(' \n\t\r')
        if( re.search('\w', line) == None ):
            continue    
        # Counting the number of spaces at the beginning of the line
        spmatch = spaces_regex.search(line)
        space_vector.append(len(spmatch.group(1)))
        #print(block)
        #print(line)
        #print(len(spmatch.group(1)))
        line_type = get_line_type(line, stripped_line, usual_spaces)
        print(line_type)
        print(line)

        if(last_line_type == -1 # -1 = not initialized
           or last_line_type == line_type):
            text.append(stripped_line)
        else:
            if(last_line_type == CHARACTER):
                last_character='\n'.join(text) #regex to supress (parenthesis) & replicate speaker
                if not last_character in characters:
                    characters.append(last_character)
            elif(last_line_type == SPEECH):
                movie_script.append({
                    'type': BLOCK_TYPES[last_line_type],
                    BLOCK_TYPES[CHARACTER]: last_character,
                    'text': '\n'.join(text)})
                #print('We just parsed this JSON block:')
                #print(movie_script[-1])
            else:
                movie_script.append({
                    'type': BLOCK_TYPES[last_line_type],
                    'text': '\n'.join(text)})
                #print('We just parsed this JSON block:')
                #print(movie_script[-1])
            text=[stripped_line]

        last_line_type = line_type
        #print('----------------')

    if n==10000000000:
        break
    else:
        n+=1
# Out:
# failure for identifying : u'                               STAR WARS: THE FORCE AWAKENS' categorizing it as unknown
# 4
#                                STAR WARS: THE FORCE AWAKENS
# failure for identifying : u'                                       Written by\r' categorizing it as unknown
# 4
#                                        Written by
# failure for identifying : u'                      Lawrence Kasdan, J.J. Abrams & Michael Arndt\r' categorizing it as unknown
# 4
#                       Lawrence Kasdan, J.J. Abrams & Michael Arndt
# failure for identifying : u'                       Based on characters created by George Lucas\r' categorizing it as unknown
# 4
#                        Based on characters created by George Lucas
# 2
#           A long time ago in a galaxy far, far away...
# failure for identifying : u'                                        STAR WARS' categorizing it as unknown
# 4
#                                         STAR WARS
# failure for identifying : u'                                       EPISODE VII' categorizing it as unknown
# 4
#                                        EPISODE VII
# failure for identifying : u'                                    THE FORCE AWAKENS' categorizing it as unknown
# 4
#                                     THE FORCE AWAKENS
# 1
#            Luke Skywalker has vanished. In his absence,
# 1
#            the sinister FIRST ORDER has risen from the
# 1
#            ashes of the Empire and will not rest until
# 1
#            Skywalker, the last Jedi, has been destroyed.
# 1
#            With the support of the REPUBLIC, General
# 1
#            Leia Organa leads a brave RESISTANCE. She is
# 1
#            desperate to find her brother Luke and gain
# 1
#            his help in restoring peace and justice to
# 1
#            the galaxy.
# 1
#            Leia has sent her most daring pilot on a secret
# 1
#            mission to Jakku, where an old ally has
# 1
#            discovered a clue to Luke's whereabouts....
# 2
#           PAN across the star field to a bright moon. A RUMBLING is
# 2
#           FELT. A VAST STAR DESTROYER -- unlike any we have seen --
# 2
#           HURTLES PAST US, of seemingly endless length, eclipsing the
# 2
#           moon. After a long beat, FOUR TRANSPORT SHIPS fly from a
# 2
#           hangar. We HOLD ON THEM NOW, as they fly off toward a distant
# 2
#           planet. Jakku. MUSIC BUILDS AND WE...
# 2
#           CUT TO BLACK.
# 2
#           A GROWING ROAR of MEAN ENGINES -- gnarled RADIO CALLS, the
# 2
#           SHUDDERING of a ship's hull. Then FLASHES OF LIGHT: for an
# 2
#           instant we see a STORMTROOPER -- then BLACKNESS. Then ANOTHER
# 2
#           STORMTROOPER, then it's gone.
# 2
#           The FLICKERING CONTINUES until the LIGHTS ARE CONSTANT. We
# 3
#                          ARE IN:
# 3
#           INT. TROOP TRANSPORT VEHICLE - NIGHT
# 2
#           TWENTY STORMTROOPERS. Holding on at attention, moving to
# 2
#           the ship's rhythm, in the tense moments before a raid. A
# 2
#           FILTERED COMMAND and they LOCK AND LOAD their heavy blaster
# 2
#           rifles. The BRUTAL NOISE is replaced by SUDDEN, SHOCKING
# 3
#                          QUIET:
# 3
#           EXT. JAKKU VILLAGE - NIGHT
# 2
#           WIDE SHOT of a small, peaceful village. Distant sounds of
# 2
#           native animals. A single wind chime.
# 2
#           Suddenly a DROID RISES INTO FRAME, CLOSE: ROUND and SKITTERY,
# 2
#           orange and white, this is BB-8.
# 2
#           Focuses on something past camera. He BEEPS -- FAST, MORSE
# 2
#           CODE-LIKE SOUNDS, clearly worried. Moves EVEN CLOSER TO
# 2
#           CAMERA -- is MORE worried -- BEEPS more -- then TURNS AND
# 2
#           ROLLS OFF FAST --
# 3
#           INT. LARGE HUT - NIGHT
# 2
#           CLOSE ON A HAND: a small LEATHER SACK is placed in the palm.
# 2
#           The hand closes. Another OLDER HAND covers it.
# 2
#           In a primitive HUT, an old explorer, LOR SAN TEKKA, (rugged,
# 2
#           kind) has handed the mysterious sack to POE DAMERON (32, in
# 2
#           a pilot's jacket). Poe has charisma, a natural spark:
# 1
#            LOR SAN TEKKA
# 1
#            This will begin to make things right.
# 1
#            I've traveled too far, and seen too
# 1
#            much, to ignore the despair in the
# 1
#            galaxy. Without the Jedi, there can
# 1
#            be no balance in the Force.
# 0
#                           POE
# 1
#            Well, because of you now we have a
# 1
#            chance. The General's been after
# 1
#            this for a long time.
# 1
#            LOR SAN TEKKA
# 1
#            "The General." To me, she's royalty.
# 1
#            Well, she certainly is that.
# 0
#                           POE
# 2
#           BB-8 ENTERS FRANTIC, BEEPS. Concerned, Poe turns to Lor San
# 2
#           Tekka.
# 0
#                           POE (CONT'D)
# 1
#            We've got company.
# 3
#           EXT. LARGE HUT - NIGHT
# 2
#           The men exit fast. Poe moves TO CAMERA, raises QUADNOCULARS.
# 2
#           POE'S POV: LIGHTS on the horizon -- approaching ENEMY SHIPS.
# 2
#           POE lowers the quadnocs -- PUSH IN ON HIS UNNERVED EYES. A
# 2
#           GROWING, FRIGHTENING THUNDER.
# 0
#                           POE
# 1
#            You have to hide.
# 1
#            LOR SAN TEKKA
# 1
#            You have to leave. Go!
# 2
#           Poe turns to him. Conflicted. Finally nods, hurries off.
# 2
#           BB-8 follows.
# 3
#           EXT. JAKKU VILLAGE - NIGHT
# 2
#           TRACK FAST with Poe as he and BB-8 hurry through the village,
# 2
#           various ARMED VILLAGERS taking position, prepared to defend.
# 3
#           EXT. JAKKU VILLAGE - NIGHT
# 2
#           A ROAR of WIND and DUST: the TRANSPORTS LAND. Stormtroopers
# 2
#           come out FIRING BLASTERS -- the VILLAGERS FIRE BACK -- many
# 2
#           are HIT!
# 3
#           EXT. RISE ADJACENT TO VILLAGE - NIGHT
# 2
#           Poe runs to an X-WING fighter, parked at a distance from the
# 2
#           village, hidden behind a ROCK OUTCROPPING.
# 0
#                           POE
# 1
#            Come on, BB-8! Hurry!
# 2
#           Poe sends BB-8 into the droid socket / co-pilot seat -- he
# 2
#           moves to the cockpit -- the CONTROLS COME TO LIFE. As the
# 2
#           CANOPY CLOSES, Poe shoots a quick look back: the ENEMY ARRIVES
# 2
#           IN THE DISTANCE.
# 2
#           Poe urgently works the controls -- BB-8 BEEPS.
# 2
#           The X-WING LANDING LIGHTS COME ON, ENGINES WHINE TO LIFE!
# 2
#           But just then:
# 2
#           Poe's ship is suddenly HIT BY BLASTERFIRE! Poe turns to
# 2
#           look: two STORMTROOPERS CHARGE HIS WAY, FIRING!
# 0
#                           POE (CONT'D)
# 1
#            I see 'em!
# 2
#           BB-8 BEEPS nervously as Poe GRABS HIS CONTROLS and FIRES AT
# 2
#           THEM, using the X-wing's drop-down antipersonnel blaster!
# 2
#           The two Troopers are BLOWN AWAY in the large BLAST HITS!
# 2
#           Poe tries to start the ship now, but the ENGINES SPUTTER.
# 2
#           Concerned, he opens his canopy, jumps down, moves to the
# 2
#           back of his ship: BAD DAMAGE ON THE REAR ENGINE PANEL.
# 2
#           They're in trouble.
# 3
#           EXT. JAKKU VILLAGE - NIGHT
# 2
#           Lor San Tekka moves sadly through the village as STORMTROOPERS
# 2
#           wielding FLAME THROWERS destroy structures. Surrendering
# 2
#           Villagers are ROUNDED UP. Penned ANIMALS panic.
# 3
#           EXT. RISE ADJACENT TO THE VILLAGE - NIGHT
# 2
#           Back at the X-wing, Poe kneels beneath his ship, pulls from
# 2
#           the leather sack a SMALL, OLD ARTIFACT which he inserts into
# 2
#           BB-8 -- the droid's MULTI-READER ENVELOPS it.
# 0
#                           POE
# 1
#            You take this. It's safer with you
# 1
#            than it is with me. You get as far
# 1
#            away from here as you can. Do you
# 1
#            hear me?
# 1
#            (BB-8 BEEPS, hesitates)
# 1
#            I'll come back for you! It will be
# 1
#            alright.
# 2
#           BB-8 watches Poe run off. BEEP-WHINES nervously, then turns
# 2
#           and heads off. Turns back once to look at Poe, then ROLLS
# 2
#           AWAY. Poe uses his blaster rifle to fire at incoming troopers
# 2
#           from cover.
# 3
#           EXT. JAKKU VILLAGE - NIGHT
# 2
#           The Troopers and villagers in battle -- as one Trooper is
# 2
#           HIT and goes down. Another -- OUR TROOPER -- KNEELS to help.
# 2
#           The hit trooper raises a torn, bloody glove -- his HUMAN
# 2
#           HAND visible -- and MARKS OUR STORMTROOPER'S MASK WITH BLOOD
# 2
#           just before he dies. Our Trooper, stands -- overwhelmed by
# 2
#           the battle.
# 2
#           AN IMPOSING SHUTTLE CRAFT -- VERTICAL WINGSPAN 90 FEET TALL --
# 2
#           LANDS NEAR THE TRANSPORT VEHICLES.
# 2
#           The shuttle craft door OPENS -- through the wind and smoke,
# 2
#           KYLO REN exits the ship: a TALL, DARK FIGURE, he strides
# 2
#           through the chaos toward San Tekka.
# 2
#           A senior Trooper moves to our blood-marked Trooper, and orders
# 3
#                          HIM:
# 0
#                           SENIOR TROOPER
# 1
#            Stay here.
# 2
#           Our Trooper nods.
# 2
#           Kylo Ren stops before the outraged Lor San Tekka, dwarfing
# 2
#           him. Only now does it become apparent that Kylo Ren wears a
# 2
#           DARK MASK, marked by battle. Inset metal lines reflect FIRE.
# 0
#                           KYLO REN
# 1
#            Look how old you've become.
# 1
#            LOR SAN TEKKA
# 1
#            Something far worse has happened to
# 1
#            you.
# 2
#           Our blood-marked TROOPER is placed in line with other
# 2
#           stormtroopers.
# 0
#                           KYLO REN
# 1
#            You know what I've come for.
# 0
#                           (CONTINUED)
# 2
#           CONTINUED: LOR SAN TEKKA
# 1
#            I know where you come from. Before
# 1
#            you called yourself Kylo Ren.
# 0
#                           KYLO REN
# 1
#            The map to Skywalker. We know you've
# 1
#            found it, and now you're going to
# 1
#            give it to the First Order.
# 2
#           Adjacent to the village, Poe enters frame -- sees the Ren/San
# 2
#           Tekka exchange continue.
# 1
#            LOR SAN TEKKA
# 1
#            The First Order rose from the dark
# 1
#            side... you did not.
# 0
#                           KYLO REN
# 1
#            I'll show you the dark side.
# 1
#            LOR SAN TEKKA
# 1
#            You may try, but you cannot deny the
# 1
#            truth that is your family.
# 2
#           Suddenly Kylo Ren raises his LIGHTSABER -- IGNITES IT --
# 2
#           PERPENDICULAR SMALLER BLADES AT THE HILT, A UNIQUE BUZZ --
# 2
#           YELLOW/RED ENERGY, SPITTING SPARKS AND SMOKE --
# 0
#                           KYLO REN
# 1
#            You're so right.
# 2
#           And as he RIPS IT DOWN ACROSS SAN TEKKA!
# 2
#           Poe, RUNNING, SEES THIS AND YELLS, AIMS HIS BLASTER AND FIRES
# 2
#           AT KYLO REN! Instantly:
# 2
#           Kylo Ren RAISES HIS HAND -- POE'S BLAST FREEZES -- THE BOLT
# 2
#           OF ENERGY STRAINING AND VIBRATING IN MID AIR!
# 2
#           Kylo Ren sees Poe, who suddenly CANNOT MOVE, but strains to.
# 2
#           He is grabbed by Stormtroopers who drag him past the
# 2
#           VIBRATING, FROZEN BLAST, to Kylo Ren.
# 2
#           A Stormtrooper begins a brutal PAT DOWN. Kylo Ren moves
# 2
#           closer. Poe just glares. The Stormtrooper KICKS OUT Poe's
# 2
#           legs -- he lands hard on his knees.
# 2
#           Kylo Ren kneels to look at Poe.
# 0
#                           POE
# 1
#            So who talks first? You talk first?
# 0
#                           KYLO REN
# 1
#            The old man gave it to you.
# 0
#                           POE
# 0
#                           (INDICATES KYLO'S
# 0
#                           MASK)
# 1
#            It's just very hard to understand
# 1
#            you with all the...
# 0
#                           (CONTINUED)
# 3
#                          CONTINUED:
# 0
#                           KYLO REN
# 0
#                           (TO TROOPERS)
# 1
#            Search him.
# 0
#                           POE
# 1
#            ... Apparatus.
# 2
#           The Troopers roughly pull Poe away. A Stormtrooper begins a
# 2
#           brutal PAT DOWN. Kylo Ren moves closer.
# 2
#           Poe just glares as the pat down ends.
# 0
#                           STORMTROOPER #1
# 1
#            Nothing, sir.
# 0
#                           KYLO REN
# 1
#            Put him on board.
# 2
#           Kylo Ren regards the Stormtroopers with the rounded up
# 2
#           Villagers, then turns to the CHROME-SKINNED, FEMALE BLACK-
# 2
#           CAPED HEAD STORMTROOPER, CAPTAIN PHASMA.
# 0
#                           CAPTAIN PHASMA
# 1
#            Sir, the villagers.
# 0
#                           KYLO REN
# 1
#            Kill them all.
# 2
#           Phasma nods, steps forward:
# 0
#                           CAPTAIN PHASMA
# 1
#            On my command!
# 2
#           The Troopers, including OURS, aim at the Villagers.
# 1
#            CAPTAIN PHASMA (CONT'D)
# 1
#            Fire!
# 2
#           Poe is roughly PULLED into a transport ship, the ramp LIFTS.
# 2
#           All around our Trooper BLASTERFIRE ERUPTS -- but we're WIDE
# 2
#           ENOUGH to see he ISN'T FIRING. PUSH IN until the FIRING
# 2
#           STOPS. All the Stormtroopers SPREAD OUT TO SEARCH -- except
# 2
#           ours.
# 2
#           Kylo Ren heads back toward his ship. But then he STOPS.
# 2
#           Feels something. TURNS AND LOOKS AT OUR STORMTROOPER for a
# 2
#           LONG MOMENT. Our Trooper can barely meet his gaze; knows
# 2
#           he's doomed.
# 2
#           Kylo Ren then heads off -- passes the FROZEN BLAST, which,
# 2
#           after a beat, GOES FREE AND SLAMS INTO A NEARBY STRUCTURE,
# 2
#           scaring the hell out of our Stormtrooper.
# 3
#           EXT. EDGE OF JAKKU VILLAGE - NIGHT
# 2
#           A Stormtrooper climbs down from the cockpit of Poe's X-wing,
# 3
#                          BACKS AWAY:
# 0
#                           (CONTINUED)
# 3
#                          CONTINUED:
# 0
#                           STORMTROOPER #2
# 1
#            Nothing here. Go ahead!
# 2
#           Three other Stormtroopers FIRE LASER CANNONS at the X-wing --
# 2
#           destroying the ship in a LARGE EXPLOSION.
# 3
#           EXT. OUTSKIRTS OF JAKKU VILLAGE - NIGHT
# 2
#           BB-8 rolls across the sand, looks back: the X-wing FIREBALL.
# 2
#           BB-8, afraid, continues on his own in a mysterious, dark
# 2
#           desert. We see a FORM -- an animal, its RED EYES LIFTING
# 2
#           from the sand, watching the rolling droid, who just keeps
# 2
#           going.
# 2
#           In a WIDE SHOT, we HEAR HIM BEEPING to himself, lonely and
# 2
#           frightened.
# 3
#           EXT. SPACE - NIGHT
# 2
#           With the SANDY PLANET OF JAKKU as backdrop, Troop Transports
# 2
#           and Kylo Ren's Shuttle approach a massive STAR DESTROYER.
# 3
#           INT. STAR DESTROYER HANGAR - NIGHT
# 2
#           Poe, shackled, is ushered from the transport through the
# 2
#           hangar. He is awed by the imposing space.
# 0
#                           POE
# 1
#            All right. All right!
# 2
#           Our Stormtrooper passes, moves fast:
# 3
#           INT. TROOP TRANSPORT VEHICLE - NIGHT
# 2
#           Our Stormtrooper enters the dark, vehicle. He removes his
# 2
#           helmet. His head comes up and we PUSH IN ON HIS FACE FOR
# 2
#           THE FIRST TIME. This is FN-2187. He is 23, likable. But
# 2
#           in this moment, terrified, desperate.
# 2
#           After a beat, behind him, CAPTAIN PHASMA enters. FN-2187
# 2
#           knows he's in trouble.
# 0
#                           CAPTAIN PHASMA
# 1
#            FN-2187. Submit your blaster for
# 1
#            inspection.
# 0
#                           FN-2187
# 1
#            Yes, Captain.
# 0
#                           CAPTAIN PHASMA
# 1
#            And who gave you permission to remove
# 1
#            that helmet?
# 0
#                           FN-2187
# 1
#            I'm sorry, Captain.
# 0
#                           CAPTAIN PHASMA
# 1
#            Report to my division at once.
# 0
#                           (CONTINUED)
# 3
#                          CONTINUED:
# 2
#           Phasma heads off. Shattered, FN-2187 replaces his helmet.
# 0
#                           CUT TO:
# 3
#           INT. JUNKED VESSEL CORRIDOR - DAY
# 2
#           A metal sheet is pulled open to reveal the wrapped up face
# 2
#           of A SCAVENGER, perhaps alien, in GOGGLES, FACE MASK and
# 2
#           GLOVES. Backpack with a STAFF strapped to it. Uses TOOLS
# 2
#           to remove various MECHANISMS from inside the wall. We are
# 2
#           in an upside-down, canted CORRIDOR. The Scavenger finds a
# 2
#           valuable piece, drops it in a SATCHEL.
# 2
#           Swings the bag back and begins CLIMBING DOWN on a cable,
# 2
#           between treacherous WALLS OF MACHINERY, headed to:
# 3
#           INT. JUNKED VESSEL - LARGER SPACE - LATER
# 2
#           Alone and tiny in this massive, sideways wreck, the Scavenger
# 2
#           descends, climbing down a two-hundred foot-long cable. LANDS
# 2
#           HARD onto rusty metal.
# 3
#           INT. JUNKED VESSEL - ENGINES - DAY
# 2
#           The Scavenger carries the satchel and another large, found
# 2
#           piece, over enormous pipes in the vast space, heads through
# 2
#           the dust toward a distant SLIT OF SUNLIGHT.
# 3
#           EXT. JUNKED VESSEL ENGINE - DAY
# 2
#           The Scavenger arrives from the darkness and pulls off goggles
# 2
#           and gear, revealing the grimy face of a beautiful, young
# 2
#           WOMAN. This is REY, 19.
# 2
#           She opens her canteen, shakes out the two final drops into
# 2
#           her mouth. HITS THE SIDE of the canteen again and again for
# 2
#           whatever she can get. CUT WIDE:
# 2
#           Rey is rendered minuscule, standing at the bottom of an EPIC
# 2
#           ENGINE OF A DECAYING, CRASHED STAR DESTROYER -- DISTANT SOUND
# 2
#           of her canteen-hitting. She sets her things on a piece of
# 2
#           sheet metal and sits next to it, sliding down the sand dune.
# 2
#           She RIDES DOWN THE MOUNTAIN OF SAND. WE HOLD FOR A LONG
# 2
#           TIME, looking down, as she recedes from us, toward the distant
# 2
#           SALT FLATS below. Random SCATTERED DEBRIS. Her SPEEDER,
# 2
#           tiny from here.
# 2
#           Rey moves to her junker SPEEDER, jumps on, fires the sputtery
# 2
#           engine and DRIVES OFF.
# 3
#           EXT. DESERT - SPACESHIP GRAVEYARD - DAY
# 2
#           Rey races along the desert floor: a GRAVEYARD OF CRASHED
# 2
#           SPACESHIPS.
# 3
#           EXT. NIIMA OUTPOST - DAY
# 2
#           Rey's speeder PASSES us, heading for a dusty, desert town.
# 2
#           Refueling, small trade, scavengers.
# 0
#                           (CONTINUED)
# 3
#                          CONTINUED:
# 2
#           CRASH! Rey's sack carrying her heavy FOUND OBJECTS hits the
# 2
#           sand. Working like a tough seaman, Rey hauls the sack from
# 2
#           her speeder toward the town.
# 3
#           EXT. NIIMA OUTPOST - CLEANING TABLE - DAY
# 2
#           TIGHT ON REY'S HANDS as she SCRUBS CLEAN her day's salvage.
# 2
#           Rey glances up: she looks at an old woman, also cleaning
# 2
#           some salvage.
# 2
#           Rey watches her, gets lost in the simple moment. A small,
# 2
#           passing alien UNDERLING barks something to her in another
# 2
#           language. She returns to work.
# 3
#           INT. NIIMA TRADING STRUCTURE - DAY
# 2
#           Rey looks up to a SERVICE WINDOW: two feet above her, behind
# 2
#           a protective screen, is her boss, UNKAR PLUTT (50, blobfish,
# 2
#           unclean). He examines her pieces. Then he offers:
# 0
#                           UNKAR
# 1
#            What you've brought me today is
# 1
#            worth... Hmmm... One quarter
# 1
#            portion.
# 2
#           Though disappointed, Rey barely shows it. She nods thanks.
# 2
#           Unkar pushes through his transfer drawer a SEALED PACKET:
# 2
#           DRIED GREEN MEAT in one section, BEIGE POWDER in another.
# 2
#           She takes it.
# 2
#           She swallows her resentment and heads off.
# 3
#           EXT. NIIMA OUTPOST - DAY
# 2
#           The IMMENSE SETTING SUN against the FLAT TERRAIN. Rey's
# 2
#           SPEEDER races, almost insignificant, across frame.
# 3
#           INT. REY'S DWELLING - DAY
# 2
#           She SCRATCHES MARKS into the rusty wall. Another MARK;
# 2
#           another DAY. And there are THOUSANDS of marks.
# 2
#           A SIZZLING SOUND over: A DRIED DESERT FLOWER in a rusty ENGINE
# 2
#           PIECE. A rough, stuffed HANDMADE DOLL, made from what looks
# 2
#           like orange Rebellion flight suit material and twine.
# 2
#           Rey's lonely, ramshackle dwelling. Everything reclaimed.
# 2
#           She cooks for one. Does everything for one. She opens the
# 2
#           POWDER, moves to the makeshift WOK, where the GREEN MEAT
# 2
#           SIZZLES. Pours the powder into milky WATER in a tin. Stirs
# 2
#           it. It GROWS INTO A LOAF as she puts the meat on an old
# 2
#           plate. Grabs the loaf.
# 3
#           EXT. REY'S DWELLING - DUSK
# 2
#           Rey sits, eats like a starving child. Every last drop.
# 2
#           Licks the metal plate. Looks out at the horizon. A single
# 2
#           silent ship heads off, a shimmering, thin contrail. She
# 2
#           wipes her mouth. Picks up an old, broken REBELLION HELMET.
# 0
#                           (CONTINUED)
# 2
#           CONTINUED: just 'cause.
# 2
#           Puts it on,
# 2
#           WIDE SHOT of Rey sitting, alone and isolated, on the leg of
# 2
#           an ANCIENT, FALLEN AT-AT in which she lives.
# 2
#           Then, a distant ELECTRONIC SQUEAL -- instantly she's up,
# 2
#           helmet too big, she rips it off. Hears ANOTHER BEEPING
# 2
#           SQUEAL. She hurries to her QUARTERSTAFF and runs off.
# 2
#           Rey climbs a dune. RISE WITH HER, revealing BB-8, caught in
# 2
#           a NET but fighting back, being held by a TEEDO (a small,
# 2
#           brutish desert tyrant), who rides a LUGGABEAST. The teedo
# 2
#           YELLS at BB-8, who BEEPS madly, struggling to free himself.
# 2
#           Rey watches this injustice for a beat, finally YELLING OUT:
# 0
#                           REY
# 1
#            Tal'ama parqual!
# 2
#           The Teedo and BB-8 STOP, GO SILENT, turn to her.
# 0
#                           REY (CONT'D)
# 1
#            Parqual zatana!
# 2
#           A half beat and the Teedo YELLS SOMETHING BACK, threatening.
# 2
#           BB-8's head swivels to him, then back to Rey, like watching
# 2
#           a tennis match.
# 2
#           Rey angrily moves to them, pulling a knife from her pouch.
# 2
#           Rey starts CUTTING BB-8 out of the netting. The Teedo freaks
# 2
#           out, YELLING. Rey suddenly stands, turns to the Teedo and
# 2
#           says, fiercely:
# 0
#                           REY (CONT'D)
# 1
#            NOMA.
# 2
#           The Teedo barks a sort of "AHHHHH!" (As if to say, "GO TO
# 2
#           HELL!"), Then heads off on his beast. This prompts BB-8 to
# 2
#           start BEEP-YELLING at the departing bully, provocatively.
# 0
#                           REY (CONT'D)
# 1
#            Shhhh.
# 2
#           BB-8 quiets instantly. The two watch the Teedo head off.
# 2
#           Finally, BB-8 BEEPS a question. She KNEELS to him.
# 0
#                           REY (CONT'D)
# 1
#            That's just Teedo. Wants you for
# 1
#            parts. He has no respect for anyone.
# 1
#            Your antenna's bent.
# 1
#            (considers BB-8 for
# 1
#            the first time,
# 0
#                           STRAIGHTENS THE
# 0
#                           ANTENNA)
# 1
#            Where do you come from?
# 0
#                           (BB-8 BEEPS)
# 1
#            Classified. Really? Me too. Big
# 1
#            secret.
# 1
#            (points to horizon)
# 1
#            Niima Outpost is that way, stay off
# 1
#            Kelvin Ridge.
# 0
#                           (MORE)
# 0
#                           (CONTINUED)
# 3
#                          CONTINUED:
# 0
#                           REY (CONT'D)
# 1
#            Keep away from the Sinking Fields in
# 1
#            the north, you'll drown in the sand.
# 1
#            (stands, heads off)
# 2
#           BB-8 starts after her, BEEPS. She turns sharply, he stops.
# 0
#                           REY (CONT'D)
# 1
#            Don't follow me. Town is that way.
# 1
#            (he BEEPS again)
# 1
#            No!
# 2
#           She heads off again. Finally he BEEPS to her -- something
# 2
#           SWEET this time. That he is alone, scared, has no one else.
# 2
#           This makes her stop. She turns and looks at him. Not liking
# 2
#           him. But a gesture of her head says, reluctantly, "Come
# 2
#           on." BB-8 quickly moves to her. They head off together.
# 0
#                           REY (CONT'D)
# 1
#            In the morning, you go.
# 0
#                           (HE BEEPS)
# 1
#            You're welcome.
# 2
#           The two disappear behind a dune.
# 3
#           EXT. STAR DESTROYER - DAY
# 2
#           Three TIE fighters head to the massive ship high above Jakku.
# 3
#           INT. STAR DESTROYER HOLDING CELL - DAY
# 2
#           POE, shackled to a chair, BEATEN, wakes up.
# 0
#                           KYLO REN
# 1
#            I had no idea we had the best pilot
# 1
#            in the Resistance on board.
# 1
#            Comfortable?
# 2
#           Through battered lips:
# 0
#                           POE
# 1
#            Not really.
# 0
#                           KYLO REN
# 1
#            I'm impressed. No one has been able
# 1
#            to get out of you what you did with
# 1
#            the map.
# 0
#                           POE
# 1
#            Might wanna rethink your technique.
# 2
#           Kylo Ren says nothing, reaches out to him. Poe flinches in
# 2
#           the chair as Kylo Ren reaches for his face, not touching
# 2
#           him. Poe is soon in agony, remains in horrible silence --
# 0
#                           KYLO REN
# 1
#            Where is it?
# 0
#                           (CONTINUED)
# 3
#                          CONTINUED:
# 0
#                           POE
# 1
#            The Resistance will not be intimidated
# 1
#            by you.
# 0
#                           KYLO REN
# 1
#            Where... is it?
# 2
#           Poe can't take it -- he BEGINS TO SCREAM and we CUT TO:
# 3
#           INT. STAR DESTROYER CORRIDOR - DAY
# 2
#           WHOOOSH! The cell door SLIDES UP. Kylo Ren exits, fierce,
# 2
#           confronts GENERAL HUX (34, scary) who awaits him:
# 0
#                           KYLO REN
# 1
#            It's in a droid. A BB unit.
# 0
#                           GENERAL HUX
# 1
#            Well then. If it's on Jakku, we'll
# 1
#            soon have it.
# 0
#                           KYLO REN
# 1
#            I leave that to you.
# 3
#           EXT. NIIMA OUTPOST - DAY
# 2
#           BB-8 is dropped to the sand.
# 0
#                           REY
# 1
#            Don't give up. He still might show
# 1
#            up. Whoever it is you're waiting
# 1
#            for. Classified. I know all about
# 1
#            waiting.
# 2
#           BB-8 BEEPTALKS a question.
# 0
#                           REY (CONT'D)
# 1
#            For my family. They'll be back.
# 1
#            One day. Come on.
# 2
#           She tries to force a smile, but can't, really. She heads
# 2
#           off. BB-8 BEEPS... then heads after her.
# 3
#           INT. NIIMA TRADING STRUCTURE - DAY
# 2
#           Rey stands with BB-8 in front of Unkar Plutt, at his window.
# 2
#           He reviews her goods. He glances quickly at BB-8.
# 0
#                           UNKAR
# 1
#            These five pieces are worth... Let
# 1
#            me see here... One half portion.
# 0
#                           REY
# 0
#                           (OBJECTS)
# 1
#            Last week they were a half portion
# 1
#            each.
# 2
#           She hates him. He leans forward.
# 0
#                           (CONTINUED)
# 3
#                          CONTINUED:
# 0
#                           UNKAR
# 1
#            What about the droid?
# 0
#                           REY
# 1
#            What about him?
# 0
#                           UNKAR
# 1
#            I'll pay for him.
# 2
#           BB-8 doesn't like this at all. Rey is awkward, but curious.
# 0
#                           UNKAR (CONT'D)
# 1
#            Sixty portions.
# 2
#           CLOSE ON HER. Stunned. Literally hungry for this amount of
# 2
#           food, her stomach practically rumbles.
# 2
#           BB-8 sees her interest and BEEPS furiously, not liking this
# 2
#           conversation at all.
# 2
#           She looks at Unkar. Looks down at BB-8. Considers it all.
# 2
#           Finally, she hears herself say:
# 0
#                           REY
# 1
#            Actually... the droid's not for sale.
# 0
#                           (TO BB-8)
# 1
#            Come on.
# 2
#           Unkar furious. Rey, then BB-8, head out. Recovering, Unkar
# 2
#           watches her go with dark eyes. He picks up a communicator:
# 0
#                           UNKAR
# 1
#            Follow the girl and get that droid.
# 2
#           He SLAMS the service window door SHUT.
# 3
#           INT. STAR DESTROYER HOLDING CELL - DAY
# 2
#           The cell door WHOOSHES OPEN -- a STORMTROOPER enters. Poe
# 2
#           remains shackled, worse for wear. A TROOPER GUARD here.
# 0
#                           STORMTROOPER
# 1
#            Ren wants the prisoner.
# 2
#           TIGHT ON POE, in pain, drained, as the Guard unshackles him.
# 3
#           INT. STAR DESTROYER CORRIDOR - DAY
# 2
#           An exhausted, handcuffed Poe is walked down the corridor by
# 2
#           the Stormtrooper, who holds a blaster at Poe's body.
# 0
#                           STORMTROOPER
# 1
#            Turn here.
# 2
#           Poe turns into a narrow passageway --
# 3
#           INT. STAR DESTROYER NARROW PASSAGEWAY - DAY
# 2
#           Heading down the narrow hall the Stormtrooper stops Poe.
# 0
#                           (CONTINUED)
# 3
#                          CONTINUED:
# 0
#                           STORMTROOPER
# 1
#            Listen carefully: you do exactly as
# 1
#            I say, I can get you out of here.
# 0
#                           POE
# 0
#                           (COMING TO)
# 1
#            If -- what--?
# 2
#           The Stormtrooper pulls off his helmet: IT IS FN-2187.
# 0
#                           FN-2187
# 1
#            This is a rescue, I'm helping you
# 1
#            escape. Can you fly a TIE fighter?
# 0
#                           POE
# 1
#            You with the Resistance--?!
# 0
#                           FN-2187
# 1
#            What?
# 0
#                           (THAT'S CRAZY)
# 1
#            No no no! I'm breaking you out.
# 1
#            Can you fly a TIE fighter?
# 0
#                           POE
# 1
#            I can fly anything. Why, why are
# 1
#            you helping me?
# 0
#                           FN-2187
# 1
#            Because it's the right thing to do.
# 0
#                           POE
# 1
#            (it hits him)
# 1
#            You need a pilot.
# 0
#                           FN-2187
# 1
#            I need a pilot.
# 2
#           And Poe, seeing this is for real, smiles a hero's smile.
# 0
#                           POE
# 1
#            We're gonna do this.
# 0
#                           FN-2187
# 1
#            (unsure but hopeful)
# 1
#            ... Yeah?
# 3
#           INT. STAR DESTROYER HANGAR - DAY
# 2
#           WIDE SHOT ESTABLISHING the hangar. Find FN-2187, again
# 2
#           masked, walking with Poe. By all appearances he's escorting
# 2
#           a prisoner. A group of OFFICERS passes in the opposite
# 2
#           direction.
# 0
#                           FN-2187
# 1
#            Okay, stay calm, stay calm.
# 0
#                           POE
# 1
#            I am calm.
# 0
#                           (CONTINUED)
# 3
#                          CONTINUED:
# 0
#                           FN-2187
# 1
#            I'm talking to myself.
# 0
#                           (BEAT)
# 1
#            Not yet. Okay, go. This way.
# 2
#           FN-2187 walks quickly toward the far wall -- Poe follows --
# 2
#           up the stairs to a two-man SPECIAL FORCES TIE FIGHTER --
# 3
#           INT. TIE FIGHTER - DAY
# 2
#           FN-2187 and Poe (wincing, sore) drop into the back-to-back
# 2
#           cockpit. FN-2187 pulls off his helmet as Poe removes his
# 2
#           cuffs and jacket, fires up the ship with excitement.
# 0
#                           POE
# 1
#            I always wanted to fly one of these
# 1
#            things. Can ya shoot?
# 0
#                           FN-2187
# 1
#            Blasters, I can!
# 0
#                           POE
# 1
#            Okay, same principal! Use the toggle
# 1
#            on the left to switch between
# 1
#            missiles, cannons, and mag pulse --
# 1
#            use the site on the right to aim,
# 1
#            triggers to fire!
# 0
#                           FN-2187
# 1
#            This is very complicated
# 2
#           FWOOOOOOM! The TIE FIGHTER LURCHES FORWARD --
# 0
#                           POE
# 1
#            I can fix this.
# 3
#           INT. HANGAR SIX CONTROL ROOM - DAY
# 2
#           WIDE: see the ship STRUGGLE TO RISE, CABLES connected to it --
# 2
#           PULL BACK FAST to REVEAL we're inside the main control room.
# 1
#            STAR DESTROYER TECHNICIAN
# 1
#            We have an unsanctioned departure
# 1
#            from bay two.
# 2
#           WHIP TO a FIRST ORDER COLONEL, who responds:
# 1
#            FIRST ORDER COLONEL
# 1
#            Alert General Hux and stop that
# 1
#            fighter.
# 3
#           INT. STAR DESTROYER HANGAR - DAY
# 2
#           The TIE Fighter LIFTS OFF from the bay, rips CHARGING cables!
# 2
#           Stormtroopers UNPACK and aim MEGABLASTERS.
# 3
#           INT. TIE FIGHTER - DAY
# 2
#           FN-2187 opens fire.
# 3
#           INT. STAR DESTROYER HANGAR - DAY
# 2
#           FN-2187 TEARS UP PARKED TIE FIGHTERS and GUN EMPLACEMENTS
# 2
#           WITH WELL-AIMED, STRATEGIC LASER BLASTS! Hits the CONTROL
# 2
#           ROOM!
# 3
#           INT. HANGAR SIX CONTROL ROOM - DAY
# 2
#           THE WINDOWS ARE BLOWN IN BY LASER BLASTS!
# 3
#           INT. TIE FIGHTER COCKPIT - DAY
# 0
#                           POE
# 1
#            I got it!
# 3
#           EXT. STAR DESTROYER - DAY
# 2
#           The TIE Fighter blasts from the ship --
# 3
#           INT. TIE FIGHTER - DAY
# 2
#           Poe pilots -- amazed, almost enjoying it.
# 0
#                           POE
# 1
#            Woooahhh! This thing really moves.
# 1
#            All right, we gotta take out as many
# 1
#            cannons as we can or we're not gonna
# 1
#            get very far!
# 0
#                           FN-2187
# 1
#            All right!
# 0
#                           POE
# 1
#            I'm gonna get us in position, just
# 1
#            stay sharp!
# 3
#           EXT. STAR DESTROYER - DAY
# 2
#           The TIE Fighter ARCS BACK, DIVES THROUGH THE OPENING BETWEEN
# 2
#           THE LEVELS OF THE MASSIVE SHIP, then FLIES DOWN AND BACK,
# 2
#           along the ship's belly --
# 3
#           INT. TIE FIGHTER - DAY
# 2
#           Poe flies toward the CANONS --
# 0
#                           POE
# 1
#            Up ahead! Up ahead! You see it?
# 1
#            I've got us dead centered. It's a
# 1
#            clean shot.
# 0
#                           FN-2187
# 1
#            Okay, got it.
# 2
#           FN-2187 gets a target, FIRES!
# 3
#           EXT. STAR DESTROYER - DAY
# 2
#           LASERS BLAST from the TIE Fighter -- A SERIES OF CANNONS
# 2
#           EXPLODE! Our TIE Fighter SLICES THROUGH the debris!
# 3
#           INT. TIE FIGHTER - DAY
# 2
#           FN-2187 YELLS in celebration:
# 0
#                           FN-2187
# 1
#            YES! You see that?! DID YOU SEE
# 1
#            THAT?
# 0
#                           POE
# 1
#            I saw it! Hey, what's your name?
# 0
#                           FN-2187
# 1
#            FN-2187!
# 2
#           Poe reacts, this tells him volumes about FN-2187's history.
# 0
#                           POE
# 1
#            FN-whaa?
# 0
#                           FN-2187
# 1
#            That's the only name they ever gave
# 1
#            me!
# 0
#                           POE
# 1
#            Well I ain't using it! FN, huh?
# 1
#            Finn. I'm gonna call you Finn!
# 1
#            That all right?
# 2
#           Even in the madness, Finn can't suppress his smile.
# 0
#                           FINN
# 1
#            "Finn." Yeah, "Finn", I like that!
# 1
#            I like that!
# 0
#                           POE
# 1
#            I'm Poe. Poe Dameron.
# 0
#                           FINN
# 1
#            Good to meet you, Poe!
# 0
#                           POE
# 1
#            Good to meet you too, Finn!
# 3
#           INT. STAR DESTROYER MAIN BRIDGE - DAY
# 2
#           General Hux looks over the shoulder of LIEUTENANT MITAKA, at
# 2
#           a console.
# 0
#                           LIEUTENANT MITAKA
# 1
#            Sir, they've taken out our turbolasers--
# 0
#                           GENERAL HUX
# 1
#            Use the ventral cannons.
# 0
#                           (CONTINUED)
# 3
#                          CONTINUED:
# 0
#                           LIEUTENANT MITAKA
# 1
#            Yes, sir. Bringing them online --
# 1
#            KYLO REN (O.S.)
# 1
#            General Hux. Is it the Resistance
# 1
#            pilot?
# 2
#           Hux turns: Kylo Ren enters fast, looms large, angry.
# 0
#                           GENERAL HUX
# 1
#            Yes, and he had help.
# 0
#                           (VEXED)
# 1
#            From one of our own.
# 2
#           PUSH IN ON REN as Hux says:
# 1
#            GENERAL HUX (CONT'D)
# 1
#            We're checking the registers now to
# 1
#            identify which Stormtrooper it was.
# 0
#                           KYLO REN
# 1
#            ... The one from the village. FN-
# 1
#            2187.
# 2
#           Hux is unnerved that Ren knows -- he chalks it up to Ren's
# 2
#           Force ability. Kylo Ren heads off.
# 0
#                           LIEUTENANT MITAKA
# 1
#            Sir. Ventral cannons hot.
# 0
#                           GENERAL HUX
# 1
#            Fire.
# 3
#           EXT. STAR DESTROYER - DAY
# 2
#           Massive WARHEAD LAUNCHERS SPIN and FIRE BLASTS toward the
# 2
#           TIE fighter, which flies EVASIVE MANEUVERS -- most blasts
# 2
#           hit the DEBRIS from the TURBOLASER DESTRUCTION.
# 2
#           The TIE fighter then PULLS A BIG TURN, BACK TOWARD JAKKU,
# 2
#           THE SANDY PLANET WHERE POE LEFT BB-8.
# 3
#           INT. TIE FIGHTER - DAY
# 0
#                           POE
# 1
#            One's coming towards you. My right,
# 1
#            your left. Do you see it?
# 0
#                           FINN
# 1
#            Hold on! I see it!
# 0
#                           POE
# 1
#            Nice shot.
# 2
#           Finn looks up suddenly in alarm --
# 0
#                           FINN
# 1
#            Where are you going?
# 0
#                           (CONTINUED)
# 3
#                          CONTINUED:
# 0
#                           POE
# 1
#            We're going back to Jakku. That's
# 1
#            where.
# 0
#                           FINN
# 1
#            No no no! We can't go back to Jakku!
# 1
#            We need to get outta this system!
# 2
#           NEAR-MISS LASER BLASTS as Poe pilots aggressively.
# 0
#                           POE
# 1
#            I got to get to my droid before the
# 1
#            First Order does!
# 0
#                           FINN
# 1
#            What - a droid?!
# 0
#                           POE
# 1
#            That's right. He's a BB unit! Orange
# 1
#            and white: one of a kind.
# 0
#                           FINN
# 1
#            I don't care what color he is! No
# 1
#            droid can be that important!
# 0
#                           POE
# 1
#            This one is, pal.
# 0
#                           FINN
# 1
#            We need to get as far away from the
# 1
#            First Order as we can! We go back
# 1
#            to Jakku, we die!
# 0
#                           POE
# 1
#            That droid's got a map that leads
# 1
#            straight to Luke Skywalker!
# 0
#                           FINN
# 1
#            Oh, you gotta be kidding me!!! I--
# 2
#           Suddenly BAM! THEY ARE HIT!
# 3
#           EXT. TIE FIGHTER - DAY
# 2
#           The TIE FIGHTER SPARKS AND SMOKES, SPIRALING out of control
# 2
#           toward the surface of Jakku!
# 3
#           INT. STAR DESTROYER MAIN BRIDGE - DAY
# 2
#           Captain Phasma and General Hux stand before a holographic
# 2
#           projection detailing FN-2187's service records.
# 0
#                           CAPTAIN PHASMA
# 1
#            FN-2187 reported to my division, was
# 1
#            evaluated and sent to Reconditioning.
# 0
#                           GENERAL HUX
# 1
#            No prior signs of non-conformity?
# 0
#                           (CONTINUED)
# 3
#                          CONTINUED:
# 0
#                           CAPTAIN PHASMA
# 1
#            This was his first offense.
# 2
#           A technician checks her readings, reports to General Hux.
# 0
#                           TECHNICIAN #1
# 1
#            General. They've been hit.
# 0
#                           GENERAL HUX
# 1
#            Destroyed?
# 0
#                           TECHNICIAN #1
# 0
#                           (GETTING READINGS)
# 1
#            Disabled. They were headed back to
# 1
#            Jakku -- the fighter's projected to
# 1
#            crash in the Goazon badlands.
# 0
#                           GENERAL HUX
# 1
#            They were going back for the droid --
# 1
#            send a squad to the wreckage.
# 3
#           EXT. JAKKU DESERT - DAY
# 2
#           TIGHT ON FINN'S FACE: His EYES OPEN. He goes from unconscious
# 2
#           to terrified, fast. He sits up, looks around. CUT BACK
# 2
#           WIDE: he sits in the middle of an EPIC DESERT, DUNES FOREVER.
# 2
#           A BLACK CHUTE blows in the wind behind him, scattered debris.
# 2
#           Then he sees, over distant dunes, RISING BLACK SMOKE. He
# 2
#           gets up -- moves toward it, calling out:
# 0
#                           FINN
# 1
#            Poe! Poe!
# 2
#           Finn scrambles over the massive dune to the TIE FIGHTER,
# 2
#           SMOKING AND ON FIRE, small debris around it. He thinks he
# 2
#           sees POE'S ARM -- he pulls on it, but it's JUST POE'S JACKET.
# 2
#           He throws that off and tries to find a way in -- even a way
# 2
#           to LOOK INSIDE, but the smoke and heat make it impossible.
# 0
#                           FINN (CONT'D)
# 1
#            Poe!!! POE!
# 2
#           Suddenly the ship BEGINS TO SINK -- like it's being CONSUMED
# 2
#           INTO QUICKSAND -- Finn is slipping in too --
# 0
#                           FINN (CONT'D)
# 1
#            POE!!! POE!!!
# 2
#           It becomes clear fast: if Finn doesn't get away, he's gonna
# 2
#           get sucked in too! So Finn scampers away from the TIE FIGHTER
# 2
#           as it SINKS INTO THE SAND! We're in the Sinking Fields. A
# 2
#           few moments and IT'S GONE.
# 2
#           Finn's out of breath. Horrified. Then A GIANT EXPLOSION
# 2
#           ERUPTS FROM below, SENDING SAND AND DEBRIS EVERYWHERE!
# 2
#           Finn sees this, disoriented, scared, exhausted and defeated.
# 2
#           And all alone.
# 3
#           EXT. DESERT - DAY
# 2
#           ENDLESS DUNES BEHIND HIM, Finn walks, removing pieces of his
# 2
#           Stormtrooper gear, using Poe's FLIGHT JACKET for shade.
# 3
#           EXT. DESERT - DAY
# 2
#           Exhausted, Finn continues his trek across the endless, sandy
# 2
#           nothingness.
# 3
#           EXT. DESERT - DAY
# 2
#           Finn, parched and losing hope, he walks to the edge of a
# 2
#           massive dune, looks out into the epic valley below. Miles
# 2
#           ahead: NIIMA OUTPOST.
# 3
#           INT. STAR DESTROYER - BRIDGE - DAY
# 2
#           General Hux and Kylo Ren walk the length of the bridge.
# 0
#                           GENERAL HUX
# 1
#            Supreme Leader Snoke was explicit.
# 1
#            Capture the droid if we can, but
# 1
#            destroy it if we must.
# 0
#                           KYLO REN
# 1
#            How capable are your soldiers,
# 1
#            General?
# 0
#                           GENERAL HUX
# 0
#                           (WITH VITRIOL)
# 1
#            I won't have you question my methods.
# 0
#                           KYLO REN
# 1
#            They're obviously skilled at
# 1
#            committing high treason. Perhaps
# 1
#            Leader Snoke should consider using a
# 1
#            clone army.
# 0
#                           GENERAL HUX
# 0
#                           (YOU SON-OF-A-BITCH)
# 1
#            My men are exceptionally trained --
# 1
#            programmed from birth--
# 0
#                           KYLO REN
# 1
#            Then they should have no problem
# 1
#            retrieving the droid. Unharmed.
# 0
#                           GENERAL HUX
# 1
#            Careful, Ren. That your "personal
# 1
#            interests" not interfere with orders
# 1
#            from Leader Snoke.
# 0
#                           KYLO REN
# 1
#            I want that map. For your sake, I
# 1
#            suggest you get it.
# 2
#           Ren heads off. Hux hates him.
# 3
#           EXT. NIIMA OUTPOST - DAY
# 2
#           Sun-scorched and exhausted, Finn stumbles out of the desert
# 2
#           into the Outpost. In a heatstroke daze he moves past enormous
# 2
#           old SHIP PARTS, MERCHANTS, SCAVENGERS and TENTED STALLS.
# 0
#                           FINN
# 1
#            Water... water... water..
# 2
#           He sees a WATER TROUGH where a filthy, slobbering hippo-like
# 2
#           creature (a HAPPABORE) DRINKS. Finn moves to it, uses his
# 2
#           hands to desperately DRINK the filthy water. After a couple
# 2
#           swallows he SPITS IT OUT, disgusted.
# 0
#                           FINN (CONT'D)
# 1
#            -- Awgh, GAH!
# 2
#           But he's parched and immediately RETURNS FOR MORE.
# 2
#           ACROSS THE MARKETPLACE, REY kneels with an emphatically
# 2
#           BEEPING BB-8.
# 2
#           Just then, TWO of UNKAR'S THUGS approach and stop her. One
# 2
#           clearly tells her that they're taking the droid. BB-8 reacts
# 2
#           nervously as Rey resists them -- one pulls a SACK over BB-8
# 2
#           while the other grabs Rey's arm -- in the tussle, Rey KNOCKS
# 2
#           OVER METAL URNS for sale --
# 2
#           Finn, still drinking, is PUSHED OVER by the happabore. He
# 2
#           falls to the ground, then turns to look when he HEARS
# 2
#           CRASHING. He sees, through the tents, REY FIGHTING.
# 2
#           He moves UP CLOSER to help this young woman being accosted --
# 2
#           but he STOPS when Rey begins to FIGHT BACK -- scrappy and
# 2
#           feral, she KICKS, BITES and HITS. Finn is taken aback as
# 2
#           she DEFEATS the attackers, who hit the sand, hard.
# 2
#           Finn just watches, stunned.
# 2
#           Rey moves to the COVERED BB-8 -- PULLS THE SACK OFF OF HIM.
# 2
#           Finn cannot believe his eyes. IT'S POE'S DROID!
# 2
#           Rey talks to BB-8, who, nervous now, looks around and...
# 2
#           SEES FINN! BB-8 STARTS BEEPING like crazy. Then something
# 2
#           insane happens: REY LOOKS AT FINN.
# 0
#                           REY
# 1
#            (To BB-8) Who? Him?
# 2
#           Finn is confused. Rey stands, staring at Finn, defiant.
# 2
#           Finn can feel trouble coming -- and Rey begins CHARGING AT
# 2
#           HIM, quarterstaff in hand.
# 2
#           Realizing he's the target, Finn begins to RUN -- away from
# 2
#           her, through the tent marketplace. Rey goes after him -- he
# 2
#           turns a corner -- then another -- then BAM! She's got
# 2
#           ahead of him and SLAMS HIM TO THE GROUND WITH HER STAFF!
# 2
#           Finn is on his back, out of breath and freaked out. She
# 2
#           holds the staff on him threateningly:
# 0
#                           REY
# 1
#            What's your hurry, thief?
# 0
#                           FINN
# 1
#            What--?! Thief?
# 2
#           BB-8 ROLLS UP FAST, MOVES TO FINN -- a WELDING ARM TELESCOPES
# 2
#           FROM HIS BODY AND SHOCKS FINN!
# 0
#                           FINN (CONT'D)
# 1
#            OW! HEY! What?!
# 0
#                           REY
# 1
#            The jacket! This droid says you
# 1
#            stole it!
# 0
#                           FINN
# 1
#            I've had a pretty messed up day,
# 1
#            alright?! So I'd appreciate it you
# 1
#            stop accusing me -- OW!!!
# 1
#            (BB-8 has ZAPPED him
# 0
#                           AGAIN)
# 1
#            STOP IT!
# 0
#                           REY
# 1
#            Where'd you get it? It belongs to
# 1
#            his master.
# 2
#           Finn looks at her -- then the agitated droid, Finn's mind
# 2
#           racing. He puts it all together. Frustrated, but sighs
# 2
#           heavily, needing to respond somehow. So he makes a hard
# 2
#           decision: to tell the truth.
# 0
#                           FINN
# 1
#            It belonged to Poe Dameron. That
# 1
#            was his name, right?
# 2
#           Rey and BB-8 react, surprised and wanting more.
# 0
#                           FINN (CONT'D)
# 1
#            He was captured... by the First Order!
# 1
#            I helped him escape but our ship
# 1
#            crashed.
# 0
#                           (RELIVING IT)
# 1
#            Poe didn't make it.
# 1
#            (sees BB-8 is sad,
# 0
#                           ROLLS OFF)
# 1
#            Look, I tried to help him. I'm
# 1
#            sorry...
# 2
#           BB-8 heads off to the side, depressed. Rey watches BB-8,
# 2
#           then considers Finn again. Says, a bit impressed:
# 0
#                           REY
# 1
#            So you're with the Resistance?
# 0
#                           (CONTINUED)
# 3
#                          CONTINUED:
# 2
# ...
# 2
#           Finn is stunned -- unprepared for this fierceness.
# 2
#           Rey sees this -- Kylo Ren unleashes a MERCILESS SERIES OF
# 2
#           BLOWS, pushing Finn further and further back until he loses
# 2
#           balance.
# 0
#                           (CONTINUED)
# 3
#                          CONTINUED:
# 2
#           That's when KYLO REN STRIKES: HE LANDS A BLOW TO FINN'S TORSO --
# 2
#           LUKE'S LIGHTSABER FLIES FROM FINN'S HAND, THROWN TWENTY FEET!
# 2
#           Kylo Ren TURNS OFF HIS LIGHTSABER and REACHES FOR LUKE'S
# 2
#           LIGHTSABER -- BECKONING IT WITH THE FORCE.
# 2
#           LUKE'S LIGHTSABER VIBRATES IN THE SNOW.
# 2
#           Kylo Ren GESTURES, INCREASES HIS POWER -- LUKE'S LIGHTSABER
# 2
#           FINALLY FLIES OUT OF THE SNOW, BULLETS TOWARD KYLO REN --
# 2
#           -- AND SPEEDS PAST HIM!
# 2
#           KYLO REN TURNS TO SEE LUKE'S LIGHTSABER LAND IN THE HAND OF
# 2
#           REY, WHO STANDS, FACING HIM, HAVING REACHED FOR IT HERSELF,
# 2
#           BUT UTTERLY STUNNED THAT IT LANDED IN HER HAND! SHE IS
# 2
#           SHOCKED -- AND SO IS KYLO REN!
# 2
#           Holding it with both hands, SHE IGNITES LUKE'S LIGHTSABER
# 2
#           FOR THE FIRST TIME, HER EYES BLAZING.
# 2
#           Kylo Ren IGNITES HIS SABER.
# 2
#           It's REY who charges now -- Kylo Ren immediately on the
# 2
#           defensive. They BATTLE POWERFULLY -- He is clearly rocked
# 2
#           by her raw, innate skill.
# 3
#           INT. X-WING - NIGHT
# 0
#                           NIV LEK
# 1
#            We just lost R-1!
# 0
#                           JESS
# 1
#            We're overwhelmed! What do we do?
# 1
#            It isn't working!
# 2
#           Another pilot looks down -- SEES THE EXPLOSION -- coming
# 2
#           from the OSCILLATOR. Relatively small, it's an opening:
# 0
#                           YOLO ZIFF
# 1
#            Black Leader, there's a brand new
# 1
#            hole in that oscillator. Looks like
# 1
#            our friends got in!
# 0
#                           POE
# 1
#            Red Four! Red Six! Cover us!
# 1
#            LT. BASTIAN
# 1
#            I'm on it!
# 0
#                           ELLO ASTY
# 1
#            Roger!
# 0
#                           POE
# 1
#            Everybody else, hit the target hard!
# 1
#            Give it everything you got!
# 2
#           And the X-WINGS DIVE and BLAST the OSCILLATOR --
# 3
#           EXT. STARKILLER BASE - OSCILLATOR - NIGHT
# 2
#           Another two X-wings -- including Poe's -- soar through the
# 2
#           trench leading to the oscillator structure!
# 0
#                           POE
# 1
#            I need some help here! I need some
# 1
#            help!
# 1
#            LT. BASTIAN
# 1
#            I'm coming in!
# 0
#                           JESS
# 1
#            Watch out!
# 0
#                           ELLO ASTY
# 1
#            I'm hit!
# 2
#           The alien pilot's X-wing is blasted to pieces.
# 0
#                           POE
# 1
#            All teams - I'm going in! Pull up
# 1
#            and cover me!
# 0
#                           NIV LEK
# 1
#            Copy that, Black Leader! Good luck,
# 1
#            Poe!
# 2
#           The trailing X-wings peel off as Poe's black fighter darts
# 2
#           into the fiery breach.
# 3
#           INT. STARKILLER BASE - CONTROL ROOM - NEAR DARKNESS
# 2
#           Outside, the SUN ALMOST COMPLETELY GONE -- PULL BACK THROUGH
# 2
#           THE WINDOW TO REVEAL A STARKILLER TECHNICIAN:
# 0
#                           STARKILLER TECHNICIAN
# 1
#            Weapon at full capacity in thirty
# 1
#            seconds.
# 0
#                           GENERAL HUX
# 1
#            Prepare to fire.
# 3
#           EXT. STARKILLER BASE - OSCILLATOR - NIGHT
# 2
#           Poe's X-wing weaves through the breach. A pursuing TIE
# 2
#           fighter does not clear the gap, leaving Poe to circle the
# 2
#           interior of the unguarded structure, firing volley after
# 2
#           volley of torpedoes.
# 3
#           EXT. STARKILLER BASE - OSCILLATOR - NIGHT
# 2
#           The remaining X-Wings -- including Poe's -- BLAST the place --
# 2
#           and the structure begins to CRATER, deep underground
# 2
#           EXPLOSIONS!
# 3
#           EXT. FOREST - NIGHT
# 2
#           Amid the BARE WHITE TREES, ONLY TWO LIGHTSABERS -- LUKE'S
# 2
#           BLUE AND REN'S YELLOW-RED -- ILLUMINATE the FLURRIES OF SNOW
# 2
#           as Rey and Kylo Ren BATTLE HARD.
# 2
#           She seems to be, impossibly, STRONGER THAN HE IS for half a
# 2
#           dozen blows -- until he FINDS HIS STRENGTH and FIGHTS BACK --
# 2
#           MOVING FORWARD and PUSHING REY BACK, into the forest.
# 2
#           Suddenly a COLOSSAL CHUNK OF THE FOREST RIGHT BEHIND REY
# 2
#           DROPS AWAY! Rey is suddenly fighting on the EDGE OF A
# 2
#           MASSIVE, BRAND NEW CLIFF!
# 0
#                           KYLO REN
# 1
#            You need a teacher! I can show you
# 1
#            the ways of the Force!
# 0
#                           REY
# 1
#            The Force.
# 2
#           Rey closes her eyes for a long beat. When Rey opens them,
# 2
#           she is centered, fortified, and she POUNDS BACK, SINGLE HANDED
# 2
#           SWIPES, hitting Ren's gnarly, spitting saber with incredible
# 2
#           FORCE. It's so fast now, so furious, that Kylo Ren FALLS
# 2
#           BACK -- She ATTACKS HARDER!
# 2
#           Ren gets up again but she HITS HIS SABER'S HILT -- HIS BLADE
# 2
#           GOES FLYING OFF, TUMBLING INTO THE SNOW -- and she SLASHES
# 2
#           AGAIN AND AGAIN AND HITS KYLO REN SQUARE IN THE HEAD AND
# 2
#           CHEST. HE GOES DOWN, SUDDENLY A FEARFUL MAN, A LARGE BURN
# 2
#           SCAR SLASHED ACROSS HIS FACE! He still reaches for his saber.
# 2
#           And she could kill him -- right now, with ONE VICIOUS STRIKE!
# 2
#           But she stops. Realizing she stands on a greater edge than
# 2
#           even the cliff -- the edge of the dark side. The earth
# 2
#           SHAKES. The earth splits. A gully forms.
# 3
#           INT. STARKILLER BASE - CONTROL ROOM - NIGHT
# 2
#           The area where the RALLY was held is now COLLAPSING into a
# 2
#           giant sink hole! We WHIP PAN to a YOUNG TECHNICIAN, who
# 2
#           watches this out the control room window in horror. He
# 2
#           hurries off, passing COLONEL DATOO, who admonishes:
# 0
#                           COLONEL DATOO
# 1
#            Lieutenant, get back to your station!
# 0
#                           YOUNG TECHNICIAN
# 1
#            (stops, fleetingly)
# 1
#            Just look. We won't survive -- even
# 1
#            Hux has gone!
# 2
#           As he hurries off, WE HEAR:
# 1
#            GENERAL HUX (V.O.)
# 1
#            Supreme Leader.
# 3
#           INT. STARKILLER BASE - ASSEMBLY ROOM - NIGHT
# 2
#           Hux stands before SNOKE'S IMAGE. Relative quiet here, but
# 2
#           distant SOUNDS OF DESTRUCTION. Hux tries to keep it together
# 2
#           but is horrified, heartsick:
# 0
#                           GENERAL HUX
# 1
#            The fuel cells have ruptured. The
# 1
#            collapse of the planet has begun.
# 2
#           Snoke takes this in. Furious, desolate... knowing.
# 0
#                           SNOKE
# 1
#            Leave the base at once and come to
# 1
#            me with Kylo Ren.
# 0
#                           (GRIM)
# 1
#            It is time to complete his training.
# 3
#           EXT. FOREST - NIGHT
# 2
#           Rey turns, runs a hundred feet through the forest to:
# 2
#           FINN, who lies, near death, not far from where the GROUND
# 2
#           FELL AWAY. Rey falls to her knees near him, turns him over,
# 2
#           sees his cauterized but possibly fatal wound.
# 0
#                           REY
# 1
#            Finn! Finn...
# 2
#           Tears come to her eyes as she lifts him, holds his lifeless
# 2
#           body in her arms. Snow flurries around them as she cries,
# 2
#           holding this boy who she just met, who she already adores.
# 2
#           They are left here to die -- nearby MORE TREES DROP as the
# 2
#           planet continues to COLLAPSE. And just as it seems like all
# 2
#           is lost... Her wet eyes look up to see:
# 2
#           LIGHTS RISE FROM THE NEWLY-FORMED CANYON -- IT'S A SHIP WE
# 2
#           KNOW -- IT'S THE MILLENNIUM FALCON -- and its lights
# 2
#           ILLUMINATE REY, WHOSE FACE FILLS WITH HOPE!
# 2
#           CHEWIE IS AT THE CONTROLS. He ROARS to them!
# 3
#           EXT. FALCON - NIGHT
# 2
#           Chewie exits the ship.
# 2
#           MOMENTS LATER Chewie CARRIES FINN up the ramp. Rey hurries
# 2
#           with them back into the ship --
# 3
#           INT. FALCON - NIGHT
# 2
#           Chewie carries Finn inside, followed by Rey.
# 3
#           EXT. SPACE - NIGHT
# 2
#           And we FLY WITH THE FALCON as it leaves the planet -- we can
# 2
#           see CHEWIE AND REY PILOTING, the COLLAPSING PLANET BEHIND
# 2
#           US. The Resistance X-wings, led by Poe, follow the Falcon.
# 3
#           INT. X-WING - NIGHT
# 0
#                           POE
# 1
#            All teams! I got eyes on them!
# 0
#                           SNAP
# 1
#            Yes!
# 2
#           The X-wings ROAR OFF, skyward as the MUSIC SOARS, the PLANET
# 2
#           IMPLODES -- THE SUNLIGHT IT CONTAINS BURSTS FORTH, and as we
# 2
#           get further and further distance from what was Starkiller
# 2
#           Base, we witness the REBIRTH OF A SUN. Light restored to a
# 2
#           corner of the galaxy.
# 2
#           The Millennium Falcon and the X-wings RIP THROUGH SPACE,
# 2
#           headed home.
# 0
#                           POE
# 1
#            Our job's done here. Let's go home!
# 3
#           EXT. D'QAR - DAY
# 2
#           ESTABLISHING SHOT as the Falcon on the landing strip.
# 3
#           EXT. RESISTANCE BASE - DAY
# 2
#           The Falcon has landed among the remaining Resistance ships.
# 2
#           Poe is there, watching as Chewie scuttles down the ramp
# 2
#           carrying an unconscious Finn. Medical Personnel and Officers,
# 2
#           meet them, usher them inside.
# 0
#                           MEDIC
# 1
#            Easy, easy. He's hurt. We've got a
# 1
#            heartbeat.
# 2
#           Rey walks down the ramp and sees, for the first time, Leia.
# 2
#           C-3PO and BB-8 behind her. The crowds are cheering.
# 2
#           Rey is so sad for Leia, so sorry.
# 2
#           The two women move for each other. And Leia takes Rey's
# 2
#           face in her hands. Despite her heartbreak, she is grateful.
# 2
#           She embraces Rey. A mother's embrace.
# 2
#           Rey cries, too, in this emotional first meeting.
# 3
#           INT. RESISTANCE BASE - DAY
# 2
#           Chewbacca sits quietly, as do many in the base, mourning
# 2
#           their losses.
# 2
#           As BB-8 approaches R2-D2, the long dormant droid suddenly
# 2
#           stirs. The droids beep at each other.
# 0
#                           C-3PO
# 1
#            R2-D2! You've come back! You found
# 1
#            what? How dare you call me that!
# 0
#                           (MORE)
# 0
#                           (CONTINUED)
# 3
#                          CONTINUED:
# 1
#            C-3PO (CONT'D)
# 1
#            (he swats R2-D2, who
# 0
#                           CONTINUES BEEPING)
# 1
#            Find Master Luke how? Come, R2! We
# 1
#            must go tell the others at once!
# 3
#           INT. RESISTANCE BASE - DAY
# 2
#           Leia stands alone and in silence, heartbroken.
# 1
#            C-3PO (O.S.)
# 1
#            General? Excuse me, General?
# 2
#           Leia turns to see droids.
# 1
#            C-3PO (CONT'D)
# 1
#            R2-D2 may contain some much needed
# 1
#            good news.
# 0
#                           LEIA
# 1
#            Tell me.
# 2
#           Rey stands with Leia, Poe C-3PO, BB-8 and a handful of
# 2
#           Resistance Officers. Suddenly R2-D2 PROJECTS A HOLOGRAM! A
# 2
#           LARGE NAVIGATIONAL MAP WITH A SPECIFIC MISSING CHUNK!
# 2
#           BB-8 BEEPS -- Poe turns to him --
# 0
#                           POE
# 1
#            Yeah, all right, buddy, hold on --
# 2
#           Poe runs over -- removes the ancient data device that Lor
# 2
#           San Tekka had given him from a base computer. He inserts it
# 2
#           back inside BB-8, who then PROJECTS HIS MAP -- which he
# 2
#           SHRINKS DOWN TO SIZE -- and the two droids MOVE SLIGHTLY --
# 2
#           TOGETHER -- THE TWO HOLOGRAMS UNITE, BB-8'S PIECE FILLING IN
# 2
#           R2-D2'S PERFECTLY!
# 2
#           Everyone REACTS -- amazed --
# 0
#                           C-3PO
# 1
#            Oh! The map! It is complete!
# 0
#                           LEIA
# 1
#            (hand on her heart)
# 1
#            -- Luke --
# 2
#           Suddenly there are CHEERS AND EMBRACES.
# 2
#           C-3PO leans down to R2-D2 and says, quietly, sweetly:
# 0
#                           C-3PO
# 1
#            (to R2-D2)
# 1
#            Oh my dear friend. How I've missed
# 1
#            you.
# 3
#           INT. RESISTANCE BASE - I.C.U. - DAY
# 2
#           A NEW DAY. Finn, unconscious in an I.C.U. POD. His fate
# 2
#           uncertain. Rey sits with him. Deeply worried. Finally she
# 2
#           leans in, close to him. She kisses him and says, quietly,
# 2
#           despite her fear:
# 0
#                           REY
# 1
#            We'll see each other again. I believe
# 1
#            that. Thank you, my friend.
# 3
#           EXT. D'QAR - DAY
# 2
#           Chewie does last minute checks of the Falcon. Rey stands
# 2
#           with Leia a beat and then turns to head to the Falcon. As
# 2
#           Rey walks off, she hears Leia call out:
# 0
#                           LEIA
# 1
#            Rey.
# 2
#           Rey turns around.
# 0
#                           LEIA (CONT'D)
# 1
#            May the Force be with you.
# 2
#           This fills Rey up. She smiles gratefully. Rey crosses to
# 2
#           the Falcon.
# 3
#           INT. MILLENNIUM FALCON - COCKPIT - DAY
# 2
#           Rey sits in the pilot seat, Chewie as co-pilot. Rey looks
# 2
#           at him compassionately.
# 2
#           Rey FLICKS SWITCHES and --
# 3
#           EXT. D'QAR - DAY
# 2
#           The Millennium Falcon RISES.
# 2
#           Leia, with Poe, BB-8, and C-3PO (with his proper arm
# 2
#           replaced), watches the next generation of Jedi begin her
# 2
#           journey.
# 3
#           EXT. SPACE - DAY
# 2
#           The Falcon FLIES through space and BLASTS to LIGHTSPEED.
# 3
#           EXT. AHCH-TO - DAY
# 2
#           A pristine and mighty OCEAN. Endless BLUE, dotted with
# 2
#           random, beautiful, mountainous BLACK ROCK ISLANDS, dotted
# 2
#           with countless GREEN TREES.
# 2
#           The Millennium Falcon FLIES INTO VIEW, BANKS toward one of
# 2
#           the ISLANDS.
# 3
#           EXT. AHCH-TO ISLAND - DAY
# 2
#           Rey, her staff strapped to her back, begins her hike up the
# 2
#           considerable mountain, glancing back at Chewie and R2-D2,
# 2
#           who watch her from the bottom of the ramp. A deep breath
# 2
#           and Rey continues her journey.
# 3
#           EXT. AHCH-TO ISLAND - STONE STAIRS - DAY
# 2
#           Built within the rock and foliage of this idyllic island are
# 2
#           seemingly endless ANCIENT STONE STEPS. Rey continues to
# 2
#           climb them, determined, despite her fatigue.
# 3
#           EXT. AHCH-TO ISLAND - STONE STRUCTURES - DAY
# 2
#           Rey arrives at a clearing. Small, modest, primitive stone
# 2
#           structures. But no one around. Rey walks past them, sees,
# 2
#           senses no one.
# 2
#           And then she stops. Feels something. She turns.
# 2
#           Standing forty feet away from her, his back to us, is a MAN,
# 2
#           in a CLOAK AND ROBE.
# 2
#           Rey stares, knowing exactly who it is. But she just stares
# 2
#           for what seems like forever. Until he finally TURNS, SLOWLY,
# 2
#           to her. Pulls back his hood.
# 2
#           IT IS LUKE SKYWALKER.
# 2
#           Older now, white hair, bearded. He looks at Rey. A kindness
# 2
#           in his eyes, but there's something tortured, too. He doesn't
# 2
#           need to ask her who she is, or what she is doing here. His
# 2
#           look says it all.
# 2
#           In response, Rey pulls something from the pack.
# 2
#           LUKE'S LIGHTSABER.
# 2
#           And she holds it out to him. An offer. A plea. The galaxy's
# 2
#           only hope.
# 2
#           HOLD ON LUKE SKYWALKER'S INCREDIBLE FACE, amazed and
# 2
#           conflicted at what he sees, as our MUSIC BUILDS, the promise
# 2
#           of an adventure, just beginning...
# 0
#                           THE END
# CPU times: user 132 ms, sys: 0 ns, total: 132 ms
# Wall time: 128 ms

# %%
movie_script
# Out:
# [{'text': u'STAR WARS: THE FORCE AWAKENS\nWritten by\nLawrence Kasdan, J.J. Abrams & Michael Arndt\nBased on characters created by George Lucas',
#   'type': 'unknown'},
#  {'text': u'A long time ago in a galaxy far, far away...',
#   'type': 'stage direction'},
#  {'text': u'STAR WARS\nEPISODE VII\nTHE FORCE AWAKENS', 'type': 'unknown'},
#  {'character': '',
#   'text': u"Luke Skywalker has vanished. In his absence,\nthe sinister FIRST ORDER has risen from the\nashes of the Empire and will not rest until\nSkywalker, the last Jedi, has been destroyed.\nWith the support of the REPUBLIC, General\nLeia Organa leads a brave RESISTANCE. She is\ndesperate to find her brother Luke and gain\nhis help in restoring peace and justice to\nthe galaxy.\nLeia has sent her most daring pilot on a secret\nmission to Jakku, where an old ally has\ndiscovered a clue to Luke's whereabouts....",
#   'type': 'speech'},
#  {'text': u"PAN across the star field to a bright moon. A RUMBLING is\nFELT. A VAST STAR DESTROYER -- unlike any we have seen --\nHURTLES PAST US, of seemingly endless length, eclipsing the\nmoon. After a long beat, FOUR TRANSPORT SHIPS fly from a\nhangar. We HOLD ON THEM NOW, as they fly off toward a distant\nplanet. Jakku. MUSIC BUILDS AND WE...\nCUT TO BLACK.\nA GROWING ROAR of MEAN ENGINES -- gnarled RADIO CALLS, the\nSHUDDERING of a ship's hull. Then FLASHES OF LIGHT: for an\ninstant we see a STORMTROOPER -- then BLACKNESS. Then ANOTHER\nSTORMTROOPER, then it's gone.\nThe FLICKERING CONTINUES until the LIGHTS ARE CONSTANT. We",
#   'type': 'stage direction'},
#  {'text': u'ARE IN:\nINT. TROOP TRANSPORT VEHICLE - NIGHT',
#   'type': 'location'},
#  {'text': u"TWENTY STORMTROOPERS. Holding on at attention, moving to\nthe ship's rhythm, in the tense moments before a raid. A\nFILTERED COMMAND and they LOCK AND LOAD their heavy blaster\nrifles. The BRUTAL NOISE is replaced by SUDDEN, SHOCKING",
#   'type': 'stage direction'},
#  {'text': u'QUIET:\nEXT. JAKKU VILLAGE - NIGHT', 'type': 'location'},
#  {'text': u'WIDE SHOT of a small, peaceful village. Distant sounds of\nnative animals. A single wind chime.\nSuddenly a DROID RISES INTO FRAME, CLOSE: ROUND and SKITTERY,\norange and white, this is BB-8.\nFocuses on something past camera. He BEEPS -- FAST, MORSE\nCODE-LIKE SOUNDS, clearly worried. Moves EVEN CLOSER TO\nCAMERA -- is MORE worried -- BEEPS more -- then TURNS AND\nROLLS OFF FAST --',
#   'type': 'stage direction'},
#  {'text': u'INT. LARGE HUT - NIGHT', 'type': 'location'},
#  {'text': u"CLOSE ON A HAND: a small LEATHER SACK is placed in the palm.\nThe hand closes. Another OLDER HAND covers it.\nIn a primitive HUT, an old explorer, LOR SAN TEKKA, (rugged,\nkind) has handed the mysterious sack to POE DAMERON (32, in\na pilot's jacket). Poe has charisma, a natural spark:",
#   'type': 'stage direction'},
#  {'character': '',
#   'text': u"LOR SAN TEKKA\nThis will begin to make things right.\nI've traveled too far, and seen too\nmuch, to ignore the despair in the\ngalaxy. Without the Jedi, there can\nbe no balance in the Force.",
#   'type': 'speech'},
#  {'character': u'POE',
#   'text': u'Well, because of you now we have a\nchance. The General\'s been after\nthis for a long time.\nLOR SAN TEKKA\n"The General." To me, she\'s royalty.\nWell, she certainly is that.',
#   'type': 'speech'},
#  {'text': u'BB-8 ENTERS FRANTIC, BEEPS. Concerned, Poe turns to Lor San\nTekka.',
#   'type': 'stage direction'},
#  {'character': u"POE (CONT'D)",
#   'text': u"We've got company.",
#   'type': 'speech'},
#  {'text': u'EXT. LARGE HUT - NIGHT', 'type': 'location'},
#  {'text': u"The men exit fast. Poe moves TO CAMERA, raises QUADNOCULARS.\nPOE'S POV: LIGHTS on the horizon -- approaching ENEMY SHIPS.\nPOE lowers the quadnocs -- PUSH IN ON HIS UNNERVED EYES. A\nGROWING, FRIGHTENING THUNDER.",
#   'type': 'stage direction'},
#  {'character': u'POE',
#   'text': u'You have to hide.\nLOR SAN TEKKA\nYou have to leave. Go!',
#   'type': 'speech'},
#  {'text': u'Poe turns to him. Conflicted. Finally nods, hurries off.\nBB-8 follows.',
#   'type': 'stage direction'},
#  {'text': u'EXT. JAKKU VILLAGE - NIGHT', 'type': 'location'},
#  {'text': u'TRACK FAST with Poe as he and BB-8 hurry through the village,\nvarious ARMED VILLAGERS taking position, prepared to defend.',
#   'type': 'stage direction'},
#  {'text': u'EXT. JAKKU VILLAGE - NIGHT', 'type': 'location'},
#  {'text': u'A ROAR of WIND and DUST: the TRANSPORTS LAND. Stormtroopers\ncome out FIRING BLASTERS -- the VILLAGERS FIRE BACK -- many\nare HIT!',
#   'type': 'stage direction'},
#  {'text': u'EXT. RISE ADJACENT TO VILLAGE - NIGHT', 'type': 'location'},
#  {'text': u'Poe runs to an X-WING fighter, parked at a distance from the\nvillage, hidden behind a ROCK OUTCROPPING.',
#   'type': 'stage direction'},
#  {'character': u'POE', 'text': u'Come on, BB-8! Hurry!', 'type': 'speech'},
#  {'text': u"Poe sends BB-8 into the droid socket / co-pilot seat -- he\nmoves to the cockpit -- the CONTROLS COME TO LIFE. As the\nCANOPY CLOSES, Poe shoots a quick look back: the ENEMY ARRIVES\nIN THE DISTANCE.\nPoe urgently works the controls -- BB-8 BEEPS.\nThe X-WING LANDING LIGHTS COME ON, ENGINES WHINE TO LIFE!\nBut just then:\nPoe's ship is suddenly HIT BY BLASTERFIRE! Poe turns to\nlook: two STORMTROOPERS CHARGE HIS WAY, FIRING!",
#   'type': 'stage direction'},
#  {'character': u"POE (CONT'D)", 'text': u"I see 'em!", 'type': 'speech'},
#  {'text': u"BB-8 BEEPS nervously as Poe GRABS HIS CONTROLS and FIRES AT\nTHEM, using the X-wing's drop-down antipersonnel blaster!\nThe two Troopers are BLOWN AWAY in the large BLAST HITS!\nPoe tries to start the ship now, but the ENGINES SPUTTER.\nConcerned, he opens his canopy, jumps down, moves to the\nback of his ship: BAD DAMAGE ON THE REAR ENGINE PANEL.\nThey're in trouble.",
#   'type': 'stage direction'},
#  {'text': u'EXT. JAKKU VILLAGE - NIGHT', 'type': 'location'},
#  {'text': u'Lor San Tekka moves sadly through the village as STORMTROOPERS\nwielding FLAME THROWERS destroy structures. Surrendering\nVillagers are ROUNDED UP. Penned ANIMALS panic.',
#   'type': 'stage direction'},
#  {'text': u'EXT. RISE ADJACENT TO THE VILLAGE - NIGHT', 'type': 'location'},
#  {'text': u"Back at the X-wing, Poe kneels beneath his ship, pulls from\nthe leather sack a SMALL, OLD ARTIFACT which he inserts into\nBB-8 -- the droid's MULTI-READER ENVELOPS it.",
#   'type': 'stage direction'},
#  {'character': u'POE',
#   'text': u"You take this. It's safer with you\nthan it is with me. You get as far\naway from here as you can. Do you\nhear me?\n(BB-8 BEEPS, hesitates)\nI'll come back for you! It will be\nalright.",
#   'type': 'speech'},
#  {'text': u'BB-8 watches Poe run off. BEEP-WHINES nervously, then turns\nand heads off. Turns back once to look at Poe, then ROLLS\nAWAY. Poe uses his blaster rifle to fire at incoming troopers\nfrom cover.',
#   'type': 'stage direction'},
#  {'text': u'EXT. JAKKU VILLAGE - NIGHT', 'type': 'location'},
#  {'text': u"The Troopers and villagers in battle -- as one Trooper is\nHIT and goes down. Another -- OUR TROOPER -- KNEELS to help.\nThe hit trooper raises a torn, bloody glove -- his HUMAN\nHAND visible -- and MARKS OUR STORMTROOPER'S MASK WITH BLOOD\njust before he dies. Our Trooper, stands -- overwhelmed by\nthe battle.\nAN IMPOSING SHUTTLE CRAFT -- VERTICAL WINGSPAN 90 FEET TALL --\nLANDS NEAR THE TRANSPORT VEHICLES.\nThe shuttle craft door OPENS -- through the wind and smoke,\nKYLO REN exits the ship: a TALL, DARK FIGURE, he strides\nthrough the chaos toward San Tekka.\nA senior Trooper moves to our blood-marked Trooper, and orders",
#   'type': 'stage direction'},
#  {'text': u'HIM:', 'type': 'location'},
#  {'character': u'SENIOR TROOPER', 'text': u'Stay here.', 'type': 'speech'},
#  {'text': u'Our Trooper nods.\nKylo Ren stops before the outraged Lor San Tekka, dwarfing\nhim. Only now does it become apparent that Kylo Ren wears a\nDARK MASK, marked by battle. Inset metal lines reflect FIRE.',
#   'type': 'stage direction'},
#  {'character': u'KYLO REN',
#   'text': u"Look how old you've become.\nLOR SAN TEKKA\nSomething far worse has happened to\nyou.",
#   'type': 'speech'},
#  {'text': u'Our blood-marked TROOPER is placed in line with other\nstormtroopers.',
#   'type': 'stage direction'},
#  {'character': u'KYLO REN',
#   'text': u"You know what I've come for.",
#   'type': 'speech'},
#  {'text': u'CONTINUED: LOR SAN TEKKA', 'type': 'stage direction'},
#  {'character': u'(CONTINUED)',
#   'text': u'I know where you come from. Before\nyou called yourself Kylo Ren.',
#   'type': 'speech'},
#  {'character': u'KYLO REN',
#   'text': u"The map to Skywalker. We know you've\nfound it, and now you're going to\ngive it to the First Order.",
#   'type': 'speech'},
#  {'text': u'Adjacent to the village, Poe enters frame -- sees the Ren/San\nTekka exchange continue.',
#   'type': 'stage direction'},
#  {'character': u'KYLO REN',
#   'text': u'LOR SAN TEKKA\nThe First Order rose from the dark\nside... you did not.',
#   'type': 'speech'},
#  {'character': u'KYLO REN',
#   'text': u"I'll show you the dark side.\nLOR SAN TEKKA\nYou may try, but you cannot deny the\ntruth that is your family.",
#   'type': 'speech'},
#  {'text': u'Suddenly Kylo Ren raises his LIGHTSABER -- IGNITES IT --\nPERPENDICULAR SMALLER BLADES AT THE HILT, A UNIQUE BUZZ --\nYELLOW/RED ENERGY, SPITTING SPARKS AND SMOKE --',
#   'type': 'stage direction'},
#  {'character': u'KYLO REN', 'text': u"You're so right.", 'type': 'speech'},
#  {'text': u"And as he RIPS IT DOWN ACROSS SAN TEKKA!\nPoe, RUNNING, SEES THIS AND YELLS, AIMS HIS BLASTER AND FIRES\nAT KYLO REN! Instantly:\nKylo Ren RAISES HIS HAND -- POE'S BLAST FREEZES -- THE BOLT\nOF ENERGY STRAINING AND VIBRATING IN MID AIR!\nKylo Ren sees Poe, who suddenly CANNOT MOVE, but strains to.\nHe is grabbed by Stormtroopers who drag him past the\nVIBRATING, FROZEN BLAST, to Kylo Ren.\nA Stormtrooper begins a brutal PAT DOWN. Kylo Ren moves\ncloser. Poe just glares. The Stormtrooper KICKS OUT Poe's\nlegs -- he lands hard on his knees.\nKylo Ren kneels to look at Poe.",
#   'type': 'stage direction'},
#  {'character': u'POE',
#   'text': u'So who talks first? You talk first?',
#   'type': 'speech'},
#  {'character': u'KYLO REN',
#   'text': u'The old man gave it to you.',
#   'type': 'speech'},
#  {'character': u"POE\n(INDICATES KYLO'S\nMASK)",
#   'text': u"It's just very hard to understand\nyou with all the...",
#   'type': 'speech'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'character': u'KYLO REN\n(TO TROOPERS)',
#   'text': u'Search him.',
#   'type': 'speech'},
#  {'character': u'POE', 'text': u'... Apparatus.', 'type': 'speech'},
#  {'text': u'The Troopers roughly pull Poe away. A Stormtrooper begins a\nbrutal PAT DOWN. Kylo Ren moves closer.\nPoe just glares as the pat down ends.',
#   'type': 'stage direction'},
#  {'character': u'STORMTROOPER #1', 'text': u'Nothing, sir.', 'type': 'speech'},
#  {'character': u'KYLO REN', 'text': u'Put him on board.', 'type': 'speech'},
#  {'text': u'Kylo Ren regards the Stormtroopers with the rounded up\nVillagers, then turns to the CHROME-SKINNED, FEMALE BLACK-\nCAPED HEAD STORMTROOPER, CAPTAIN PHASMA.',
#   'type': 'stage direction'},
#  {'character': u'CAPTAIN PHASMA',
#   'text': u'Sir, the villagers.',
#   'type': 'speech'},
#  {'character': u'KYLO REN', 'text': u'Kill them all.', 'type': 'speech'},
#  {'text': u'Phasma nods, steps forward:', 'type': 'stage direction'},
#  {'character': u'CAPTAIN PHASMA', 'text': u'On my command!', 'type': 'speech'},
#  {'text': u'The Troopers, including OURS, aim at the Villagers.',
#   'type': 'stage direction'},
#  {'character': u'CAPTAIN PHASMA',
#   'text': u"CAPTAIN PHASMA (CONT'D)\nFire!",
#   'type': 'speech'},
#  {'text': u"Poe is roughly PULLED into a transport ship, the ramp LIFTS.\nAll around our Trooper BLASTERFIRE ERUPTS -- but we're WIDE\nENOUGH to see he ISN'T FIRING. PUSH IN until the FIRING\nSTOPS. All the Stormtroopers SPREAD OUT TO SEARCH -- except\nours.\nKylo Ren heads back toward his ship. But then he STOPS.\nFeels something. TURNS AND LOOKS AT OUR STORMTROOPER for a\nLONG MOMENT. Our Trooper can barely meet his gaze; knows\nhe's doomed.\nKylo Ren then heads off -- passes the FROZEN BLAST, which,\nafter a beat, GOES FREE AND SLAMS INTO A NEARBY STRUCTURE,\nscaring the hell out of our Stormtrooper.",
#   'type': 'stage direction'},
#  {'text': u'EXT. EDGE OF JAKKU VILLAGE - NIGHT', 'type': 'location'},
#  {'text': u"A Stormtrooper climbs down from the cockpit of Poe's X-wing,",
#   'type': 'stage direction'},
#  {'text': u'BACKS AWAY:', 'type': 'location'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'character': u'STORMTROOPER #2',
#   'text': u'Nothing here. Go ahead!',
#   'type': 'speech'},
#  {'text': u'Three other Stormtroopers FIRE LASER CANNONS at the X-wing --\ndestroying the ship in a LARGE EXPLOSION.',
#   'type': 'stage direction'},
#  {'text': u'EXT. OUTSKIRTS OF JAKKU VILLAGE - NIGHT', 'type': 'location'},
#  {'text': u'BB-8 rolls across the sand, looks back: the X-wing FIREBALL.\nBB-8, afraid, continues on his own in a mysterious, dark\ndesert. We see a FORM -- an animal, its RED EYES LIFTING\nfrom the sand, watching the rolling droid, who just keeps\ngoing.\nIn a WIDE SHOT, we HEAR HIM BEEPING to himself, lonely and\nfrightened.',
#   'type': 'stage direction'},
#  {'text': u'EXT. SPACE - NIGHT', 'type': 'location'},
#  {'text': u"With the SANDY PLANET OF JAKKU as backdrop, Troop Transports\nand Kylo Ren's Shuttle approach a massive STAR DESTROYER.",
#   'type': 'stage direction'},
#  {'text': u'INT. STAR DESTROYER HANGAR - NIGHT', 'type': 'location'},
#  {'text': u'Poe, shackled, is ushered from the transport through the\nhangar. He is awed by the imposing space.',
#   'type': 'stage direction'},
#  {'character': u'POE', 'text': u'All right. All right!', 'type': 'speech'},
#  {'text': u'Our Stormtrooper passes, moves fast:', 'type': 'stage direction'},
#  {'text': u'INT. TROOP TRANSPORT VEHICLE - NIGHT', 'type': 'location'},
#  {'text': u"Our Stormtrooper enters the dark, vehicle. He removes his\nhelmet. His head comes up and we PUSH IN ON HIS FACE FOR\nTHE FIRST TIME. This is FN-2187. He is 23, likable. But\nin this moment, terrified, desperate.\nAfter a beat, behind him, CAPTAIN PHASMA enters. FN-2187\nknows he's in trouble.",
#   'type': 'stage direction'},
#  {'character': u'CAPTAIN PHASMA',
#   'text': u'FN-2187. Submit your blaster for\ninspection.',
#   'type': 'speech'},
#  {'character': u'FN-2187', 'text': u'Yes, Captain.', 'type': 'speech'},
#  {'character': u'CAPTAIN PHASMA',
#   'text': u'And who gave you permission to remove\nthat helmet?',
#   'type': 'speech'},
#  {'character': u'FN-2187', 'text': u"I'm sorry, Captain.", 'type': 'speech'},
#  {'character': u'CAPTAIN PHASMA',
#   'text': u'Report to my division at once.',
#   'type': 'speech'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'text': u'Phasma heads off. Shattered, FN-2187 replaces his helmet.',
#   'type': 'stage direction'},
#  {'text': u'INT. JUNKED VESSEL CORRIDOR - DAY', 'type': 'location'},
#  {'text': u'A metal sheet is pulled open to reveal the wrapped up face\nof A SCAVENGER, perhaps alien, in GOGGLES, FACE MASK and\nGLOVES. Backpack with a STAFF strapped to it. Uses TOOLS\nto remove various MECHANISMS from inside the wall. We are\nin an upside-down, canted CORRIDOR. The Scavenger finds a\nvaluable piece, drops it in a SATCHEL.\nSwings the bag back and begins CLIMBING DOWN on a cable,\nbetween treacherous WALLS OF MACHINERY, headed to:',
#   'type': 'stage direction'},
#  {'text': u'INT. JUNKED VESSEL - LARGER SPACE - LATER', 'type': 'location'},
#  {'text': u'Alone and tiny in this massive, sideways wreck, the Scavenger\ndescends, climbing down a two-hundred foot-long cable. LANDS\nHARD onto rusty metal.',
#   'type': 'stage direction'},
#  {'text': u'INT. JUNKED VESSEL - ENGINES - DAY', 'type': 'location'},
#  {'text': u'The Scavenger carries the satchel and another large, found\npiece, over enormous pipes in the vast space, heads through\nthe dust toward a distant SLIT OF SUNLIGHT.',
#   'type': 'stage direction'},
#  {'text': u'EXT. JUNKED VESSEL ENGINE - DAY', 'type': 'location'},
#  {'text': u'The Scavenger arrives from the darkness and pulls off goggles\nand gear, revealing the grimy face of a beautiful, young\nWOMAN. This is REY, 19.\nShe opens her canteen, shakes out the two final drops into\nher mouth. HITS THE SIDE of the canteen again and again for\nwhatever she can get. CUT WIDE:\nRey is rendered minuscule, standing at the bottom of an EPIC\nENGINE OF A DECAYING, CRASHED STAR DESTROYER -- DISTANT SOUND\nof her canteen-hitting. She sets her things on a piece of\nsheet metal and sits next to it, sliding down the sand dune.\nShe RIDES DOWN THE MOUNTAIN OF SAND. WE HOLD FOR A LONG\nTIME, looking down, as she recedes from us, toward the distant\nSALT FLATS below. Random SCATTERED DEBRIS. Her SPEEDER,\ntiny from here.\nRey moves to her junker SPEEDER, jumps on, fires the sputtery\nengine and DRIVES OFF.',
#   'type': 'stage direction'},
#  {'text': u'EXT. DESERT - SPACESHIP GRAVEYARD - DAY', 'type': 'location'},
#  {'text': u'Rey races along the desert floor: a GRAVEYARD OF CRASHED\nSPACESHIPS.',
#   'type': 'stage direction'},
#  {'text': u'EXT. NIIMA OUTPOST - DAY', 'type': 'location'},
#  {'text': u"Rey's speeder PASSES us, heading for a dusty, desert town.\nRefueling, small trade, scavengers.",
#   'type': 'stage direction'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'text': u"CRASH! Rey's sack carrying her heavy FOUND OBJECTS hits the\nsand. Working like a tough seaman, Rey hauls the sack from\nher speeder toward the town.",
#   'type': 'stage direction'},
#  {'text': u'EXT. NIIMA OUTPOST - CLEANING TABLE - DAY', 'type': 'location'},
#  {'text': u"TIGHT ON REY'S HANDS as she SCRUBS CLEAN her day's salvage.\nRey glances up: she looks at an old woman, also cleaning\nsome salvage.\nRey watches her, gets lost in the simple moment. A small,\npassing alien UNDERLING barks something to her in another\nlanguage. She returns to work.",
#   'type': 'stage direction'},
#  {'text': u'INT. NIIMA TRADING STRUCTURE - DAY', 'type': 'location'},
#  {'text': u'Rey looks up to a SERVICE WINDOW: two feet above her, behind\na protective screen, is her boss, UNKAR PLUTT (50, blobfish,\nunclean). He examines her pieces. Then he offers:',
#   'type': 'stage direction'},
#  {'character': u'UNKAR',
#   'text': u"What you've brought me today is\nworth... Hmmm... One quarter\nportion.",
#   'type': 'speech'},
#  {'text': u'Though disappointed, Rey barely shows it. She nods thanks.\nUnkar pushes through his transfer drawer a SEALED PACKET:\nDRIED GREEN MEAT in one section, BEIGE POWDER in another.\nShe takes it.\nShe swallows her resentment and heads off.',
#   'type': 'stage direction'},
#  {'text': u'EXT. NIIMA OUTPOST - DAY', 'type': 'location'},
#  {'text': u"The IMMENSE SETTING SUN against the FLAT TERRAIN. Rey's\nSPEEDER races, almost insignificant, across frame.",
#   'type': 'stage direction'},
#  {'text': u"INT. REY'S DWELLING - DAY", 'type': 'location'},
#  {'text': u"She SCRATCHES MARKS into the rusty wall. Another MARK;\nanother DAY. And there are THOUSANDS of marks.\nA SIZZLING SOUND over: A DRIED DESERT FLOWER in a rusty ENGINE\nPIECE. A rough, stuffed HANDMADE DOLL, made from what looks\nlike orange Rebellion flight suit material and twine.\nRey's lonely, ramshackle dwelling. Everything reclaimed.\nShe cooks for one. Does everything for one. She opens the\nPOWDER, moves to the makeshift WOK, where the GREEN MEAT\nSIZZLES. Pours the powder into milky WATER in a tin. Stirs\nit. It GROWS INTO A LOAF as she puts the meat on an old\nplate. Grabs the loaf.",
#   'type': 'stage direction'},
#  {'text': u"EXT. REY'S DWELLING - DUSK", 'type': 'location'},
#  {'text': u'Rey sits, eats like a starving child. Every last drop.\nLicks the metal plate. Looks out at the horizon. A single\nsilent ship heads off, a shimmering, thin contrail. She\nwipes her mouth. Picks up an old, broken REBELLION HELMET.',
#   'type': 'stage direction'},
#  {'text': u"CONTINUED: just 'cause.\nPuts it on,\nWIDE SHOT of Rey sitting, alone and isolated, on the leg of\nan ANCIENT, FALLEN AT-AT in which she lives.\nThen, a distant ELECTRONIC SQUEAL -- instantly she's up,\nhelmet too big, she rips it off. Hears ANOTHER BEEPING\nSQUEAL. She hurries to her QUARTERSTAFF and runs off.\nRey climbs a dune. RISE WITH HER, revealing BB-8, caught in\na NET but fighting back, being held by a TEEDO (a small,\nbrutish desert tyrant), who rides a LUGGABEAST. The teedo\nYELLS at BB-8, who BEEPS madly, struggling to free himself.\nRey watches this injustice for a beat, finally YELLING OUT:",
#   'type': 'stage direction'},
#  {'character': u'REY', 'text': u"Tal'ama parqual!", 'type': 'speech'},
#  {'text': u'The Teedo and BB-8 STOP, GO SILENT, turn to her.',
#   'type': 'stage direction'},
#  {'character': u"REY (CONT'D)", 'text': u'Parqual zatana!', 'type': 'speech'},
#  {'text': u"A half beat and the Teedo YELLS SOMETHING BACK, threatening.\nBB-8's head swivels to him, then back to Rey, like watching\na tennis match.\nRey angrily moves to them, pulling a knife from her pouch.\nRey starts CUTTING BB-8 out of the netting. The Teedo freaks\nout, YELLING. Rey suddenly stands, turns to the Teedo and\nsays, fiercely:",
#   'type': 'stage direction'},
#  {'character': u"REY (CONT'D)", 'text': u'NOMA.', 'type': 'speech'},
#  {'text': u'The Teedo barks a sort of "AHHHHH!" (As if to say, "GO TO\nHELL!"), Then heads off on his beast. This prompts BB-8 to\nstart BEEP-YELLING at the departing bully, provocatively.',
#   'type': 'stage direction'},
#  {'character': u"REY (CONT'D)", 'text': u'Shhhh.', 'type': 'speech'},
#  {'text': u'BB-8 quiets instantly. The two watch the Teedo head off.\nFinally, BB-8 BEEPS a question. She KNEELS to him.',
#   'type': 'stage direction'},
#  {'character': u"REY (CONT'D)",
#   'text': u"That's just Teedo. Wants you for\nparts. He has no respect for anyone.\nYour antenna's bent.\n(considers BB-8 for\nthe first time,",
#   'type': 'speech'},
#  {'character': u'STRAIGHTENS THE\nANTENNA)',
#   'text': u'Where do you come from?',
#   'type': 'speech'},
#  {'character': u'(BB-8 BEEPS)',
#   'text': u'Classified. Really? Me too. Big\nsecret.\n(points to horizon)\nNiima Outpost is that way, stay off\nKelvin Ridge.',
#   'type': 'speech'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'character': u"REY (CONT'D)",
#   'text': u"Keep away from the Sinking Fields in\nthe north, you'll drown in the sand.\n(stands, heads off)",
#   'type': 'speech'},
#  {'text': u'BB-8 starts after her, BEEPS. She turns sharply, he stops.',
#   'type': 'stage direction'},
#  {'character': u"REY (CONT'D)",
#   'text': u"Don't follow me. Town is that way.\n(he BEEPS again)\nNo!",
#   'type': 'speech'},
#  {'text': u'She heads off again. Finally he BEEPS to her -- something\nSWEET this time. That he is alone, scared, has no one else.\nThis makes her stop. She turns and looks at him. Not liking\nhim. But a gesture of her head says, reluctantly, "Come\non." BB-8 quickly moves to her. They head off together.',
#   'type': 'stage direction'},
#  {'character': u"REY (CONT'D)",
#   'text': u'In the morning, you go.',
#   'type': 'speech'},
#  {'character': u'(HE BEEPS)', 'text': u"You're welcome.", 'type': 'speech'},
#  {'text': u'The two disappear behind a dune.', 'type': 'stage direction'},
#  {'text': u'EXT. STAR DESTROYER - DAY', 'type': 'location'},
#  {'text': u'Three TIE fighters head to the massive ship high above Jakku.',
#   'type': 'stage direction'},
#  {'text': u'INT. STAR DESTROYER HOLDING CELL - DAY', 'type': 'location'},
#  {'text': u'POE, shackled to a chair, BEATEN, wakes up.',
#   'type': 'stage direction'},
#  {'character': u'KYLO REN',
#   'text': u'I had no idea we had the best pilot\nin the Resistance on board.\nComfortable?',
#   'type': 'speech'},
#  {'text': u'Through battered lips:', 'type': 'stage direction'},
#  {'character': u'POE', 'text': u'Not really.', 'type': 'speech'},
#  {'character': u'KYLO REN',
#   'text': u"I'm impressed. No one has been able\nto get out of you what you did with\nthe map.",
#   'type': 'speech'},
#  {'character': u'POE',
#   'text': u'Might wanna rethink your technique.',
#   'type': 'speech'},
#  {'text': u'Kylo Ren says nothing, reaches out to him. Poe flinches in\nthe chair as Kylo Ren reaches for his face, not touching\nhim. Poe is soon in agony, remains in horrible silence --',
#   'type': 'stage direction'},
#  {'character': u'KYLO REN', 'text': u'Where is it?', 'type': 'speech'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'character': u'POE',
#   'text': u'The Resistance will not be intimidated\nby you.',
#   'type': 'speech'},
#  {'character': u'KYLO REN', 'text': u'Where... is it?', 'type': 'speech'},
#  {'text': u"Poe can't take it -- he BEGINS TO SCREAM and we CUT TO:",
#   'type': 'stage direction'},
#  {'text': u'INT. STAR DESTROYER CORRIDOR - DAY', 'type': 'location'},
#  {'text': u'WHOOOSH! The cell door SLIDES UP. Kylo Ren exits, fierce,\nconfronts GENERAL HUX (34, scary) who awaits him:',
#   'type': 'stage direction'},
#  {'character': u'KYLO REN',
#   'text': u"It's in a droid. A BB unit.",
#   'type': 'speech'},
#  {'character': u'GENERAL HUX',
#   'text': u"Well then. If it's on Jakku, we'll\nsoon have it.",
#   'type': 'speech'},
#  {'character': u'KYLO REN', 'text': u'I leave that to you.', 'type': 'speech'},
#  {'text': u'EXT. NIIMA OUTPOST - DAY', 'type': 'location'},
#  {'text': u'BB-8 is dropped to the sand.', 'type': 'stage direction'},
#  {'character': u'REY',
#   'text': u"Don't give up. He still might show\nup. Whoever it is you're waiting\nfor. Classified. I know all about\nwaiting.",
#   'type': 'speech'},
#  {'text': u'BB-8 BEEPTALKS a question.', 'type': 'stage direction'},
#  {'character': u"REY (CONT'D)",
#   'text': u"For my family. They'll be back.\nOne day. Come on.",
#   'type': 'speech'},
#  {'text': u"She tries to force a smile, but can't, really. She heads\noff. BB-8 BEEPS... then heads after her.",
#   'type': 'stage direction'},
#  {'text': u'INT. NIIMA TRADING STRUCTURE - DAY', 'type': 'location'},
#  {'text': u'Rey stands with BB-8 in front of Unkar Plutt, at his window.\nHe reviews her goods. He glances quickly at BB-8.',
#   'type': 'stage direction'},
#  {'character': u'UNKAR',
#   'text': u'These five pieces are worth... Let\nme see here... One half portion.',
#   'type': 'speech'},
#  {'character': u'REY\n(OBJECTS)',
#   'text': u'Last week they were a half portion\neach.',
#   'type': 'speech'},
#  {'text': u'She hates him. He leans forward.', 'type': 'stage direction'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'character': u'UNKAR', 'text': u'What about the droid?', 'type': 'speech'},
#  {'character': u'REY', 'text': u'What about him?', 'type': 'speech'},
#  {'character': u'UNKAR', 'text': u"I'll pay for him.", 'type': 'speech'},
#  {'text': u"BB-8 doesn't like this at all. Rey is awkward, but curious.",
#   'type': 'stage direction'},
#  {'character': u"UNKAR (CONT'D)",
#   'text': u'Sixty portions.',
#   'type': 'speech'},
#  {'text': u'CLOSE ON HER. Stunned. Literally hungry for this amount of\nfood, her stomach practically rumbles.\nBB-8 sees her interest and BEEPS furiously, not liking this\nconversation at all.\nShe looks at Unkar. Looks down at BB-8. Considers it all.\nFinally, she hears herself say:',
#   'type': 'stage direction'},
#  {'character': u'REY',
#   'text': u"Actually... the droid's not for sale.",
#   'type': 'speech'},
#  {'character': u'(TO BB-8)', 'text': u'Come on.', 'type': 'speech'},
#  {'text': u'Unkar furious. Rey, then BB-8, head out. Recovering, Unkar\nwatches her go with dark eyes. He picks up a communicator:',
#   'type': 'stage direction'},
#  {'character': u'UNKAR',
#   'text': u'Follow the girl and get that droid.',
#   'type': 'speech'},
#  {'text': u'He SLAMS the service window door SHUT.',
#   'type': 'stage direction'},
#  {'text': u'INT. STAR DESTROYER HOLDING CELL - DAY', 'type': 'location'},
#  {'text': u'The cell door WHOOSHES OPEN -- a STORMTROOPER enters. Poe\nremains shackled, worse for wear. A TROOPER GUARD here.',
#   'type': 'stage direction'},
#  {'character': u'STORMTROOPER',
#   'text': u'Ren wants the prisoner.',
#   'type': 'speech'},
#  {'text': u'TIGHT ON POE, in pain, drained, as the Guard unshackles him.',
#   'type': 'stage direction'},
#  {'text': u'INT. STAR DESTROYER CORRIDOR - DAY', 'type': 'location'},
#  {'text': u"An exhausted, handcuffed Poe is walked down the corridor by\nthe Stormtrooper, who holds a blaster at Poe's body.",
#   'type': 'stage direction'},
#  {'character': u'STORMTROOPER', 'text': u'Turn here.', 'type': 'speech'},
#  {'text': u'Poe turns into a narrow passageway --', 'type': 'stage direction'},
#  {'text': u'INT. STAR DESTROYER NARROW PASSAGEWAY - DAY', 'type': 'location'},
#  {'text': u'Heading down the narrow hall the Stormtrooper stops Poe.',
#   'type': 'stage direction'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'character': u'STORMTROOPER',
#   'text': u'Listen carefully: you do exactly as\nI say, I can get you out of here.',
#   'type': 'speech'},
#  {'character': u'POE\n(COMING TO)',
#   'text': u'If -- what--?',
#   'type': 'speech'},
#  {'text': u'The Stormtrooper pulls off his helmet: IT IS FN-2187.',
#   'type': 'stage direction'},
#  {'character': u'FN-2187',
#   'text': u"This is a rescue, I'm helping you\nescape. Can you fly a TIE fighter?",
#   'type': 'speech'},
#  {'character': u'POE',
#   'text': u'You with the Resistance--?!',
#   'type': 'speech'},
#  {'character': u'FN-2187', 'text': u'What?', 'type': 'speech'},
#  {'character': u"(THAT'S CRAZY)",
#   'text': u"No no no! I'm breaking you out.\nCan you fly a TIE fighter?",
#   'type': 'speech'},
#  {'character': u'POE',
#   'text': u'I can fly anything. Why, why are\nyou helping me?',
#   'type': 'speech'},
#  {'character': u'FN-2187',
#   'text': u"Because it's the right thing to do.",
#   'type': 'speech'},
#  {'character': u'POE',
#   'text': u'(it hits him)\nYou need a pilot.',
#   'type': 'speech'},
#  {'character': u'FN-2187', 'text': u'I need a pilot.', 'type': 'speech'},
#  {'text': u"And Poe, seeing this is for real, smiles a hero's smile.",
#   'type': 'stage direction'},
#  {'character': u'POE', 'text': u"We're gonna do this.", 'type': 'speech'},
#  {'character': u'FN-2187',
#   'text': u'(unsure but hopeful)\n... Yeah?',
#   'type': 'speech'},
#  {'text': u'INT. STAR DESTROYER HANGAR - DAY', 'type': 'location'},
#  {'text': u"WIDE SHOT ESTABLISHING the hangar. Find FN-2187, again\nmasked, walking with Poe. By all appearances he's escorting\na prisoner. A group of OFFICERS passes in the opposite\ndirection.",
#   'type': 'stage direction'},
#  {'character': u'FN-2187',
#   'text': u'Okay, stay calm, stay calm.',
#   'type': 'speech'},
#  {'character': u'POE', 'text': u'I am calm.', 'type': 'speech'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'character': u'FN-2187',
#   'text': u"I'm talking to myself.",
#   'type': 'speech'},
#  {'character': u'(BEAT)',
#   'text': u'Not yet. Okay, go. This way.',
#   'type': 'speech'},
#  {'text': u'FN-2187 walks quickly toward the far wall -- Poe follows --\nup the stairs to a two-man SPECIAL FORCES TIE FIGHTER --',
#   'type': 'stage direction'},
#  {'text': u'INT. TIE FIGHTER - DAY', 'type': 'location'},
#  {'text': u'FN-2187 and Poe (wincing, sore) drop into the back-to-back\ncockpit. FN-2187 pulls off his helmet as Poe removes his\ncuffs and jacket, fires up the ship with excitement.',
#   'type': 'stage direction'},
#  {'character': u'POE',
#   'text': u'I always wanted to fly one of these\nthings. Can ya shoot?',
#   'type': 'speech'},
#  {'character': u'FN-2187', 'text': u'Blasters, I can!', 'type': 'speech'},
#  {'character': u'POE',
#   'text': u'Okay, same principal! Use the toggle\non the left to switch between\nmissiles, cannons, and mag pulse --\nuse the site on the right to aim,\ntriggers to fire!',
#   'type': 'speech'},
#  {'character': u'FN-2187',
#   'text': u'This is very complicated',
#   'type': 'speech'},
#  {'text': u'FWOOOOOOM! The TIE FIGHTER LURCHES FORWARD --',
#   'type': 'stage direction'},
#  {'character': u'POE', 'text': u'I can fix this.', 'type': 'speech'},
#  {'text': u'INT. HANGAR SIX CONTROL ROOM - DAY', 'type': 'location'},
#  {'text': u"WIDE: see the ship STRUGGLE TO RISE, CABLES connected to it --\nPULL BACK FAST to REVEAL we're inside the main control room.",
#   'type': 'stage direction'},
#  {'character': u'POE',
#   'text': u'STAR DESTROYER TECHNICIAN\nWe have an unsanctioned departure\nfrom bay two.',
#   'type': 'speech'},
#  {'text': u'WHIP TO a FIRST ORDER COLONEL, who responds:',
#   'type': 'stage direction'},
#  {'character': u'POE',
#   'text': u'FIRST ORDER COLONEL\nAlert General Hux and stop that\nfighter.',
#   'type': 'speech'},
#  {'text': u'INT. STAR DESTROYER HANGAR - DAY', 'type': 'location'},
#  {'text': u'The TIE Fighter LIFTS OFF from the bay, rips CHARGING cables!\nStormtroopers UNPACK and aim MEGABLASTERS.',
#   'type': 'stage direction'},
#  {'text': u'INT. TIE FIGHTER - DAY', 'type': 'location'},
#  {'text': u'FN-2187 opens fire.', 'type': 'stage direction'},
#  {'text': u'INT. STAR DESTROYER HANGAR - DAY', 'type': 'location'},
#  {'text': u'FN-2187 TEARS UP PARKED TIE FIGHTERS and GUN EMPLACEMENTS\nWITH WELL-AIMED, STRATEGIC LASER BLASTS! Hits the CONTROL\nROOM!',
#   'type': 'stage direction'},
#  {'text': u'INT. HANGAR SIX CONTROL ROOM - DAY', 'type': 'location'},
#  {'text': u'THE WINDOWS ARE BLOWN IN BY LASER BLASTS!',
#   'type': 'stage direction'},
#  {'text': u'INT. TIE FIGHTER COCKPIT - DAY', 'type': 'location'},
#  {'character': u'POE', 'text': u'I got it!', 'type': 'speech'},
#  {'text': u'EXT. STAR DESTROYER - DAY', 'type': 'location'},
#  {'text': u'The TIE Fighter blasts from the ship --',
#   'type': 'stage direction'},
#  {'text': u'INT. TIE FIGHTER - DAY', 'type': 'location'},
#  {'text': u'Poe pilots -- amazed, almost enjoying it.',
#   'type': 'stage direction'},
#  {'character': u'POE',
#   'text': u"Woooahhh! This thing really moves.\nAll right, we gotta take out as many\ncannons as we can or we're not gonna\nget very far!",
#   'type': 'speech'},
#  {'character': u'FN-2187', 'text': u'All right!', 'type': 'speech'},
#  {'character': u'POE',
#   'text': u"I'm gonna get us in position, just\nstay sharp!",
#   'type': 'speech'},
#  {'text': u'EXT. STAR DESTROYER - DAY', 'type': 'location'},
#  {'text': u"The TIE Fighter ARCS BACK, DIVES THROUGH THE OPENING BETWEEN\nTHE LEVELS OF THE MASSIVE SHIP, then FLIES DOWN AND BACK,\nalong the ship's belly --",
#   'type': 'stage direction'},
#  {'text': u'INT. TIE FIGHTER - DAY', 'type': 'location'},
#  {'text': u'Poe flies toward the CANONS --', 'type': 'stage direction'},
#  {'character': u'POE',
#   'text': u"Up ahead! Up ahead! You see it?\nI've got us dead centered. It's a\nclean shot.",
#   'type': 'speech'},
#  {'character': u'FN-2187', 'text': u'Okay, got it.', 'type': 'speech'},
#  {'text': u'FN-2187 gets a target, FIRES!', 'type': 'stage direction'},
#  {'text': u'EXT. STAR DESTROYER - DAY', 'type': 'location'},
#  {'text': u'LASERS BLAST from the TIE Fighter -- A SERIES OF CANNONS\nEXPLODE! Our TIE Fighter SLICES THROUGH the debris!',
#   'type': 'stage direction'},
#  {'text': u'INT. TIE FIGHTER - DAY', 'type': 'location'},
#  {'text': u'FN-2187 YELLS in celebration:', 'type': 'stage direction'},
#  {'character': u'FN-2187',
#   'text': u'YES! You see that?! DID YOU SEE\nTHAT?',
#   'type': 'speech'},
#  {'character': u'POE',
#   'text': u"I saw it! Hey, what's your name?",
#   'type': 'speech'},
#  {'character': u'FN-2187', 'text': u'FN-2187!', 'type': 'speech'},
#  {'text': u"Poe reacts, this tells him volumes about FN-2187's history.",
#   'type': 'stage direction'},
#  {'character': u'POE', 'text': u'FN-whaa?', 'type': 'speech'},
#  {'character': u'FN-2187',
#   'text': u"That's the only name they ever gave\nme!",
#   'type': 'speech'},
#  {'character': u'POE',
#   'text': u"Well I ain't using it! FN, huh?\nFinn. I'm gonna call you Finn!\nThat all right?",
#   'type': 'speech'},
#  {'text': u"Even in the madness, Finn can't suppress his smile.",
#   'type': 'stage direction'},
#  {'character': u'FINN',
#   'text': u'"Finn." Yeah, "Finn", I like that!\nI like that!',
#   'type': 'speech'},
#  {'character': u'POE', 'text': u"I'm Poe. Poe Dameron.", 'type': 'speech'},
#  {'character': u'FINN', 'text': u'Good to meet you, Poe!', 'type': 'speech'},
#  {'character': u'POE',
#   'text': u'Good to meet you too, Finn!',
#   'type': 'speech'},
#  {'text': u'INT. STAR DESTROYER MAIN BRIDGE - DAY', 'type': 'location'},
#  {'text': u'General Hux looks over the shoulder of LIEUTENANT MITAKA, at\na console.',
#   'type': 'stage direction'},
#  {'character': u'LIEUTENANT MITAKA',
#   'text': u"Sir, they've taken out our turbolasers--",
#   'type': 'speech'},
#  {'character': u'GENERAL HUX',
#   'text': u'Use the ventral cannons.',
#   'type': 'speech'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'character': u'LIEUTENANT MITAKA',
#   'text': u'Yes, sir. Bringing them online --\nKYLO REN (O.S.)\nGeneral Hux. Is it the Resistance\npilot?',
#   'type': 'speech'},
#  {'text': u'Hux turns: Kylo Ren enters fast, looms large, angry.',
#   'type': 'stage direction'},
#  {'character': u'GENERAL HUX',
#   'text': u'Yes, and he had help.',
#   'type': 'speech'},
#  {'character': u'(VEXED)', 'text': u'From one of our own.', 'type': 'speech'},
#  {'text': u'PUSH IN ON REN as Hux says:', 'type': 'stage direction'},
#  {'character': u'(VEXED)',
#   'text': u"GENERAL HUX (CONT'D)\nWe're checking the registers now to\nidentify which Stormtrooper it was.",
#   'type': 'speech'},
#  {'character': u'KYLO REN',
#   'text': u'... The one from the village. FN-\n2187.',
#   'type': 'speech'},
#  {'text': u"Hux is unnerved that Ren knows -- he chalks it up to Ren's\nForce ability. Kylo Ren heads off.",
#   'type': 'stage direction'},
#  {'character': u'LIEUTENANT MITAKA',
#   'text': u'Sir. Ventral cannons hot.',
#   'type': 'speech'},
#  {'character': u'GENERAL HUX', 'text': u'Fire.', 'type': 'speech'},
#  {'text': u'EXT. STAR DESTROYER - DAY', 'type': 'location'},
#  {'text': u'Massive WARHEAD LAUNCHERS SPIN and FIRE BLASTS toward the\nTIE fighter, which flies EVASIVE MANEUVERS -- most blasts\nhit the DEBRIS from the TURBOLASER DESTRUCTION.\nThe TIE fighter then PULLS A BIG TURN, BACK TOWARD JAKKU,\nTHE SANDY PLANET WHERE POE LEFT BB-8.',
#   'type': 'stage direction'},
#  {'text': u'INT. TIE FIGHTER - DAY', 'type': 'location'},
#  {'character': u'POE',
#   'text': u"One's coming towards you. My right,\nyour left. Do you see it?",
#   'type': 'speech'},
#  {'character': u'FINN', 'text': u'Hold on! I see it!', 'type': 'speech'},
#  {'character': u'POE', 'text': u'Nice shot.', 'type': 'speech'},
#  {'text': u'Finn looks up suddenly in alarm --', 'type': 'stage direction'},
#  {'character': u'FINN', 'text': u'Where are you going?', 'type': 'speech'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'character': u'POE',
#   'text': u"We're going back to Jakku. That's\nwhere.",
#   'type': 'speech'},
#  {'character': u'FINN',
#   'text': u"No no no! We can't go back to Jakku!\nWe need to get outta this system!",
#   'type': 'speech'},
#  {'text': u'NEAR-MISS LASER BLASTS as Poe pilots aggressively.',
#   'type': 'stage direction'},
#  {'character': u'POE',
#   'text': u'I got to get to my droid before the\nFirst Order does!',
#   'type': 'speech'},
#  {'character': u'FINN', 'text': u'What - a droid?!', 'type': 'speech'},
#  {'character': u'POE',
#   'text': u"That's right. He's a BB unit! Orange\nand white: one of a kind.",
#   'type': 'speech'},
#  {'character': u'FINN',
#   'text': u"I don't care what color he is! No\ndroid can be that important!",
#   'type': 'speech'},
#  {'character': u'POE', 'text': u'This one is, pal.', 'type': 'speech'},
#  {'character': u'FINN',
#   'text': u'We need to get as far away from the\nFirst Order as we can! We go back\nto Jakku, we die!',
#   'type': 'speech'},
#  {'character': u'POE',
#   'text': u"That droid's got a map that leads\nstraight to Luke Skywalker!",
#   'type': 'speech'},
#  {'character': u'FINN',
#   'text': u'Oh, you gotta be kidding me!!! I--',
#   'type': 'speech'},
#  {'text': u'Suddenly BAM! THEY ARE HIT!', 'type': 'stage direction'},
#  {'text': u'EXT. TIE FIGHTER - DAY', 'type': 'location'},
#  {'text': u'The TIE FIGHTER SPARKS AND SMOKES, SPIRALING out of control\ntoward the surface of Jakku!',
#   'type': 'stage direction'},
#  {'text': u'INT. STAR DESTROYER MAIN BRIDGE - DAY', 'type': 'location'},
#  {'text': u"Captain Phasma and General Hux stand before a holographic\nprojection detailing FN-2187's service records.",
#   'type': 'stage direction'},
#  {'character': u'CAPTAIN PHASMA',
#   'text': u'FN-2187 reported to my division, was\nevaluated and sent to Reconditioning.',
#   'type': 'speech'},
#  {'character': u'GENERAL HUX',
#   'text': u'No prior signs of non-conformity?',
#   'type': 'speech'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'character': u'CAPTAIN PHASMA',
#   'text': u'This was his first offense.',
#   'type': 'speech'},
#  {'text': u'A technician checks her readings, reports to General Hux.',
#   'type': 'stage direction'},
#  {'character': u'TECHNICIAN #1',
#   'text': u"General. They've been hit.",
#   'type': 'speech'},
#  {'character': u'GENERAL HUX', 'text': u'Destroyed?', 'type': 'speech'},
#  {'character': u'TECHNICIAN #1\n(GETTING READINGS)',
#   'text': u"Disabled. They were headed back to\nJakku -- the fighter's projected to\ncrash in the Goazon badlands.",
#   'type': 'speech'},
#  {'character': u'GENERAL HUX',
#   'text': u'They were going back for the droid --\nsend a squad to the wreckage.',
#   'type': 'speech'},
#  {'text': u'EXT. JAKKU DESERT - DAY', 'type': 'location'},
#  {'text': u"TIGHT ON FINN'S FACE: His EYES OPEN. He goes from unconscious\nto terrified, fast. He sits up, looks around. CUT BACK\nWIDE: he sits in the middle of an EPIC DESERT, DUNES FOREVER.\nA BLACK CHUTE blows in the wind behind him, scattered debris.\nThen he sees, over distant dunes, RISING BLACK SMOKE. He\ngets up -- moves toward it, calling out:",
#   'type': 'stage direction'},
#  {'character': u'FINN', 'text': u'Poe! Poe!', 'type': 'speech'},
#  {'text': u"Finn scrambles over the massive dune to the TIE FIGHTER,\nSMOKING AND ON FIRE, small debris around it. He thinks he\nsees POE'S ARM -- he pulls on it, but it's JUST POE'S JACKET.\nHe throws that off and tries to find a way in -- even a way\nto LOOK INSIDE, but the smoke and heat make it impossible.",
#   'type': 'stage direction'},
#  {'character': u"FINN (CONT'D)", 'text': u'Poe!!! POE!', 'type': 'speech'},
#  {'text': u"Suddenly the ship BEGINS TO SINK -- like it's being CONSUMED\nINTO QUICKSAND -- Finn is slipping in too --",
#   'type': 'stage direction'},
#  {'character': u"FINN (CONT'D)", 'text': u'POE!!! POE!!!', 'type': 'speech'},
#  {'text': u"It becomes clear fast: if Finn doesn't get away, he's gonna\nget sucked in too! So Finn scampers away from the TIE FIGHTER\nas it SINKS INTO THE SAND! We're in the Sinking Fields. A\nfew moments and IT'S GONE.\nFinn's out of breath. Horrified. Then A GIANT EXPLOSION\nERUPTS FROM below, SENDING SAND AND DEBRIS EVERYWHERE!\nFinn sees this, disoriented, scared, exhausted and defeated.\nAnd all alone.",
#   'type': 'stage direction'},
#  {'text': u'EXT. DESERT - DAY', 'type': 'location'},
#  {'text': u"ENDLESS DUNES BEHIND HIM, Finn walks, removing pieces of his\nStormtrooper gear, using Poe's FLIGHT JACKET for shade.",
#   'type': 'stage direction'},
#  {'text': u'EXT. DESERT - DAY', 'type': 'location'},
#  {'text': u'Exhausted, Finn continues his trek across the endless, sandy\nnothingness.',
#   'type': 'stage direction'},
#  {'text': u'EXT. DESERT - DAY', 'type': 'location'},
#  {'text': u'Finn, parched and losing hope, he walks to the edge of a\nmassive dune, looks out into the epic valley below. Miles\nahead: NIIMA OUTPOST.',
#   'type': 'stage direction'},
#  {'text': u'INT. STAR DESTROYER - BRIDGE - DAY', 'type': 'location'},
#  {'text': u'General Hux and Kylo Ren walk the length of the bridge.',
#   'type': 'stage direction'},
#  {'character': u'GENERAL HUX',
#   'text': u'Supreme Leader Snoke was explicit.\nCapture the droid if we can, but\ndestroy it if we must.',
#   'type': 'speech'},
#  {'character': u'KYLO REN',
#   'text': u'How capable are your soldiers,\nGeneral?',
#   'type': 'speech'},
#  {'character': u'GENERAL HUX\n(WITH VITRIOL)',
#   'text': u"I won't have you question my methods.",
#   'type': 'speech'},
#  {'character': u'KYLO REN',
#   'text': u"They're obviously skilled at\ncommitting high treason. Perhaps\nLeader Snoke should consider using a\nclone army.",
#   'type': 'speech'},
#  {'character': u'GENERAL HUX\n(YOU SON-OF-A-BITCH)',
#   'text': u'My men are exceptionally trained --\nprogrammed from birth--',
#   'type': 'speech'},
#  {'character': u'KYLO REN',
#   'text': u'Then they should have no problem\nretrieving the droid. Unharmed.',
#   'type': 'speech'},
#  {'character': u'GENERAL HUX',
#   'text': u'Careful, Ren. That your "personal\ninterests" not interfere with orders\nfrom Leader Snoke.',
#   'type': 'speech'},
#  {'character': u'KYLO REN',
#   'text': u'I want that map. For your sake, I\nsuggest you get it.',
#   'type': 'speech'},
#  {'text': u'Ren heads off. Hux hates him.', 'type': 'stage direction'},
#  {'text': u'EXT. NIIMA OUTPOST - DAY', 'type': 'location'},
#  {'text': u'Sun-scorched and exhausted, Finn stumbles out of the desert\ninto the Outpost. In a heatstroke daze he moves past enormous\nold SHIP PARTS, MERCHANTS, SCAVENGERS and TENTED STALLS.',
#   'type': 'stage direction'},
#  {'character': u'FINN',
#   'text': u'Water... water... water..',
#   'type': 'speech'},
#  {'text': u'He sees a WATER TROUGH where a filthy, slobbering hippo-like\ncreature (a HAPPABORE) DRINKS. Finn moves to it, uses his\nhands to desperately DRINK the filthy water. After a couple\nswallows he SPITS IT OUT, disgusted.',
#   'type': 'stage direction'},
#  {'character': u"FINN (CONT'D)", 'text': u'-- Awgh, GAH!', 'type': 'speech'},
#  {'text': u"But he's parched and immediately RETURNS FOR MORE.\nACROSS THE MARKETPLACE, REY kneels with an emphatically\nBEEPING BB-8.\nJust then, TWO of UNKAR'S THUGS approach and stop her. One\nclearly tells her that they're taking the droid. BB-8 reacts\nnervously as Rey resists them -- one pulls a SACK over BB-8\nwhile the other grabs Rey's arm -- in the tussle, Rey KNOCKS\nOVER METAL URNS for sale --\nFinn, still drinking, is PUSHED OVER by the happabore. He\nfalls to the ground, then turns to look when he HEARS\nCRASHING. He sees, through the tents, REY FIGHTING.\nHe moves UP CLOSER to help this young woman being accosted --\nbut he STOPS when Rey begins to FIGHT BACK -- scrappy and\nferal, she KICKS, BITES and HITS. Finn is taken aback as\nshe DEFEATS the attackers, who hit the sand, hard.\nFinn just watches, stunned.\nRey moves to the COVERED BB-8 -- PULLS THE SACK OFF OF HIM.\nFinn cannot believe his eyes. IT'S POE'S DROID!\nRey talks to BB-8, who, nervous now, looks around and...\nSEES FINN! BB-8 STARTS BEEPING like crazy. Then something\ninsane happens: REY LOOKS AT FINN.",
#   'type': 'stage direction'},
#  {'character': u'REY', 'text': u'(To BB-8) Who? Him?', 'type': 'speech'},
#  {'text': u"Finn is confused. Rey stands, staring at Finn, defiant.\nFinn can feel trouble coming -- and Rey begins CHARGING AT\nHIM, quarterstaff in hand.\nRealizing he's the target, Finn begins to RUN -- away from\nher, through the tent marketplace. Rey goes after him -- he\nturns a corner -- then another -- then BAM! She's got\nahead of him and SLAMS HIM TO THE GROUND WITH HER STAFF!\nFinn is on his back, out of breath and freaked out. She\nholds the staff on him threateningly:",
#   'type': 'stage direction'},
#  {'character': u'REY', 'text': u"What's your hurry, thief?", 'type': 'speech'},
#  {'character': u'FINN', 'text': u'What--?! Thief?', 'type': 'speech'},
#  {'text': u'BB-8 ROLLS UP FAST, MOVES TO FINN -- a WELDING ARM TELESCOPES\nFROM HIS BODY AND SHOCKS FINN!',
#   'type': 'stage direction'},
#  {'character': u"FINN (CONT'D)", 'text': u'OW! HEY! What?!', 'type': 'speech'},
#  {'character': u'REY',
#   'text': u'The jacket! This droid says you\nstole it!',
#   'type': 'speech'},
#  {'character': u'FINN',
#   'text': u"I've had a pretty messed up day,\nalright?! So I'd appreciate it you\nstop accusing me -- OW!!!\n(BB-8 has ZAPPED him",
#   'type': 'speech'},
#  {'character': u'AGAIN)', 'text': u'STOP IT!', 'type': 'speech'},
#  {'character': u'REY',
#   'text': u"Where'd you get it? It belongs to\nhis master.",
#   'type': 'speech'},
# ...
#   'type': 'speech'},
#  {'text': u'A gentle, satisfied nod from Snoke, and Kylo Ren, obsessed,\nfilled up, exits. Snoke watches him disappear, a grotesque\nevil SMILE growing -- as he DISINTEGRATES -- Snoke has been\na HOLOGRAM all along.',
#   'type': 'stage direction'},
#  {'text': u'EXT. LIGHTSPEED SPACE - DAY', 'type': 'location'},
#  {'text': u'RACING with the Falcon through the STRINGLIGHT of lightspeed.',
#   'type': 'stage direction'},
#  {'text': u'INT. MILLENNIUM FALCON - DAY', 'type': 'location'},
#  {'text': u'CHAOS: INTERCUT between the COCKPIT where Han and Rey pilot,\nALARMS SOUNDING, problems everywhere, and the LOUNGE where\nCHEWIE YELPS as Finn nervously works to BANDAGE HIS SHOULDER.\nSPARKS!',
#   'type': 'stage direction'},
#  {'character': u'HAN', 'text': u'Electrical overload!', 'type': 'speech'},
#  {'character': u'REY', 'text': u'I can fix that!', 'type': 'speech'},
#  {'character': u'HAN', 'text': u"The coolant's leaking!", 'type': 'speech'},
#  {'character': u'REY',
#   'text': u'Try transferring auxiliary power to\nthe secondary tank--',
#   'type': 'speech'},
#  {'character': u'HAN',
#   'text': u'-- Secondary tank, I got it!',
#   'type': 'speech'},
#  {'text': u'INT. LOUNGE:', 'type': 'location'},
#  {'text': u"CHEWIE HOWLS IN PAIN! Finn hangs in there, wraps a bandage\non Chewie's shoulder: Chewie ROARS. BB-8 scurries off.",
#   'type': 'stage direction'},
#  {'character': u'FINN',
#   'text': u'Chewie, come on! I need help with\nthis giant hairy thing! Stop moving!\nChewie!',
#   'type': 'speech'},
#  {'text': u'INT. FALCON COCKPIT:', 'type': 'location'},
#  {'character': u'HAN',
#   'text': u"You hurt Chewie, you're gonna deal\nwith me!",
#   'type': 'speech'},
#  {'text': u'INT. LOUNGE:', 'type': 'location'},
#  {'text': u'As Finn struggles to bandage the Wookiee:',
#   'type': 'stage direction'},
#  {'character': u'FINN',
#   'text': u'Hurt him?! He almost killed me six\ntimes!\n(Chewie GRABS HIM by\nthe collar, ROARS)\nWhich is fine.',
#   'type': 'speech'},
#  {'text': u'INT. FALCON COCKPIT:', 'type': 'location'},
#  {'character': u'HAN',
#   'text': u"This hyperdrive blows there's gonna\nbe pieces of us in three different\nsystems.",
#   'type': 'speech'},
#  {'text': u'Han at the controls when all the alarms STOP. Rey, satisfied,\nsits in the co-pilot seat. Han is confused.',
#   'type': 'stage direction'},
#  {'character': u"HAN (CONT'D)", 'text': u"What'd you do?", 'type': 'speech'},
#  {'character': u'REY',
#   'text': u'I by-passed the compressor.',
#   'type': 'speech'},
#  {'text': u'He looks at her. A little, appreciative laugh. Han exits,\nwalking past BB-8.',
#   'type': 'stage direction'},
#  {'character': u'HAN', 'text': u'Move, Ball.', 'type': 'speech'},
#  {'text': u'INT. MILLENNIUM FALCON - LOUNGE AREA - DAY', 'type': 'location'},
#  {'text': u"Han kneels at Chewie, who lies awake but recovering. Han\nchecks his friend's wound with care. Chewie MOAN-TALKS.",
#   'type': 'stage direction'},
#  {'character': u'HAN',
#   'text': u"Nah, don't say that, you did great.\nJust rest.",
#   'type': 'speech'},
#  {'text': u'Han turns to Finn, who sits at the HOLOCHESS set, BB-8 beside\nhim. This is awkward for Han, but damn, he means it:',
#   'type': 'stage direction'},
#  {'character': u"HAN (CONT'D)",
#   'text': u'Good job, kid. And thanks.',
#   'type': 'speech'},
#  {'character': u'FINN', 'text': u"You're welcome.", 'type': 'speech'},
#  {'text': u'Finn has accidentally hit a button on the chess set, and the\nPIECES appear, looking up at Finn, curiously. The pieces\nstart to FIGHT as Finn fiddles with the controls, trying to\nturn it off.',
#   'type': 'stage direction'},
#  {'character': u'HAN', 'text': u'So, fugitives, huh?', 'type': 'speech'},
#  {'character': u'REY',
#   'text': u'The First Order wants the map.',
#   'type': 'speech'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'character': u"REY (CONT'D)",
#   'text': u'(re: Finn and BB-8)\nFinn is with the Resistance...',
#   'type': 'speech'},
#  {'character': u'(SHRUGS)',
#   'text': u"... I'm just a scavenger.",
#   'type': 'speech'},
#  {'text': u'Han gives Finn a skeptical once-over as Finn finally manages\nto TURN THE CHESS SET OFF as Rey enters. Han looks to BB-8.',
#   'type': 'stage direction'},
#  {'character': u'HAN', 'text': u"Let's see whatcha got.", 'type': 'speech'},
#  {'character': u'REY\n(TO BB-8)', 'text': u'Go ahead.', 'type': 'speech'},
#  {'text': u'BB-8 rolls forward -- and suddenly PROJECTS A HOLOGRAPHIC\nMAP, FILLING THE ROOM. PLANETS, STARS, SYSTEMS.\nThey all react. Chewie sits to look up. Han moves through\nstars, becomes reflective.',
#   'type': 'stage direction'},
#  {'character': u'HAN',
#   'text': u"This map's not complete. It's just\na piece. Ever since Luke disappeared,\npeople have been looking for him.",
#   'type': 'speech'},
#  {'character': u'REY', 'text': u"Why'd he leave?", 'type': 'speech'},
#  {'character': u'HAN',
#   'text': u'He was training a new generation of\nJedi. One boy, an apprentice turned\nagainst him, destroyed it all. Luke\nfelt responsible... He walked away\nfrom everything.',
#   'type': 'speech'},
#  {'character': u'FINN',
#   'text': u'Do you know what happened to him?',
#   'type': 'speech'},
#  {'character': u'HAN',
#   'text': u"There're a lot of rumors. Stories.\nThe people who knew him the best\nthink he went looking for the first\nJedi temple.",
#   'type': 'speech'},
#  {'character': u'REY', 'text': u'The Jedi were real?', 'type': 'speech'},
#  {'character': u'HAN',
#   'text': u'I used to wonder that myself. Thought\nit was a bunch of mumbo-jumbo --\nmagical power holding together good,\nevil, the dark side and the light.',
#   'type': 'speech'},
#  {'character': u'(BEAT)',
#   'text': u"'Crazy thing is, it's true. The\nForce, the Jedi, all of it. It's\nall true.",
#   'type': 'speech'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'text': u'An alarm rings on the control station, prompting Han to toggle\nsome switches. BB-8 cuts off the hologram. Chewie rises\nand moans to Han, but Han motions for Chewie to lay back',
#   'type': 'stage direction'},
#  {'text': u'DOWN:', 'type': 'location'},
#  {'character': u"HAN (CONT'D)",
#   'text': u"No, you rest.\n(To Rey and Finn)\nYou want my help? You're getting\nit. Gonna see an old friend. She'll\nget your droid home. This is our\nstop.",
#   'type': 'speech'},
#  {'text': u'Han leaves towards the cockpit, Rey and Finn following.',
#   'type': 'stage direction'},
#  {'text': u'EXT. LIGHTSPEED TO SPACE - DAY', 'type': 'location'},
#  {'text': u'BEHIND THE FALCON as it DROPS OUT OF LIGHTSPEED, revealing a\nBEAUTIFUL GREEN PLANET ahead, TAKODANA.',
#   'type': 'stage direction'},
#  {'text': u'INT. MILLENNIUM FALCON - COCKPIT - DAY', 'type': 'location'},
#  {'text': u'Han pilots. Finn and BB-8 beside him, Rey as co-pilot.\nHan notices Rey looking out the windshield, almost in tears.',
#   'type': 'stage direction'},
#  {'character': u'REY\n(QUIETLY)',
#   'text': u"... I didn't know there was this\nmuch green in the whole galaxy...",
#   'type': 'speech'},
#  {'text': u'Han watches her -- sees a vulnerability that touches him.',
#   'type': 'stage direction'},
#  {'text': u'EXT. TAKODANA PLANET - DAY', 'type': 'location'},
#  {'text': u'The Falcon CRESTS OVER an ENDLESS GREEN FOREST TO REVEAL a\nCASTLE on a picturesque LAKE.\nThe Falcon lands near the castle, among dozens of WORN,\nsmallish freighters.',
#   'type': 'stage direction'},
#  {'text': u"EXT. LANDING PAD - NEAR MAZ'S CASTLE - DAY", 'type': 'location'},
#  {'text': u'Rey steps off the Falcon, UP TO CAMERA, BB-8 at her side.\nShe takes in the towering stone CASTLE, FOREST to one side,\nLAKE to the other. Serene, beautiful, all new to her.',
#   'type': 'stage direction'},
#  {'text': u'INT. MILLENNIUM FALCON - LOUNGE AREA - DAY', 'type': 'location'},
#  {'text': u'From BLACKNESS: a storage unit opens. Han rummages,\nretrieving old BLASTERS. Finn arrives behind him, concerned.',
#   'type': 'stage direction'},
#  {'character': u'FINN',
#   'text': u"Hey, Solo -- I'm not sure what we're\nwalking into here --",
#   'type': 'speech'},
#  {'character': u'HAN',
#   'text': u'D\'you just call me "Solo"?',
#   'type': 'speech'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'character': u'FINN',
#   'text': u"Sorry. Han-- Mr. Solo. You should\nknow, I'm a big deal in the\nResistance. Which puts a real target\non my back. Are there any\nconspirators here? First Order\nsympathizers?",
#   'type': 'speech'},
#  {'character': u'HAN',
#   'text': u"Listen big deal, you've got another\nproblem. Women always figure out\nthe truth.",
#   'type': 'speech'},
#  {'text': u'Hands him a BLASTER.', 'type': 'stage direction'},
#  {'character': u"HAN (CONT'D)", 'text': u'Always.', 'type': 'speech'},
#  {'text': u'Han walks off. Finn watches him go, wracked with guilt.',
#   'type': 'stage direction'},
#  {'text': u"EXT. MAZ'S CASTLE - DAY", 'type': 'location'},
#  {'text': u'Han hands Rey a blaster pistol as she stands at looks at the\ncastle.',
#   'type': 'stage direction'},
#  {'character': u'HAN', 'text': u'You might need this.', 'type': 'speech'},
#  {'character': u'REY',
#   'text': u'I think I can handle myself.',
#   'type': 'speech'},
#  {'character': u'HAN',
#   'text': u"I know you do. That's why I'm giving\nit to you. Take it.",
#   'type': 'speech'},
#  {'text': u'Rey picks it up. Grips it.', 'type': 'stage direction'},
#  {'character': u"HAN (CONT'D)",
#   'text': u'You know how to use one of these?',
#   'type': 'speech'},
#  {'character': u'REY',
#   'text': u'Yeah, you pull the trigger.',
#   'type': 'speech'},
#  {'character': u'HAN',
#   'text': u"There's a little bit more to it than\nthat. You got a lot to learn. You\ngot a name?",
#   'type': 'speech'},
#  {'character': u'REY', 'text': u'Rey.', 'type': 'speech'},
#  {'character': u'HAN',
#   'text': u"Rey. I've been thinkin' about\nbringing on some more crew, Rey. A\nsecond mate. Someone to help out.\nSomeone who can keep up with Chewie\nand me, appreciates the Falcon.",
#   'type': 'speech'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'character': u'REY',
#   'text': u'Are you offering me a job?',
#   'type': 'speech'},
#  {'character': u'HAN',
#   'text': u"I wouldn't be nice to you. It doesn't\npay much.",
#   'type': 'speech'},
#  {'character': u'REY', 'text': u"You're offering me a job.", 'type': 'speech'},
#  {'character': u'HAN', 'text': u"I'm thinking about it.", 'type': 'speech'},
#  {'text': u"Rey wants to say yes. But something stops her. A line she\ncan't cross.",
#   'type': 'stage direction'},
#  {'character': u"HAN (CONT'D)", 'text': u'Well?', 'type': 'speech'},
#  {'character': u'REY',
#   'text': u"If you were, I'd be flattered. But\nI have to get home.",
#   'type': 'speech'},
#  {'text': u'Han looks at her, questioningly.', 'type': 'stage direction'},
#  {'character': u'HAN', 'text': u'Jakku?', 'type': 'speech'},
#  {'text': u'Rey looks off, in thought. Yeah, Jakku.',
#   'type': 'stage direction'},
#  {'character': u'REY\n(BEAT)',
#   'text': u"I've already been away too long.",
#   'type': 'speech'},
#  {'character': u'HAN\n(TO CHEWIE)',
#   'text': u'Chewie, check out the ship as best\nyou can.',
#   'type': 'speech'},
#  {'character': u"HAN (CONT'D)",
#   'text': u"It's too bad. Chewie kind of likes\nyou.",
#   'type': 'speech'},
#  {'text': u'Han heads off. HOLD on Rey.', 'type': 'stage direction'},
#  {'text': u"EXT. MAZ'S CASTLE - DAY", 'type': 'location'},
#  {'text': u'Han walks them to the castle.', 'type': 'stage direction'},
#  {'character': u'FINN',
#   'text': u'Solo, why are we here again?',
#   'type': 'speech'},
#  {'character': u'HAN',
#   'text': u'To get your droid on a clean ship.',
#   'type': 'speech'},
#  {'character': u'REY', 'text': u'Clean?', 'type': 'speech'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'character': u'HAN',
#   'text': u"Do you think it was luck that Chewie\nand I found the Falcon? If we can\nfind it on our scanners, the First\nOrder's not far behind. Want to get\nBB-8 to the Resistance? Maz Kanata\nis our best bet.",
#   'type': 'speech'},
#  {'character': u'FINN', 'text': u'We can trust her, right?', 'type': 'speech'},
#  {'character': u'HAN',
#   'text': u"Relax, kid. She's run this watering\nhole for a thousand years. Maz is a\nbit of an acquired taste, so let me\ndo the talking. And whatever you\ndo, don't stare...\nREY AND FINN\nAt what?",
#   'type': 'speech'},
#  {'character': u'HAN', 'text': u'Any of it.', 'type': 'speech'},
#  {'text': u'The door opens. Music. Madness. And...',
#   'type': 'stage direction'},
#  {'text': u"INT. MAZ'S CASTLE - MAIN ROOM - DAY", 'type': 'location'},
#  {'text': u'We ENTER THE LOUD, CROWDED MESS of a hall -- PUSHING PAST a\nroom full of rough and odd ALIENS AND HUMANS, who gamble,\ndrink, scheme, negotiate, argue -- until we end up on the\nBACK of a tiny, thousand year-old, four foot tall ALIEN, who\nsuddenly STARTS, as if SENSING something -- the Alien TURNS\nTO US: she is FEMALE, wearing large ADJUSTABLE GOGGLES.\nThis is MAZ KANATA.',
#   'type': 'stage direction'},
#  {'character': u'MAZ', 'text': u'Han Solo!', 'type': 'speech'},
#  {'text': u"Everyone turns to look. It's ALL QUIET in here.",
#   'type': 'stage direction'},
#  {'character': u'HAN',
#   'text': u'(Sotto) Oh boy. (Louder, waving)\nHey, Maz!',
#   'type': 'speech'},
#  {'text': u'NOISE returns. Maz walks to them, pushes someone away.',
#   'type': 'stage direction'},
#  {'character': u'MAZ', 'text': u"Where's my boyfriend?", 'type': 'speech'},
#  {'character': u'HAN',
#   'text': u"Chewie's working on the Falcon.",
#   'type': 'speech'},
#  {'character': u'MAZ',
#   'text': u"I like that Wookiee. I assume you\nneed something. Desperately. Let's\nget to it.",
#   'type': 'speech'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'text': u'Maz walks off, gesturing for them to follow. Finn and Rey\nare confused. Han indicates for them to follow. They do --\npassing the enormous GRUMMGAR, who sits with vixen BAZINE\nNETAL, who watches them suspiciously.\nA SMALL DROID (GA-97), who turns its head to see BB-8\nfollowing Rey across the room. GA-97, now animated, makes a\nsmall TRANSMITTING SOUND, which is subtitled.',
#   'type': 'stage direction'},
#  {'character': u'GA-97',
#   'text': u'Alert the Resistance. Their missing\ndroid is here!',
#   'type': 'speech'},
#  {'text': u'And we CUT TO:\nIN A DARK ALCOVE - MOMENTS LATER\nBazine enters a shadowy space, stealthily makes a call on a\ncommunicator. Clearly, BAZINE IS A SPY. Subtitled:',
#   'type': 'stage direction'},
#  {'character': u'BAZINE',
#   'text': u"Inform the First Order... I've found\nthe droid.",
#   'type': 'speech'},
#  {'text': u'EXT. STARKILLER BASE - DAY', 'type': 'location'},
#  {'text': u'A massive Star Destroyer hovers over the hacked ice planet.',
#   'type': 'stage direction'},
#  {'text': u"INT. STAR DESTROYER - KYLO REN'S CHAMBERS - DAY",
#   'type': 'location'},
#  {'text': u'A dark space. Kylo Ren, CLOSE TO CAMERA, addresses someone\nOFF-CAMERA whom we do not see.',
#   'type': 'stage direction'},
#  {'character': u'KYLO REN',
#   'text': u'Forgive me. I feel it again. The\npull to the light. Supreme Leader\nsenses it. Show me again, the power\nof the darkness, and I will let\nnothing stand in our way. Show me,\nGrandfather, and I will finish what\nyou started.',
#   'type': 'speech'},
#  {'text': u'As his emotion builds, he stands and heads off -- we FOLLOW\nHIM, PIVOTING TO REVEAL who he was talking to: THE BURNT,\nASHEN, GHOSTLY DEFORMED MASK OF DARTH VADER.',
#   'type': 'stage direction'},
#  {'text': u"INT. MAZ'S CASTLE - TABLE - DAY", 'type': 'location'},
#  {'text': u'Maz is putting together some FOOD as she says:',
#   'type': 'stage direction'},
#  {'character': u'MAZ',
#   'text': u"A map to Skywalker himself? You're\nright back in the mess.",
#   'type': 'speech'},
#  {'character': u'HAN',
#   'text': u'Maz, I need you to get this droid to\nLeia.',
#   'type': 'speech'},
#  {'text': u'CONTINUED:', 'type': 'location'},
#  {'character': u'MAZ',
#   'text': u"Hmm. No. You've been running away\nfrom this fight for too long. Han,\nnyakee nago wadda. Go home!",
#   'type': 'speech'},
#  {'character': u'HAN',
#   'text': u"Leia doesn't want to see me.",
#   'type': 'speech'},
#  {'character': u'FINN',
#   'text': u'Please, we came here for your help.',
#   'type': 'speech'},
#  ...]

# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

space_vector_=np.array(space_vector)
plt.figure(figsize=(20,10))
plt.hist(space_vector_, bins=np.arange(space_vector_.min(), space_vector_.max()+1)-0.5)
plt.title('White space (head of line) distributions')
plt.xlabel('Number of white spaces')
plt.ylabel('Count')

# %%
from collections import Counter
Counter(space_vector)

    #all the occurences except the top 3 are occurences from global stage references
# Out:
# Counter({10: 2041,
#          11: 1565,
#          22: 1,
#          23: 1,
#          25: 88,
#          26: 947,
#          31: 1,
#          36: 1,
#          39: 2,
#          40: 1})

# %%
# script dict to be serialized as JSON
script=dict()


# Let's fill what we can here
script['movie_url'] = script_url

# movie's name


# movie's year



BLOCK_TYPES=['character', 'speech', 'stage direction', 'location']
CHARACTER=0
SPEECH=1
DIRECTIONS=2
LOCATION=3


# COMPILE ALL THE REGULAR EXPRESSIONS!
spaces_regex = re.compile("^(\s*).*")
location_regex = re.compile("^\s*(INT\.|EXT\.)")

def get_line_type(line, stripped_line, usual_spaces, characters):
    # Counting the number of spaces at the beginning of the line
    spmatch = spaces_regex.search(line)
    spaces_number = len(spmatch.group(1))
    block_type = 0

    if( location_regex.search(line) != None ):
        return LOCATION

    if stripped_line in characters:
        return CHARACTER

    # Look for space
    for block_type_usual_spaces in usual_spaces:
        if spaces_number in block_type_usual_spaces:
            block_type = usual_spaces.index(block_type_usual_spaces)
            #print('We consider {:d} leading spaces as a \'{:s}\' block.'.format(
            #      spaces_number, BLOCK_TYPES[block_type]))
            return usual_spaces.index(block_type_usual_spaces)

    print('There are {:d} space(s) at the beginning of this line'.format(spaces_number))
    question = "What kind of block is that?\n"
    for i in range(len(BLOCK_TYPES)):
        question += '\t('+str(i)+') ' + BLOCK_TYPES[i] + '\n'
    print(question)

    validated = False
    while( validated == False):
        try:
            block_type = int(input('? [0-{:d}] '.format(len(BLOCK_TYPES)-1)))
            while( block_type < 0 or block_type >= len(BLOCK_TYPES)):
                block_type = int(input('? [0-{:d}] '.format(len(BLOCK_TYPES)-1)))
        except ValueError:
            continue

        validated = True


    remember_spaces = False
    validated = False
    while( validated == False):
        answer_spaces = input('Are all  lines with {:d} leading spaces \'{:s}\' blocks ? (Y/n) '.format(
                spaces_number, BLOCK_TYPES[block_type]))

        if( answer_spaces == 'n' or answer_spaces =='N' ):
            print('You said no: we will ask you again next time.')
            remember_spaces = False
        else:
            print('You said yes: ' +
                  'every new block with {:d} leading spaces '.format(spaces_number) +
                  'will now be considered a \'{:s}\'.'.format(BLOCK_TYPES[block_type]) )
            remember_spaces = True

        validated = True


    if( remember_spaces ):
        usual_spaces[block_type].append(spaces_number)

    return block_type



# In[53]:

# DA big loop

usual_spaces=[[] for i in range(len(BLOCK_TYPES))]

# Ici on définit les variables qu'on remplira de texte
is_intro = True
movie_script = []
intro = []
last_line_type = -1
last_character = ''
text = []
characters=[]


print()
print()
print("Here we go for some kickass movie script parsing!")
print()
print()
print("Start by telling me when the introduction will end.")

for block in script_text.descendants:
    # Si block est une instance de bs4.Tag, il est entouré de balises HTML
    # Le prochain block contiendra le même texte sans les balises
    # Donc on continue sans parser ce bloc
    if(isinstance(block, Tag)):
        continue

    # UnicodeDammit converts any string to UTF-8
    # does not work so well
    block = UnicodeDammit(block, soup.original_encoding).unicode_markup
    # remove leading and ending end of lines
    block = block.strip('\n')

    # if the block doesn't have any text, skip it
    if( re.search('\w', block) == None ):
        continue

    # bs4 ne coupe pas toujours bien les différents blocs
    # Mieux vaut donc redécouper par paragraphe et les traiter un à un
    for line in block.split('\n'):
        stripped_line = line.strip(' \n\t\r')
        if( re.search('\w', line) == None ):
            continue

        print('------------------------------ Begin line ------------------------------')
        print(line)
        print('                        ------- End line -------')

        if( is_intro ):
            print()
            answer = input("Is that still part of the intro? (Y/n) ")

            if(answer == 'n' or answer == 'N'):
                is_intro = False
                movie_script.append({
                    'type': 'introduction',
                    'text': '\n'.join(intro)})

                print(movie_script[-1])
            else:
                print("OK")
                print()
                intro.append(stripped_line)
                continue


        line_type = get_line_type(line, stripped_line, usual_spaces, characters)
        print("The last line was interpreted as '{}'".format(BLOCK_TYPES[line_type]))
        print()

        if(last_line_type == -1 # -1 = not initialized
           or last_line_type == line_type):
            text.append(stripped_line)
        else:
            if(last_line_type == CHARACTER):
                last_character='\n'.join(text)
                if not last_character in characters:
                    characters.append(last_character)
            elif(last_line_type == SPEECH):
                movie_script.append({
                    'type': BLOCK_TYPES[last_line_type],
                    BLOCK_TYPES[CHARACTER]: last_character,
                    'text': '\n'.join(text)})
                print('We just parsed this JSON block:')
                print(movie_script[-1])
            else:
                movie_script.append({
                    'type': BLOCK_TYPES[last_line_type],
                    'text': '\n'.join(text)})
                print('We just parsed this JSON block:')
                print(movie_script[-1])
            text=[stripped_line]

        last_line_type = line_type

        #print('block_type={:d}'.format(line_type))
        #print('usual spaces:')
        #print(usual_spaces)
        #print('This line is a \'{:s}\'.'.format(BLOCK_TYPES[line_type]))

        print()

    print()
    print()

movie_script.append({
    'type': BLOCK_TYPES[line_type],
    'text': '\n'.join(text)})

print('We just parsed this JSON block:')
print(movie_script[-1])
print()
print()

script['movie_script'] = movie_script

print('All done, biiiiitch!')


# In[64]:

#print(flush=True)
#print(flush=True)
print('(Our current directory is: {})'.format(os.getcwd()))
out_filename = input('Now, gimme an output filename: ')

try:
    fd = open(out_filename, 'w')
    json.dump(script, fd, indent=True)
    print('We just successfully wrote {}\'s script as JSON to {} .'.format(script['movie_title'], fd.name))
    print('Bravo!')
except:
    print("Shit happened: ", sys.exc_info()[0])
finally:
    fd.close()
    print()
    print('Done.')
# Out:
# ()
# ()
# Here we go for some kickass movie script parsing!
# ()
# ()
# Start by telling me when the introduction will end.
# ------------------------------ Begin line ------------------------------
#                                STAR WARS: THE FORCE AWAKENS
#                         ------- End line -------
# ()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-164-0649fca48c7c> in <module>()
#     140         if( is_intro ):
#     141             print()
# --> 142             answer = input("Is that still part of the intro? (Y/n) ")
#     143
#     144             if(answer == 'n' or answer == 'N'):
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/ipykernel/ipkernel.pyc in <lambda>(prompt)
#     139             self._sys_eval_input = builtin_mod.input
#     140             builtin_mod.raw_input = self.raw_input
# --> 141             builtin_mod.input = lambda prompt='': eval(self.raw_input(prompt))
#     142         self._save_getpass = getpass.getpass
#     143         getpass.getpass = self.getpass
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in raw_input(self, prompt)
#     675             self._parent_ident,
#     676             self._parent_header,
# --> 677             password=False,
#     678         )
#     679
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in _input_request(self, prompt, ident, parent, password)
#     705             except KeyboardInterrupt:
#     706                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 707                 raise KeyboardInterrupt
#     708             else:
#     709                 break
#
# KeyboardInterrupt:

# %%
# script dict to be serialized as JSON
script=dict()


# Let's fill what we can here
script['movie_url'] = script_url

# movie's name


# movie's year



BLOCK_TYPES=['character', 'speech', 'stage direction', 'location']
CHARACTER=0
SPEECH=1
DIRECTIONS=2
LOCATION=3


# COMPILE ALL THE REGULAR EXPRESSIONS!
spaces_regex = re.compile("^(\s*).*")
location_regex = re.compile("^\s*(INT\.|EXT\.)")


# DA big loop
usual_spaces=[[] for i in range(len(BLOCK_TYPES))]
# Ici on définit les variables qu'on remplira de texte
is_intro = True
movie_script = []
intro = []
last_line_type = -1
last_character = ''
text = []
characters=[]


# In[53]:

# DA big loop

usual_spaces=[[] for i in range(len(BLOCK_TYPES))]
usual_spaces=[[26,32]]
# Ici on définit les variables qu'on remplira de texte
is_intro = True
movie_script = []
intro = []
last_line_type = -1
last_character = ''
text = []
characters=[]

# %%
for block in script_text.descendants:
    # Si block est une instance de bs4.Tag, il est entouré de balises HTML
    # Le prochain block contiendra le même texte sans les balises
    # Donc on continue sans parser ce bloc
    if(isinstance(block, Tag)):
        continue

    # UnicodeDammit converts any string to UTF-8
    # does not work so well
    block = UnicodeDammit(block, soup.original_encoding).unicode_markup
    # remove leading and ending end of lines
    block = block.strip('\n')

    # if the block doesn't have any text, skip it
    if( re.search('\w', block) == None ):
        continue

    # bs4 ne coupe pas toujours bien les différents blocs
    # Mieux vaut donc redécouper par paragraphe et les traiter un à un
    for line in block.split('\n'):
        stripped_line = line.strip(' \n\t\r')



        line_type = get_line_type(line, stripped_line, usual_spaces, characters)
        print("The last line was interpreted as '{}'".format(BLOCK_TYPES[line_type]))
        print()

        if(last_line_type == -1 # -1 = not initialized
           or last_line_type == line_type):
            text.append(stripped_line)
        else:
            if(last_line_type == CHARACTER):
                last_character='\n'.join(text)
                if not last_character in characters:
                    characters.append(last_character)
            elif(last_line_type == SPEECH):
                movie_script.append({
                    'type': BLOCK_TYPES[last_line_type],
                    BLOCK_TYPES[CHARACTER]: last_character,
                    'text': '\n'.join(text)})
                print('We just parsed this JSON block:')
                print(movie_script[-1])
            else:
                movie_script.append({
                    'type': BLOCK_TYPES[last_line_type],
                    'text': '\n'.join(text)})
                print('We just parsed this JSON block:')
                print(movie_script[-1])
            text=[stripped_line]

        last_line_type = line_type

        #print('block_type={:d}'.format(line_type))
        #print('usual spaces:')
        #print(usual_spaces)
        #print('This line is a \'{:s}\'.'.format(BLOCK_TYPES[line_type]))

        print()

    print()
    print()

movie_script.append({
    'type': BLOCK_TYPES[line_type],
    'text': '\n'.join(text)})

print('We just parsed this JSON block:')
print(movie_script[-1])
print()
print()

script['movie_script'] = movie_script

print('All done!')


# In[64]:

#print(flush=True)
#print(flush=True)
print('(Our current directory is: {})'.format(os.getcwd()))
out_filename = 'test.txt'

try:
    fd = open(out_filename, 'w')
    json.dump(script, fd, indent=True)
    print('We just successfully wrote {}\'s script as JSON to {} .'.format(script['movie_title'], fd.name))
    print('Bravo!')
except:
    print("Shit happened: ", sys.exc_info()[0])
finally:
    fd.close()
    print()
    print('Done.')
